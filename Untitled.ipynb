# %%
from tool.func import *

# %%
from tqdm import tqdm_notebook

# %%
l1 = import_mono('rus')

# %%
w = Word('Евгений', 'rus', s=['np'])

# %%
w = Word('или', 'rus', ['n'])

# %%
w.lemma
# Out:
# 'Евгений'

# %%
type(w)
# Out:
# tool.func.Word

# %%
l1[w]

# %%
l1.list.sort(key=str)

# %%
l1.list
# Out:
# [rus$в$[pr_],
#  rus$внутри$[pr_],
#  rus$возле$[pr_],
#  rus$граммофон$[n-m-nn_n],
#  rus$для$[pr_],
#  rus$до$[pr_],
#  rus$за$[pr_],
#  rus$кроме$[pr_],
#  rus$между$[pr_],
#  rus$мимо$[pr_],
#  rus$на$[pr_],
#  rus$над$[pr_],
#  rus$о$[pr_],
#  rus$около$[pr_],
#  rus$перед$[pr_],
#  rus$перед$[n_n-m-nn],
#  rus$из$[pr_],
#  rus$с$[pr_],
#  rus$prpers$[prn-pers-p3-mf-pl_prn_prn-pers],
#  rus$prpers$[prn-p1-mf_prn-pers-p1-mf],
#  rus$prpers$[prn-p2-mf_prn-pers-p2-mf],
#  rus$это$[prn-dem-nt_prn-dem-nt-sg_prn],
#  rus$который$[prn_prn-rel],
#  rus$весь$[prn-def-mfn-an-pl_prn-def_prn],
#  rus$весь$[det-ind-mfn-an-pl-nom_det-ind_det_det-ind-mfn],
#  rus$сколько$[prn_prn-itg_prn-itg-mfn-sg],
#  rus$сколько$[det_det-qnt_det-qnt-mfn-sg],
#  rus$сколько$[num_num-mfn-an-pl],
#  rus$что$[prn_prn-itg_prn-itg-nt-sg_prn-itg-nt],
#  rus$свой$[det-pos_det-pos-m-an-sg-nom_det],
#  rus$самый$[det-def-m-an-sg-nom_det-def],
#  rus$ваш$[det-pos_det-pos-m-sg-nom_det-pos-m-sg_det_det-pos-m-nn-sg-nom],
#  rus$ваш$[prn-pos_prn],
#  rus$правило$[n-nt-nn_n],
#  rus$год$[n-m-nn_n-m_n],
#  rus$август$[n-m-nn_n-m_n],
#  rus$авиация$[n-f-nn_n-f_n],
#  rus$автобус$[n-m-nn_n_n-m],
#  rus$автомат$[n-m-nn_n],
#  rus$автомобиль$[n-m-nn_n_n-m],
#  rus$автор$[n-m-aa_n_n-m],
#  rus$авторитет$[n-m-nn_n],
#  rus$агент$[n-m-aa_n],
#  rus$агентство$[n-nt-nn_n_n-nt],
#  rus$ад$[n-m-nn_n-m-nn-sg_n],
#  rus$адвокат$[n-m-aa_n_n-m],
#  rus$адмирал$[n-m-aa_n_n-m],
#  rus$адрес$[n-m-nn_n],
#  rus$академик$[n-m-aa_n],
#  rus$академия$[n-f-nn_n_n-f],
#  rus$аккумулятор$[n-m-nn_n],
#  rus$акт$[n-m-nn_n],
#  rus$акцент$[n-m-nn_n],
#  rus$акция$[n-f-nn_n-f_n],
#  rus$алкоголь$[n-m-nn_n_n-m],
#  rus$альбом$[n-m-nn_n],
#  rus$анализ$[n-m-nn_n_n-m],
#  rus$ангел$[n-m-aa_n],
#  rus$англичанин$[n-m-aa_n],
#  rus$анекдот$[n-m-nn_n],
#  rus$аппарат$[n-m-nn_n],
#  rus$аппетит$[n-m-nn_n],
#  rus$апрель$[n-m-nn_n-m_n],
#  rus$аргумент$[n-m-nn_n],
#  rus$арест$[n-m-nn_n-m_n],
#  rus$армия$[n-f-nn_n-f_n],
#  rus$артиллерия$[n-f-nn_n],
#  rus$архив$[n-m-nn_n_n-m],
#  rus$асфальт$[n-m-nn_n],
#  rus$атмосфера$[n-f-nn_n_n-f],
#  rus$аэродром$[n-m-nn_n],
#  rus$аэропорт$[n-m-nn_n-m_n],
#  rus$бабочка$[n-f-aa_n_n-f],
#  rus$бабушка$[n-f-aa_n],
#  rus$база$[n-f-nn_n],
#  rus$базар$[n-m-nn_n],
#  rus$балкон$[n-m-nn_n],
#  rus$банда$[n-f-nn_n_n-f],
#  rus$бандит$[n-m-aa_n],
#  rus$банк$[n-m-nn_n_n-m],
#  rus$баня$[n-f-nn_n_n-f],
#  rus$барак$[n-m-nn_n],
#  rus$барон$[n-m-aa_n],
#  rus$барьер$[n-m-nn_n],
#  rus$бассейн$[n-m-nn_n],
#  rus$батальон$[n-m-nn_n_n-m],
#  rus$батарея$[n-f-nn_n],
#  rus$башня$[n-f-nn_n],
#  rus$бег$[n-m-nn_n-m-nn-sg_n],
#  rus$бедро$[n-nt-nn_n],
#  rus$безопасность$[n-f-nn_n-f],
#  rus$белок$[n-m-nn_n],
#  rus$бензин$[n-m-nn_n],
#  rus$берег$[n-m-nn_n],
#  rus$бес$[n-m-aa_n],
#  rus$беспокойство$[n-nt-nn_n],
#  rus$библиотека$[n-f-nn_n],
#  rus$бизнес$[n-m-nn_n_n-m],
#  rus$билет$[n-m-nn_n],
#  rus$бинокль$[n-m-nn_n],
#  rus$биография$[n-f-nn_n],
#  rus$битва$[n-f-nn_n],
#  rus$благо$[n-nt-nn_n],
#  rus$благодарность$[n-f-nn_n_n-f],
#  rus$блин$[n-m-nn_n],
#  rus$блок$[n-m-nn_n_n-m],
#  rus$блюдо$[n-nt-nn_n],
#  rus$бог$[n-m-aa_n-m_n],
#  rus$богатство$[n-nt-nn_n_n-nt],
#  rus$бой$[n-m-aa_n],
#  rus$бок$[n-m-nn_n],
#  rus$бокал$[n-m-nn_n],
#  rus$болезнь$[n-f-nn_n-f_n],
#  rus$болото$[n-nt-nn_n],
#  rus$боль$[n-f-nn_n],
#  rus$больница$[n-f-nn_n_n-f],
#  rus$большевик$[n-m-aa_n],
#  rus$большинство$[n-nt-nn_n_n-nt],
#  rus$бомба$[n-f-nn_n_n-f],
#  rus$борода$[n-f-nn_n],
#  rus$борьба$[n-f-nn_n-f],
#  rus$ботинок$[n-m-nn_n],
#  rus$брак$[n-m-nn_n],
#  rus$брат$[n-m-aa_n],
#  rus$бред$[n-m-nn_n-m-nn-sg_n],
#  rus$бригада$[n-f-nn_n_n-f],
#  rus$бригадир$[n-m-aa_n],
#  rus$бровь$[n-f-nn_n],
#  rus$брюхо$[n-nt-nn_n],
#  rus$будущее$[n-nt-nn_n-nt_n],
#  rus$буква$[n-f-nn_n_n-f],
#  rus$бульвар$[n-m-nn_n],
#  rus$бумага$[n-f-nn_n],
#  rus$буря$[n-f-nn_n],
#  rus$бутылка$[n-f-nn_n],
#  rus$бык$[n-m-aa_n],
#  rus$бюджет$[n-m-nn_n_n-m],
#  rus$бюро$[n-nt-aa_n],
#  rus$вагон$[n-m-nn_n],
#  rus$вал$[n-m-nn_n],
#  rus$валюта$[n-f-nn_n_n-f],
#  rus$ванна$[n-f-nn_n],
#  rus$введение$[n-nt-nn_n],
#  rus$вдова$[n-f-aa_n],
#  rus$ведьма$[n-f-aa_n],
#  rus$век$[n-m-nn_n-m_n],
#  rus$веко$[n-nt-nn_n],
#  rus$величина$[n-f-nn_n],
#  rus$велосипед$[n-m-nn_n],
#  rus$вена$[n-f-nn_n],
#  rus$вера$[n-f-nn_n],
#  rus$веранда$[n-f-nn_n],
#  rus$версия$[n-f-nn_n],
#  rus$вершина$[n-f-nn_n],
#  rus$вес$[n-m-nn_n_n-m-nn-pl],
#  rus$весло$[n-nt-nn_n],
#  rus$весна$[n-f-nn_n_n-f],
#  rus$ветвь$[n-f-nn_n],
#  rus$ветер$[n-m-nn_n_n-m],
#  rus$ветеран$[n-m-aa_n_n-m],
#  rus$вечер$[n-m-nn_n],
#  rus$вещество$[n-nt-nn_n],
#  rus$взгляд$[n-m-nn_n],
#  rus$взрыв$[n-m-nn_n_n-m],
#  rus$видимость$[n-f-nn_n],
#  rus$виза$[n-f-nn_n_n-f],
#  rus$вина$[n-f-nn_n_n-f],
#  rus$вино$[n-nt-nn_n],
#  rus$винтовка$[n-f-nn_n],
#  rus$виски$[n-m-aa_n],
#  rus$висок$[n-m-nn_n],
#  rus$вкус$[n-m-nn_n],
#  rus$владелец$[n-m-aa_n],
#  rus$власть$[n-f-nn_n_n-f],
#  rus$внимание$[n-nt-nn_n-nt_n],
#  rus$внук$[n-m-aa_n],
#  rus$вода$[n-f-nn_n_n-f],
#  rus$водка$[n-f-nn_n],
#  rus$вождь$[n-m-aa_n],
#  rus$воздух$[n-m-nn_n_n-m],
#  rus$возможность$[n-f-nn_n],
#  rus$воин$[n-m-aa_n],
#  rus$война$[n-f-nn_n-f_n],
#  rus$войско$[n-nt-nn_n],
#  rus$вокзал$[n-m-nn_n],
#  rus$волк$[n-m-aa_n],
#  rus$волна$[n-f-nn_n_n-f],
#  rus$волнение$[n-nt-nn_n],
#  rus$волос$[n-m-nn_n],
#  rus$волшебник$[n-m-aa_n],
#  rus$воля$[n-f-nn_n_n-f],
#  rus$воображение$[n-nt-nn_n],
#  rus$вопрос$[n-m-nn_n-m_n],
#  rus$воробей$[n-m-aa_n],
#  rus$воротник$[n-m-aa_n],
#  rus$воскресенье$[n-nt-nn_n],
#  rus$воспаление$[n-nt-nn_n],
#  rus$восток$[n-m-nn_n_n-m],
#  rus$восторг$[n-m-nn_n],
#  rus$враг$[n-m-aa_n],
#  rus$врач$[n-m-aa_n_n-m],
#  rus$время$[n-nt-nn_n_n-nt],
#  rus$вселенная$[n-f-nn_n],
#  rus$выбор$[n-m-nn_n_n-m],
#  rus$вызов$[n-m-nn_n],
#  rus$выпуск$[n-m-nn_n],
#  rus$высота$[n-f-nn_n_n-f],
#  rus$выставка$[n-f-nn_n],
#  rus$выстрел$[n-m-nn_n_n-m],
#  rus$выход$[n-m-nn_n],
#  rus$газ$[n-m-nn_n_n-m],
#  rus$газета$[n-f-nn_n_n-f],
#  rus$галстук$[n-m-nn_n],
#  rus$гараж$[n-m-nn_n],
#  rus$гвоздь$[n-m-nn_n],
#  rus$ген$[n-m-nn_n_n-m],
#  rus$генерал$[n-m-aa_n-m_n],
#  rus$гений$[n-m-aa_n],
#  rus$герой$[n-m-aa_n],
#  rus$глава$[n-f-nn_n],
#  rus$глаз$[n-m-nn_n_n-m],
#  rus$глина$[n-f-nn_n],
#  rus$глоток$[n-m-nn_n],
#  rus$гнев$[n-m-nn_n],
#  rus$гнездо$[n-nt-nn_n],
#  rus$голова$[n-f-nn_n-f_n],
#  rus$голод$[n-m-nn_n-m-nn-sg_n-m],
#  rus$голос$[n-m-nn_n_n-m],
#  rus$гора$[n-f-nn_n_n-f],
#  rus$гордость$[n-f-nn_n],
#  rus$горе$[n-nt-nn_n-nt-nn-sg],
#  rus$горечь$[n-f-nn_n],
#  rus$горизонт$[n-m-nn_n],
#  rus$горло$[n-nt-nn_n],
#  rus$город$[n-m-nn_n-m_n],
#  rus$городок$[n-m-nn_n],
#  rus$горшок$[n-m-nn_n],
#  rus$госпиталь$[n-m-nn_n],
#  rus$господь$[n-m-aa_n],
#  rus$госпожа$[n-f-aa_n],
#  rus$гостиница$[n-f-nn_n_n-f],
#  rus$гость$[n-m-aa_n],
#  rus$государство$[n-nt-nn_n_n-nt],
#  rus$градус$[n-m-nn_n_n-m],
#  rus$грамм$[n-m-aa_n],
#  rus$граната$[n-f-nn_n_n-f],
#  rus$граница$[n-f-nn_n_n-f],
#  rus$грек$[n-m-aa_n-m],
#  rus$гриб$[n-m-nn_n],
#  rus$гроб$[n-m-nn_n],
#  rus$гроза$[n-f-nn_n],
#  rus$гром$[n-m-nn_n],
#  rus$груз$[n-m-nn_n],
#  rus$грузовик$[n-m-nn_n_n-m],
#  rus$группа$[n-f-nn_n_n-f],
#  rus$группировка$[n-f-nn_n],
#  rus$грязь$[n-f-nn_n],
#  rus$губа$[n-f-nn_n],
#  rus$губернатор$[n-m-aa_n],
#  rus$гусь$[n-m-aa_n],
#  rus$давление$[n-nt-nn_n_n-nt],
#  rus$даль$[n-f-nn_n],
#  rus$дама$[n-f-aa_n],
#  rus$дар$[n-m-nn_n],
#  rus$дата$[n-f-nn_n_n-f],
#  rus$дача$[n-f-nn_n],
#  rus$дверь$[n-f-nn_n_n-f],
#  rus$двигатель$[n-m-nn_n],
#  rus$движение$[n-nt-nn_n_n-nt],
#  rus$двор$[n-m-nn_n],
#  rus$дворец$[n-m-nn_n],
#  rus$девочка$[n-f-aa_n],
#  rus$дед$[n-m-aa_n],
#  rus$дедушка$[n-m-aa_n],
#  rus$декабрь$[n-m-nn_n-m_n],
#  rus$делегация$[n-f-nn_n_n-f],
#  rus$демократия$[n-f-nn_n-f_n],
#  rus$день$[n-m-nn_n-m_n],
#  rus$депутат$[n-m-aa_n-m],
#  rus$деревня$[n-f-nn_n_n-f],
#  rus$дерево$[n-nt-nn_n_n-nt],
#  rus$десятилетие$[n-nt-nn_n-nt],
#  rus$деталь$[n-f-nn_n],
#  rus$детство$[n-nt-nn_n],
#  rus$диван$[n-m-nn_n],
#  rus$дивизия$[n-f-nn_n],
#  rus$диплом$[n-m-nn_n],
#  rus$дипломат$[n-m-aa_n-m_n],
#  rus$диск$[n-m-nn_n],
#  rus$длина$[n-f-nn_n_n-f],
#  rus$дневник$[n-m-nn_n_n-m],
#  rus$дно$[n-nt-nn_n],
#  rus$добро$[n-nt-nn_n],
#  rus$доверие$[n-nt-nn_n_n-nt],
#  rus$договор$[n-m-nn_n_n-m],
#  rus$дождь$[n-m-nn_n_n-m],
#  rus$доза$[n-f-nn_n],
#  rus$док$[n-m-nn_n],
#  rus$доказательство$[n-nt-nn_n_n-nt],
#  rus$доклад$[n-m-nn_n_n-m],
#  rus$доктор$[n-m-aa_n],
#  rus$документ$[n-m-nn_n-m_n],
#  rus$долг$[n-m-nn_n_n-m],
#  rus$язык$[n-m-nn_n_n-m],
#  rus$долина$[n-f-nn_n],
#  rus$доллар$[n-m-nn_n-m_n],
#  rus$дом$[n-m-nn_n_n-m],
#  rus$домик$[n-m-nn_n],
#  rus$дон$[n-m-aa_n-m],
#  rus$дорога$[n-f-nn_n_n-f],
#  rus$достоинство$[n-nt-nn_n],
#  rus$доход$[n-m-nn_n],
#  rus$дочь$[n-f-aa_n],
#  rus$дракон$[n-m-aa_n],
#  rus$дровосек$[n-m-aa_n],
#  rus$дрожь$[n-f-nn_n],
#  rus$друг$[n-m-aa_n_n-m],
#  rus$дружба$[n-f-nn_n_n-f],
#  rus$дуб$[n-m-nn_n],
#  rus$дух$[n-m-nn_n_n-m],
#  rus$душа$[n-f-nn_n],
#  rus$дым$[n-m-nn_n_n-m],
#  rus$дыра$[n-f-nn_n],
#  rus$дырка$[n-f-nn_n],
#  rus$дыхание$[n-nt-nn_n_n-nt],
#  rus$дьявол$[n-m-aa_n],
#  rus$дядя$[n-m-aa_n],
#  rus$еврей$[n-m-aa_n],
#  rus$еда$[n-f-nn_n],
#  rus$единица$[n-f-nn_n_n-f],
#  rus$жар$[n-m-nn_n],
#  rus$желание$[n-nt-nn_n],
#  rus$железо$[n-nt-nn_n],
#  rus$желудок$[n-m-nn_n_n-m],
#  rus$жена$[n-f-aa_n],
#  rus$жених$[n-m-aa_n],
#  rus$женщина$[n-f-aa_n_n-f],
#  rus$жертва$[n-f-aa_n],
#  rus$жест$[n-m-nn_n],
#  rus$живопись$[n-f-nn_n],
#  rus$живот$[n-m-nn_n],
#  rus$жидкость$[n-f-nn_n_n-f],
#  rus$жизнь$[n-f-nn_n-f_n],
#  rus$жир$[n-m-nn_n],
#  rus$журнал$[n-m-nn_n_n-m],
#  rus$журналист$[n-m-aa_n_n-m],
#  rus$забор$[n-m-nn_n],
#  rus$забота$[n-f-nn_n],
#  rus$зависть$[n-f-nn_n],
#  rus$завод$[n-m-nn_n],
#  rus$завтрак$[n-m-nn_n_n-m],
#  rus$загадка$[n-f-nn_n],
#  rus$заговор$[n-m-nn_n_n-m],
#  rus$задача$[n-f-nn_n_n-f],
#  rus$закат$[n-m-nn_n],
#  rus$закон$[n-m-nn_n-m_n],
#  rus$зал$[n-m-nn_n],
#  rus$заместитель$[n-m-aa_n_n-m],
#  rus$заметка$[n-f-nn_n],
#  rus$замок$[n-m-nn_n],
#  rus$занавеска$[n-f-nn_n],
#  rus$запад$[n-m-nn_n_n-m],
#  rus$запах$[n-m-nn_n],
#  rus$зарплата$[n-f-nn_n],
#  rus$заря$[n-f-nn_n],
#  rus$затылок$[n-m-nn_n],
#  rus$защита$[n-f-nn_n_n-f],
#  rus$заяц$[n-m-aa_n],
#  rus$звезда$[n-f-nn_n_n-f],
#  rus$зверь$[n-m-aa_n],
#  rus$звук$[n-m-nn_n],
#  rus$здание$[n-nt-nn_n_n-nt],
#  rus$здоровье$[n-nt-nn_n_n-nt],
#  rus$зелень$[n-f-nn_n],
#  rus$земля$[n-f-nn_n_n-f],
#  rus$зеркало$[n-nt-nn_n],
#  rus$зима$[n-f-nn_n],
#  rus$зло$[n-nt-nn_n],
#  rus$змей$[n-m-aa_n],
#  rus$змея$[n-f-aa_n_n-f],
#  rus$знак$[n-m-nn_n_n-m],
#  rus$знамя$[n-nt-nn_n],
#  rus$знание$[n-nt-nn_n_n-nt],
#  rus$значение$[n-nt-nn_n],
#  rus$золото$[n-nt-nn_n_n-nt],
#  rus$зона$[n-f-nn_n_n-f],
#  rus$зрение$[n-nt-nn_n],
#  rus$игра$[n-f-nn_n_n-f],
#  rus$игрушка$[n-f-nn_n],
#  rus$идеал$[n-m-nn_n],
#  rus$идеология$[n-f-nn_n],
#  rus$идея$[n-f-nn_n-f_n],
#  rus$идиот$[n-m-aa_n],
#  rus$изба$[n-f-nn_n],
#  rus$икона$[n-f-nn_n],
#  rus$император$[n-m-aa_n_n-m],
#  rus$империя$[n-f-nn_n_n-f],
#  rus$имущество$[n-nt-nn_n],
#  rus$имя$[n-nt-nn_n_n-nt],
#  rus$инвалид$[n-m-aa_n],
#  rus$инженер$[n-m-aa_n_n-m],
#  rus$иностранец$[n-m-aa_n],
#  rus$инстинкт$[n-m-nn_n],
#  rus$институт$[n-m-nn_n_n-m],
#  rus$инструкция$[n-f-nn_n_n-f],
#  rus$инструмент$[n-m-nn_n],
#  rus$интеллигент$[n-m-aa_n],
#  rus$интеллигенция$[n-f-nn_n-f],
#  rus$интервью$[n-nt-aa_n-nt_n],
#  rus$интерес$[n-m-nn_n-m_n],
#  rus$информация$[n-f-nn_n-f_n],
#  rus$исключение$[n-nt-nn_n],
#  rus$искра$[n-f-nn_n],
#  rus$искусство$[n-nt-nn_n_n-nt],
#  rus$исследование$[n-nt-nn_n-nt],
#  rus$истина$[n-f-nn_n_n-f],
#  rus$история$[n-f-nn_n_n-f],
#  rus$источник$[n-m-nn_n-m_n],
#  rus$исход$[n-m-nn_n],
#  rus$итог$[n-m-nn_n],
#  rus$июль$[n-m-nn_n-m_n],
#  rus$июнь$[n-m-nn_n-m_n],
#  rus$кабинет$[n-m-nn_n],
#  rus$каблук$[n-m-nn_n],
#  rus$казарма$[n-f-nn_n],
#  rus$камень$[n-m-nn_n_n-m],
#  rus$камера$[n-f-nn_n],
#  rus$кампания$[n-f-nn_n-f_n],
#  rus$канал$[n-m-nn_n_n-m],
#  rus$кандидат$[n-m-aa_n-m_n],
#  rus$капитал$[n-m-nn_n_n-m],
#  rus$капитан$[n-m-aa_n],
#  rus$капля$[n-f-nn_n],
#  rus$капуста$[n-f-nn_n],
#  rus$карандаш$[n-m-nn_n],
#  rus$карман$[n-m-nn_n],
#  rus$карта$[n-f-nn_n_n-f_n-f-nn-pl],
#  rus$картина$[n-f-nn_n_n-f],
#  rus$карьера$[n-f-nn_n],
#  rus$катастрофа$[n-f-nn_n],
#  rus$категория$[n-f-nn_n],
#  rus$катер$[n-m-nn_n],
#  rus$кафе$[n-nt-nn_n],
#  rus$качество$[n-nt-nn_n_n-nt],
#  rus$каша$[n-f-nn_n],
#  rus$квартал$[n-m-nn_n],
#  rus$квартира$[n-f-nn_n_n-f],
#  rus$килограмм$[n-m-nn_n_n-m],
#  rus$километр$[n-m-nn_n_n-m],
#  rus$кино$[n-nt-nn_n],
#  rus$кирпич$[n-m-nn_n],
#  rus$кислота$[n-f-nn_n],
#  rus$кладбище$[n-nt-nn_n-nt-nn-sg_n],
#  rus$класс$[n-m-nn_n],
#  rus$клетка$[n-f-nn_n_n-f],
#  rus$клиент$[n-m-aa_n],
#  rus$кличка$[n-f-nn_n],
#  rus$клуб$[n-m-nn_n],
#  rus$ключ$[n-m-nn_n],
#  rus$книга$[n-f-nn_n_n-f],
#  rus$кнопка$[n-f-nn_n],
#  rus$князь$[n-m-aa_n],
#  rus$кодекс$[n-m-nn_n_n-m],
#  rus$кожа$[n-f-nn_n_n-f],
#  rus$коза$[n-f-aa_n],
#  rus$кол$[n-m-nn_n],
#  rus$колбаса$[n-f-nn_n],
#  rus$колдун$[n-m-aa_n],
#  rus$колесо$[n-nt-nn_n],
#  rus$количество$[n-nt-nn_n],
#  rus$коллектив$[n-m-nn_n],
#  rus$коллекция$[n-f-nn_n],
#  rus$колодец$[n-m-nn_n],
#  rus$колонна$[n-f-nn_n],
#  rus$колхоз$[n-m-nn_n],
#  rus$команда$[n-f-nn_n_n-f],
#  rus$комар$[n-m-aa_n],
#  rus$комиссия$[n-f-nn_n_n-f],
#  rus$комитет$[n-m-nn_n_n-m],
#  rus$коммунизм$[n-m-nn_n_n-m],
#  rus$комната$[n-f-nn_n],
#  rus$компания$[n-f-nn_n_n-f],
#  rus$комплекс$[n-m-nn_n],
#  rus$компьютер$[n-m-nn_n_n-m],
#  rus$конверт$[n-m-nn_n],
#  rus$контакт$[n-m-nn_n],
#  rus$контракт$[n-m-nn_n_n-m],
#  rus$контроль$[n-m-nn_n],
#  rus$конференция$[n-f-nn_n-f_n],
#  rus$конфета$[n-f-nn_n],
#  rus$концерт$[n-m-nn_n_n-m],
#  rus$коньяк$[n-m-nn_n],
#  rus$копия$[n-f-nn_n],
#  rus$копыто$[n-nt-nn_n],
#  rus$корабль$[n-m-nn_n],
#  rus$корень$[n-m-nn_n_n-m],
#  rus$король$[n-m-aa_n-m],
#  rus$корпорация$[n-f-nn_n-f],
#  rus$корпус$[n-m-nn_n-m],
#  rus$кость$[n-f-nn_n-f],
#  rus$кофе$[n-nt_n-nt-nn],
#  rus$край$[n-m-nn_n-m],
#  rus$кредит$[n-m-nn_n-m],
#  rus$крепость$[n-f-nn_n-f],
#  rus$кризис$[n-m-nn_n-m],
#  rus$критика$[n-f-nn_n-f],
#  rus$кровь$[n-f-nn_n-f],
#  rus$круг$[n-m-nn_n-m],
#  rus$крыло$[n-nt-nn_n-nt],
#  rus$культура$[n-f-nn_n-f],
#  rus$куча$[n-f-nn_n-f],
#  rus$лаборатория$[n-f-nn_n_n-f],
#  rus$лагерь$[n-m-nn_n_n-m],
#  rus$лампа$[n-f-nn_n],
#  rus$лев$[n-m-aa_n_n-m],
#  rus$легенда$[n-f-nn_n],
#  rus$лейтенант$[n-m-aa_n],
#  rus$лекарство$[n-nt-nn_n_n-nt],
#  rus$лента$[n-f-nn_n],
#  rus$лес$[n-m-nn_n_n-m],
#  rus$лестница$[n-f-nn_n],
#  rus$лето$[n-nt-nn_n_n-nt],
#  rus$лечение$[n-nt-nn_n],
#  rus$лидер$[n-m-aa_n_n-m],
#  rus$линия$[n-f-nn_n],
#  rus$лист$[n-m-nn_n_n-m],
#  rus$листва$[n-f-nn_n],
#  rus$литература$[n-f-nn_n_n-f],
#  rus$лифт$[n-m-nn_n],
#  rus$лицо$[n-nt-nn_n_n-nt],
#  rus$лицо$[nt_n-nt-aa],
#  rus$личность$[n-f-nn_n_n-f],
#  rus$лоб$[n-m-nn_n_n-m],
#  rus$лодка$[n-f-nn_n],
#  rus$ложь$[n-f-nn_n],
#  rus$лозунг$[n-m-nn_n],
#  rus$лопата$[n-f-nn_n],
#  rus$лошадь$[n-f-aa_n],
#  rus$луг$[n-m-nn_n],
#  rus$лужа$[n-f-nn_n],
#  rus$луна$[n-f-nn_n-f_n],
#  rus$любитель$[n-m-aa_n],
#  rus$любовь$[n-f-nn_n],
#  rus$маг$[n-m-aa_n],
#  rus$май$[n-m-nn_n-m-nn-sg_n_n-m],
#  rus$майка$[n-f-nn_n],
#  rus$майор$[n-m-aa_n_n-m],
#  rus$мак$[n-m-nn_n],
#  rus$малыш$[n-m-aa_n],
#  rus$мальчик$[n-m-aa_n],
#  rus$мама$[n-f-aa_n],
#  rus$марка$[n-f-nn_n],
#  rus$март$[n-m-nn_n-m_n],
#  rus$марш$[n-m-nn_n],
#  rus$маршал$[n-m-aa_n],
#  rus$маска$[n-f-nn_n],
#  rus$масло$[n-nt-nn_n],
#  rus$масса$[n-f-nn_n_n-f],
#  rus$мастер$[n-m-aa_n],
#  rus$масштаб$[n-m-nn_n],
#  rus$материал$[n-m-nn_n],
#  rus$материя$[n-f-nn_n],
#  rus$матрос$[n-m-aa_n],
#  rus$матч$[n-m-nn_n],
#  rus$мать$[n-f-aa_n],
#  rus$машина$[n-f-nn_n],
#  rus$мебель$[n-f-nn_n],
#  rus$медаль$[n-f-nn_n],
#  rus$медведь$[n-m-aa_n],
#  rus$медицина$[n-f-nn_n_n-f],
#  rus$мелодия$[n-f-nn_n],
#  rus$мера$[n-f-nn_n],
#  rus$место$[n-nt-nn_n_n-nt],
#  rus$месяц$[n-m-nn_n-m_n],
#  rus$металл$[n-m-nn_n],
#  rus$метод$[n-m-nn_n_n-m],
#  rus$метр$[n-m-nn_n_n-m],
#  rus$метро$[n-nt-aa_n],
#  rus$механизм$[n-m-nn_n],
#  rus$меч$[n-m-nn_n_n-m],
#  rus$мечта$[n-f-nn_n-f-nn-sg_n],
#  rus$миг$[n-m-nn_n],
#  rus$милиция$[n-f-nn_n_n-f],
#  rus$мина$[n-f-nn_n_n-f],
#  rus$министерство$[n-nt-nn_n_n-nt],
#  rus$министр$[n-m-aa_n-m_n],
#  rus$минута$[n-f-nn_n_n-f],
#  rus$мир$[n-m-nn_n_n-m],
#  rus$миска$[n-f-nn_n],
#  rus$митинг$[n-m-nn_n_n-m],
#  rus$младенец$[n-m-aa_n],
#  rus$множество$[n-nt-nn_n_n-nt],
#  rus$могила$[n-f-nn_n],
#  rus$мода$[n-f-nn_n],
#  rus$мозг$[n-m-nn_n],
#  rus$молитва$[n-f-nn_n],
#  rus$молния$[n-f-nn_n],
#  rus$молодость$[n-f-nn_n],
#  rus$молоко$[n-nt-nn_n],
#  rus$момент$[n-m-nn_n_n-m],
#  rus$монастырь$[n-m-nn_n_n-m],
#  rus$монах$[n-m-aa_n],
#  rus$монета$[n-f-nn_n],
#  rus$мораль$[n-f-nn_n],
#  rus$морда$[n-f-nn_n],
#  rus$море$[n-nt-nn_n_n-nt],
#  rus$мороз$[n-m-nn_n],
#  rus$моряк$[n-m-aa_n],
#  rus$мост$[n-m-nn_n_n-m],
#  rus$мотив$[n-m-nn_n],
#  rus$мотор$[n-m-nn_n],
#  rus$мотоцикл$[n-m-nn_n],
#  rus$мудрость$[n-f-nn_n_n-f],
#  rus$муж$[n-m-aa_n],
#  rus$мужчина$[n-m-aa_n-m_n],
#  rus$музей$[n-m-nn_n_n-m],
#  rus$музыка$[n-f-nn_n_n-f],
#  rus$музыкант$[n-m-aa_n],
#  rus$мука$[n-f-nn_n],
#  rus$мундир$[n-m-nn_n],
#  rus$мусор$[n-m-nn_n_n-m-nn-sg],
#  rus$муха$[n-f-aa_n],
#  rus$мыло$[n-nt-nn_n],
#  rus$мысль$[n-f-nn_n],
#  rus$мышца$[n-f-nn_n],
#  rus$мышь$[n-f-aa_n],
#  rus$мэр$[n-m-aa_n_n-m],
#  rus$мясо$[n-nt-nn_n_n-nt],
#  rus$мяч$[n-m-nn_n],
#  rus$наблюдение$[n-nt-nn_n],
#  rus$награда$[n-f-nn_n],
#  rus$надежда$[n-f-nn_n-f_n],
#  rus$наказание$[n-nt-nn_n],
#  rus$налог$[n-m-nn_n-m_n],
#  rus$напряжение$[n-nt-nn_n],
#  rus$народ$[n-m-nn_n_n-m],
#  rus$население$[n-nt-nn_n-nt_n],
#  rus$наслаждение$[n-nt-nn_n],
#  rus$настроение$[n-nt-nn_n],
#  rus$наступление$[n-nt-nn_n_n-nt],
#  rus$наука$[n-f-nn_n_n-f],
#  rus$национальность$[n-f-nn_n],
#  rus$нация$[n-f-nn_n_n-f],
#  rus$начальство$[n-nt-nn_n],
#  rus$небо$[n-nt-nn_n_n-nt],
#  rus$невеста$[n-f-aa_n],
#  rus$невроз$[n-m-nn_n],
#  rus$негр$[n-m-aa_n],
#  rus$неделя$[n-f-nn_n-f_n],
#  rus$немец$[n-m-aa_n],
#  rus$ненависть$[n-f-nn_n_n-f],
#  rus$необходимость$[n-f-nn_n_n-f],
#  rus$нерв$[n-m-nn_n],
#  rus$неудача$[n-f-nn_n],
#  rus$нефть$[n-f-nn_n_n-f],
#  rus$новость$[n-f-nn_n-f_n],
#  rus$нога$[n-f-nn_n_n-f],
#  rus$ноготь$[n-m-nn_n_n-m],
#  rus$нож$[n-m-nn_n],
#  rus$номенклатура$[n-f-nn_n],
#  rus$норма$[n-f-nn_n],
#  rus$нос$[n-m-nn_n_n-m],
#  rus$носок$[n-m-nn_n],
#  rus$ночь$[n-f-nn_n_n-f],
#  rus$ноябрь$[n-m-nn_n-m_n],
#  rus$нужда$[n-f-nn_n],
#  rus$обвинение$[n-nt-nn_n_n-nt],
#  rus$обед$[n-m-nn_n],
#  rus$обезьяна$[n-f-aa_n],
#  rus$облако$[n-nt-nn_n_n-nt],
#  rus$оболочка$[n-f-nn_n],
#  rus$оборона$[n-f-nn_n-f_n],
#  rus$образ$[n-m-nn_n],
#  rus$образование$[n-nt-nn_n_n-nt],
#  rus$обстоятельство$[n-nt-nn_n],
#  rus$обувь$[n-f-nn_n],
#  rus$общение$[n-nt-nn_n_n-nt],
#  rus$общество$[n-nt-nn_n_n-nt],
#  rus$объект$[n-m-nn_n_n-m],
#  rus$овраг$[n-m-nn_n],
#  rus$овца$[n-f-aa_n],
#  rus$огонь$[n-m-nn_n-m_n],
#  rus$огород$[n-m-nn_n],
#  rus$огурец$[n-m-nn_n],
#  rus$одежда$[n-f-nn_n],
#  rus$одеяло$[n-nt-nn_n],
#  rus$одиночество$[n-nt-nn_n],
#  rus$озеро$[n-nt-nn_n_n-nt],
#  rus$океан$[n-m-nn_n_n-m],
#  rus$окно$[n-nt-nn_n],
#  rus$окончание$[n-nt-nn_n],
#  rus$окружение$[n-nt-nn_n],
#  rus$октябрь$[n-m-nn_n-m_n],
#  rus$окурок$[n-m-nn_n],
#  rus$олень$[n-m-aa_n_n-m],
#  rus$опасность$[n-f-nn_n],
#  rus$операция$[n-f-nn_n],
#  rus$орган$[n-m-nn_n_n-m],
#  rus$организация$[n-f-nn_n_n-f],
#  rus$организм$[n-m-nn_n],
#  rus$орех$[n-m-nn_n],
#  rus$оркестр$[n-m-nn_n],
#  rus$оружие$[n-nt-nn_n_n-nt],
#  rus$осень$[n-f-nn_n_n-f],
#  rus$особенность$[n-f-nn_n],
#  rus$остров$[n-m-nn_n-m_n],
#  rus$ось$[n-f-nn_n],
#  rus$ответ$[n-m-nn_n_n-m],
#  rus$ответственность$[n-f-nn_n_n-f],
#  rus$отдел$[n-m-nn_n],
#  rus$отделение$[n-nt-nn_n],
#  rus$отдых$[n-m-nn_n],
#  rus$отель$[n-m-nn_n],
#  rus$отец$[n-m-aa_n],
#  rus$открытие$[n-nt-nn_n-nt],
#  rus$отношение$[n-nt-nn_n_n-nt],
#  rus$отражение$[n-nt-nn_n],
#  rus$отряд$[n-m-nn_n],
#  rus$оттенок$[n-m-nn_n],
#  rus$офис$[n-m-nn_n],
#  rus$офицер$[n-m-aa_n_n-m],
#  rus$официант$[n-m-aa_n],
#  rus$охота$[n-f-nn_n],
#  rus$охрана$[n-f-nn_n],
#  rus$охранник$[n-m-aa_n],
#  rus$оценка$[n-f-nn_n_n-f],
#  rus$очередь$[n-f-nn_n],
#  rus$ошибка$[n-f-nn_n],
#  rus$ощущение$[n-nt-nn_n],
#  rus$падаль$[n-f-nn_n_n-f],
#  rus$падение$[n-nt-nn_n],
#  rus$пазуха$[n-f-nn_n],
#  rus$пакет$[n-m-nn_n_n-m],
#  rus$палатка$[n-f-nn_n],
#  rus$палец$[n-m-nn_n],
#  rus$палуба$[n-m-nn_n],
#  rus$пальто$[n-nt-aa_n],
#  rus$памятник$[n-m-nn_n],
#  rus$память$[n-f-nn_n],
#  rus$пан$[n-m-aa_n],
#  rus$паника$[n-f-nn_n],
#  rus$папка$[n-f-nn_n],
#  rus$пара$[n-f-nn_n_n-f],
#  rus$парк$[n-m-nn_n_n-m],
#  rus$парламент$[n-m-nn_n-m_n],
#  rus$паровоз$[n-m-nn_n],
#  rus$пароход$[n-m-nn_n],
#  rus$партия$[n-f-nn_n-f_n],
#  rus$партнер$[n-m-aa_n-m],
#  rus$паспорт$[n-m-nn_n_n-m],
#  rus$пассажир$[n-m-aa_n],
#  rus$пастух$[n-m-aa_n],
#  rus$патрон$[n_n-m-aa],
#  rus$пауза$[n-f-nn_n],
#  rus$пациент$[n-m-aa_n],
#  rus$пейзаж$[n-m-nn_n],
#  rus$пена$[n-f-nn_n],
#  rus$пенсия$[n-f-nn_n_n-f],
#  rus$пепел$[n-m-nn_n],
#  rus$перевод$[n-m-nn_n],
#  rus$переводчик$[n-m-aa_n],
#  rus$передача$[n-f-nn_n],
#  rus$перец$[n-m-nn_n],
#  rus$период$[n-m-nn_n_n-m],
#  rus$перо$[n-nt-nn_n_n-nt],
#  rus$перспектива$[n-f-nn_n-f_n],
#  rus$перчатка$[n-f-nn_n],
#  rus$песня$[n-f-nn_n_n-f],
#  rus$песок$[n-m-nn_n_n-m],
#  rus$петля$[n-f-nn_n],
#  rus$петух$[n-m-aa_n],
#  rus$пехота$[n-f-nn_n],
#  rus$печаль$[n-f-nn_n],
#  rus$печать$[n-f-nn_n],
#  rus$печень$[n-f-nn_n],
#  rus$печь$[n_n-f-aa],
#  rus$пещера$[n-f-nn_n],
#  rus$пиво$[n-nt-nn_n_n-nt],
#  rus$пиджак$[n-m-nn_n],
#  rus$пила$[n-f-nn_n],
#  rus$пилот$[n-m-aa_n],
#  rus$пионер$[n-m-aa_n],
#  rus$писатель$[n-m-aa_n_n-m],
#  rus$пистолет$[n-m-nn_n],
#  rus$письмо$[n-nt-nn_n_n-nt],
#  rus$пища$[n-f-nn_n_n-f],
#  rus$пламя$[n-nt-nn_n-nt-nn-sg_n],
#  rus$план$[n-m-nn_n_n-m],
#  rus$планета$[n-f-nn_n],
#  rus$платформа$[n-f-nn_n-f],
#  rus$платье$[n-nt-nn_n],
#  rus$плач$[n-m-nn_n],
#  rus$плащ$[n-m-nn_n],
#  rus$племя$[n-nt-nn_n],
#  rus$плод$[n-m-nn_n_n-m],
#  rus$площадь$[n-f-nn_n_n-f],
#  rus$пляж$[n-m-nn_n],
#  rus$победа$[n-f-nn_n-f_n],
#  rus$повар$[n-m-aa_n],
#  rus$поведение$[n-nt-nn_n_n-nt],
#  rus$поверхность$[n-f-nn_n],
#  rus$погода$[n-f-nn_n],
#  rus$погон$[n-m-nn_n],
#  rus$подарок$[n-m-nn_n],
#  rus$подбородок$[n-m-nn_n],
#  rus$подвал$[n-m-nn_n],
#  rus$подпись$[n-f-nn_n],
#  rus$подполковник$[n-m-aa_n_n-m],
#  rus$подросток$[n-m-aa_n],
#  rus$подруга$[n-f-aa_n_n-f],
#  rus$подушка$[n-f-nn_n],
#  rus$подъезд$[n-m-nn_n],
#  rus$поезд$[n-m-nn_n_n-m],
#  rus$пожар$[n-m-nn_n],
#  rus$поза$[n-f-nn_n],
#  rus$позор$[n-m-nn_n],
#  rus$поколение$[n-nt-nn_n],
#  rus$покупатель$[n-m-aa_n],
#  rus$пол$[n-m-nn_n_n-m],
#  rus$полдень$[n-m-nn_n],
#  rus$поле$[n-nt-nn_n_n-nt_n-nt-nn-pl],
#  rus$политик$[n-m-aa_n-m_n],
#  rus$политика$[n-f-nn_n-f_n],
#  rus$полиция$[n-f-nn_n-f_n],
#  rus$полк$[n-m-nn_n],
#  rus$полковник$[n-m-aa_n_n-m],
#  rus$полоса$[n-f-nn_n],
#  rus$полотенце$[n-nt-nn_n],
#  rus$понедельник$[n-m-nn_n-m_n],
#  rus$понимание$[n-nt-nn_n],
#  rus$понятие$[n-nt-nn_n],
#  rus$поп$[n-m-nn_n],
#  rus$порошок$[n-m-nn_n],
#  rus$порт$[n-m-nn_n],
#  rus$портрет$[n-m-nn_n],
#  rus$портфель$[n-m-nn_n],
#  rus$порыв$[n-m-nn_n],
#  rus$порядок$[n-m-nn_n_n-m],
#  rus$посол$[n-m-aa_n-m_n],
#  rus$посольство$[n-nt-nn_n-nt_n],
#  rus$пост$[n-m-nn_n_n-m],
#  rus$посуда$[n-f-nn_n],
#  rus$пот$[n-m-nn_n],
#  rus$поток$[n-m-nn_n],
#  rus$потолок$[n-m-nn_n],
#  rus$потомок$[n-m-aa_n_n-m-aa-pl],
#  rus$потребность$[n-f-nn_n],
#  rus$поцелуй$[n-m-nn_n],
#  rus$почва$[n-f-nn_n],
#  rus$почерк$[n-m-nn_n],
#  rus$почта$[n-f-nn_n],
#  rus$поэзия$[n-f-nn_n],
#  rus$поэт$[n-m-aa_n],
#  rus$пояс$[n-m-nn_n],
#  rus$правда$[n-f-nn_n],
#  rus$правительство$[n-nt-nn_n-nt_n],
#  rus$право$[n-nt-nn_n],
#  rus$праздник$[n-m-nn_n_n-m],
#  rus$практика$[n-f-nn_n],
#  rus$предел$[n-m-nn_n],
#  rus$предок$[n-m-aa_n],
#  rus$предположение$[n-nt-nn_n],
#  rus$предприятие$[n-nt-nn_n_n-nt],
#  rus$представление$[n-nt-nn_n],
#  rus$предчувствие$[n-nt-nn_n-nt],
#  rus$президент$[n-m-aa_n-m_n],
#  rus$презрение$[n-nt-nn_n],
#  rus$премия$[n-f-nn_n_n-f],
#  rus$премьер$[n-m-aa_n-m],
#  rus$преподаватель$[n-m-aa_n],
#  rus$преступление$[n-nt-nn_n-nt_n],
#  rus$прибыль$[n-f-nn_n],
#  rus$привычка$[n-f-nn_n],
#  rus$приговор$[n-m-nn_n],
#  rus$признание$[n-nt-nn_n],
#  rus$приключение$[n-nt-nn_n],
#  rus$принц$[n-m-aa_n],
#  rus$принцесса$[n-f-aa_n],
#  rus$принцип$[n-m-nn_n_n-m],
#  rus$природа$[n-f-nn_n_n-f],
#  rus$приход$[n-m-nn_n],
#  rus$причина$[n-f-nn_n_n-f],
#  rus$приятель$[n-m-aa_n],
#  rus$пробка$[n-f-nn_n],
#  rus$проблема$[n-f-nn_n_n-f],
#  rus$провинция$[n-f-nn_n-f_n],
#  rus$провод$[n-m-nn_n],
#  rus$проводник$[n-m-aa_n],
#  rus$проволока$[n-f-nn_n],
#  rus$прогноз$[n-m-nn_n],
#  rus$программа$[n-f-nn_n-f_n],
#  rus$прогресс$[n-m-nn_n],
#  rus$продавец$[n-m-aa_n],
#  rus$продажа$[n-f-nn_n_n-f],
#  rus$продукт$[n-m-nn_n_n-m],
#  rus$проект$[n-m-nn_n-m_n],
#  rus$проза$[n-f-nn_n],
#  rus$произведение$[n-nt-nn_n],
#  rus$производство$[n-nt-nn_n_n-nt],
#  rus$прокуратура$[n-f-nn_n-f],
#  rus$прокурор$[n-m-aa_n-m_n],
#  rus$промышленность$[n-f-nn_n-f_n],
#  rus$пропаганда$[n-f-nn_n],
#  rus$проспект$[n-m-nn_n],
#  rus$простыня$[n-f-nn_n],
#  rus$протест$[n-m-nn_n-m_n],
#  rus$противоречие$[n-nt-nn_n],
#  rus$протокол$[n-m-nn_n_n-m],
#  rus$профессия$[n-f-nn_n],
#  rus$профессор$[n-m-aa_n_n-m],
#  rus$процедура$[n-f-nn_n_n-f],
#  rus$процент$[n-m-nn_n_n-m],
#  rus$процесс$[n-m-nn_n_n-m],
#  rus$птица$[n-f-aa_n_n-f],
#  rus$публика$[n-f-nn_n_n-f],
#  rus$пуговица$[n-f-nn_n],
#  rus$пузырь$[n-m-nn_n],
#  rus$пуля$[n-f-nn_n_n-f],
#  rus$пустота$[n-f-nn_n],
#  rus$пустыня$[n-f-nn_n],
#  rus$путешествие$[n-nt-nn_n],
#  rus$путь$[n-m-nn_n_n-m],
#  rus$пыль$[n-f-nn_n],
#  rus$пьеса$[n-f-nn_n],
#  rus$пятница$[n-f-nn_n_n-f],
#  rus$раб$[n-m-aa_n],
#  rus$работа$[n-f-nn_n_n-f],
#  rus$работник$[n-m-aa_n],
#  rus$равновесие$[n-nt-nn_n],
#  rus$разведка$[n-f-nn_n-f],
#  rus$разведчик$[n-m-aa_n],
#  rus$развитие$[n-nt-nn_n_n-nt],
#  rus$разговор$[n-m-nn_n_n-m],
#  rus$размер$[n-m-nn_n_n-m],
#  rus$разница$[n-f-nn_n],
#  rus$разрешение$[n-nt-nn_n],
#  rus$разум$[n-m-nn_n],
#  rus$рай$[n-m-nn_n],
#  rus$район$[n-m-nn_n-m_n],
#  rus$ракета$[n-f-nn_n_n-f],
#  rus$рама$[n-f-nn_n],
#  rus$рана$[n-f-nn_n],
#  rus$ранг$[n-m-nn_n],
#  rus$рассвет$[n-m-nn_n-m],
#  rus$рассказ$[n-m-nn_n],
#  rus$расстояние$[n-nt-nn_n],
#  rus$раствор$[n-m-nn_n],
#  rus$растение$[n-nt-nn_n],
#  rus$реакция$[n-f-nn_n],
#  rus$реальность$[n-f-nn_n_n-f],
#  rus$ребро$[n-nt-nn_n],
#  rus$революция$[n-f-nn_n_n-f],
#  rus$регион$[n-m-nn_n_n-m],
#  rus$редактор$[n-m-aa_n_n-m],
#  rus$результат$[n-m-nn_n_n-m],
#  rus$река$[n-f-nn_n_n-f],
#  rus$реклама$[n-f-nn_n],
#  rus$религия$[n-f-nn_n_n-f],
#  rus$рельс$[n-m-nn_n],
#  rus$ремень$[n-m-nn_n],
#  rus$республика$[n-f-nn_n-f_n],
#  rus$ресторан$[n-m-nn_n_n-m],
#  rus$реформа$[n-f-nn_n-f],
#  rus$речь$[n-f-nn_n],
#  rus$рис$[n-m-nn_n],
#  rus$риск$[n-m-nn_n-m],
#  rus$рисунок$[n-m-nn_n],
#  rus$ритм$[n-m-nn_n],
#  rus$рог$[n-m-nn_n_n-m],
#  rus$род$[n-m-nn_n_n-m],
#  rus$родина$[n-f-nn_n],
#  rus$родитель$[n-m-aa_n_n-m-aa-pl],
#  rus$роза$[n-f-nn_n],
#  rus$роль$[n-f-nn_n_n-f],
#  rus$роман$[n-m-nn_n_n-m],
#  rus$роса$[n-f-nn_n],
#  rus$рост$[n-m-nn_n],
#  rus$рот$[n-m-nn_n-m-nn-pl_n],
#  rus$рота$[n-f-nn_n],
#  rus$рубаха$[n-f-nn_n],
#  rus$рубашка$[n-f-nn_n],
#  rus$рубль$[n-m-nn_n],
#  rus$рука$[n-f-nn_n],
#  rus$рукав$[n-m-nn_n],
#  rus$руководство$[n-nt-nn_n_n-nt],
#  rus$русский$[adj_adj-sint],
#  rus$русский$[n-m-aa_n],
#  rus$ручей$[n-m-nn_n],
#  rus$ручка$[n-f-nn_n],
#  rus$рыба$[n-f-aa_n_n-f],
#  rus$рыбак$[n-m-aa_n],
#  rus$рынок$[n-m-nn_n_n-m],
#  rus$рыцарь$[n-m-aa_n],
#  rus$рюкзак$[n-m-nn_n],
#  rus$рюмка$[n-f-nn_n],
#  rus$ряд$[n-m-nn_n],
#  rus$сад$[n-m-nn_n],
#  rus$сало$[n-nt-nn_n],
#  rus$салон$[n-m-nn_n],
#  rus$самоубийство$[n-nt-nn_n],
#  ...]

# %%
l1.list
# Out:
# [rus$$[_num_num-digit-mfn-pl-nom],
#  rus$prpers$[prn-p1-mf_prn-pers-p1-mf],
#  rus$prpers$[prn-p2-mf_prn-pers-p2-mf],
#  rus$prpers$[prn-pers-p3-mf-pl_prn_prn-pers],
#  rus$Алексей$[np-ant-m_np-ant-m-aa],
#  rus$Аллах$[n-m-aa_n],
#  rus$Бек$[np-ant-m_np-ant-m-aa],
#  rus$Ваш$[det-pos-m-sg_det-pos-m-sg-nom],
#  rus$Водолей$[n_n-m-aa],
#  rus$Возрождение$[n_n-nt-nn],
#  rus$Вы$[prn-pers-p2-mf-pl_prn-pers-p2-mf-pl-gen],
#  rus$Гаутама$[n_n-f-aa],
#  rus$Давид$[np-ant-m_np-ant-m-aa],
#  rus$Дева$[n_n-f-aa],
#  rus$Дина$[np-ant-f_np-ant-f-sg],
#  rus$Дэвид$[np-ant-m_np-ant-m-aa],
#  rus$Евгений$[np-ant-m_np-ant-m-aa],
#  rus$Запад$[n_n-m-nn],
#  rus$Земля$[n_n-f-nn],
#  rus$Карл$[np-ant-m_np-ant-m-aa],
#  rus$Кузнецов$[np-cog_np-cog-m],
#  rus$Ленин$[np-cog_np-cog-m],
#  rus$Ломоносов$[np-cog_np-cog-m],
#  rus$Марк$[np-ant-m_np-ant-m-aa],
#  rus$Менделеев$[np-cog_np-cog-m],
#  rus$Мухаммед$[np-ant-m_np-ant-m-aa],
#  rus$Назарбаев$[np-cog_np-cog-m],
#  rus$ООН$[np-org-f_np-org],
#  rus$Овен$[n_n-m-nn],
#  rus$РСФСР$[np-top-f_np-top-f-sg],
#  rus$РФ$[np-top-f_np-top-f-sg],
#  rus$Реформация$[n_n-f-nn],
#  rus$Ричард$[np-ant-m_np-ant-m-aa],
#  rus$СМИ$[n_n-nt],
#  rus$СПИД$[n_n-m],
#  rus$СССР$[np-top-m_np-top-m-sg],
#  rus$США$[np-top-pl_np-top-mfn-pl-nom],
#  rus$Фердинанд$[np-ant-m_np-ant-m-aa],
#  rus$Эдвард$[np-ant-m-aa_np-ant-m],
#  rus$Юрий$[np-ant-m_np-ant-m-aa],
#  rus$Яковлев$[np-cog_np-cog-m],
#  rus$абака$[n-f-nn_n],
#  rus$аббат$[n-m-aa_n],
#  rus$аббатиса$[n-f-aa_n],
#  rus$аббатство$[n_n-nt-nn],
#  rus$аббревиатура$[n-f-nn_n],
#  rus$абдикация$[n-f-nn_n-f],
#  rus$аберрация$[n-f-nn_n],
#  rus$абзац$[n-m-nn_n],
#  rus$аболиционизм$[n-m-nn_n-m],
#  rus$абонемент$[n-m-nn_n],
#  rus$абориген$[n_n-m-aa],
#  rus$аборт$[n-m-nn_n-m_n],
#  rus$абракадабра$[n-f-nn_n],
#  rus$абрикос$[n-m-nn_n],
#  rus$абрис$[n-m-nn_n],
#  rus$абсент$[n-m-nn_n],
#  rus$абсолютизм$[n-m-nn_n_n-m],
#  rus$абсолютный$[adj-sint_adj],
#  rus$абсорбция$[n-f-nn_n-f],
#  rus$абстиненция$[n_n-f-nn],
#  rus$абстрактный$[adj-sint_adj],
#  rus$абстракция$[n-f-nn_n-f],
#  rus$абсурдный$[adj-sint_adj],
#  rus$абсцесс$[n-m-nn_n],
#  rus$абсцисса$[n_n-f-nn],
#  rus$авангард$[n-m-nn_n],
#  rus$авантюрин$[n-m-nn_n],
#  rus$авантюрист$[n-m-aa_n],
#  rus$авар$[n_n-m-aa],
#  rus$авария$[n-f-nn_n_n-f],
#  rus$авгур$[n_n-m-aa],
#  rus$август$[n-m-nn_n-m_n],
#  rus$авеню$[n-f-nn_n],
#  rus$авиакомпания$[n-f-nn_n-f],
#  rus$авиатор$[n-m-aa_n],
#  rus$авиация$[n-f-nn_n-f_n],
#  rus$авоська$[n_n-f-nn],
#  rus$австралопитек$[n_n-m-aa],
#  rus$австрийский$[adj_adj-sint],
#  rus$автаркия$[n-f-nn_n],
#  rus$автобиография$[n-f-nn_n],
#  rus$автобус$[n-m-nn_n_n-m],
#  rus$автовесы$[n-m-nn_n-m-nn-pl],
#  rus$автограф$[n-m-nn_n],
#  rus$автожир$[n-m-nn_n],
#  rus$автомагистраль$[n-f-nn_n-f],
#  rus$автомат$[n-m-nn_n],
#  rus$автоматизация$[n-f-nn_n],
#  rus$автоматический$[adj_adj-sint],
#  rus$автомобилист$[n_n-m-aa],
#  rus$автомобиль$[n-m-nn_n_n-m],
#  rus$автоморфизм$[n-m-nn_n],
#  rus$автономия$[n-f-nn_n_n-f],
#  rus$автономность$[n_n-f-nn],
#  rus$автономный$[adj-sint_adj],
#  rus$автоответчик$[n_n-m-nn],
#  rus$автор$[n-m-aa_n_n-m],
#  rus$авторитет$[n-m-nn_n],
#  rus$авторский$[adj_adj-sint],
#  rus$авторучка$[n-f-nn_n],
#  rus$автосани$[n-m-nn_n-m-nn-pl],
#  rus$автострада$[n-f-nn_n],
#  rus$автошкола$[n_n-f-nn],
#  rus$агава$[n-f-nn_n],
#  rus$агар-агар$[n_n-m-nn],
#  rus$агат$[n-m-nn_n],
#  rus$агент$[n-m-aa_n],
#  rus$агентство$[n-nt-nn_n_n-nt],
#  rus$агломерат$[n-m-nn_n],
#  rus$агностицизм$[n-m-nn_n],
#  rus$агония$[n-f-nn_n],
#  rus$агорафобия$[n-f-nn_n],
#  rus$аграрный$[adj-sint_adj],
#  rus$агрессивность$[n-f-nn_n],
#  rus$агрессивный$[adj-sint_adj],
#  rus$агрессия$[n-f-nn_n],
#  rus$агроном$[n-m-aa_n],
#  rus$агрономия$[n-f-nn_n],
#  rus$агротехнический$[adj_adj-sint],
#  rus$ад$[n-m-nn_n-m-nn-sg_n],
#  rus$адаптация$[n-f-nn_n-f],
#  rus$адаптер$[n-m-nn_n],
#  rus$адаптивный$[adj_adj-sint],
#  rus$адвокат$[n-m-aa_n_n-m],
#  rus$адгезия$[n-f-nn_n],
#  rus$адекватный$[adj-sint_adj],
#  rus$адепт$[n-m-aa_n],
#  rus$административный$[adj-sint_adj],
#  rus$администрация$[n-f-nn_n_n-f],
#  rus$адмирал$[n-m-aa_n_n-m],
#  rus$адмиралтейство$[n-nt-nn_n],
#  rus$адреналин$[n-m-nn_n-m],
#  rus$адрес$[n-m-nn_n],
#  rus$адресант$[n-m-aa_n],
#  rus$адресат$[n-m-aa_n],
#  rus$адъюнкт$[n_n-m-aa],
#  rus$адъютант$[n_n-m-aa],
#  rus$адюльтер$[n-m-nn_n],
#  rus$азалия$[n-f-nn_n],
#  rus$азарт$[n-m-nn_n],
#  rus$азартный$[adj-sint_adj],
#  rus$азбука$[n-f-nn_n],
#  rus$азербайджанец$[n_n-m-aa],
#  rus$азербайджанка$[n_n-f-aa],
#  rus$азербайджанский$[adj_adj-m],
#  rus$азиат$[n_n-m-aa],
#  rus$азиатский$[adj_adj-sint],
#  rus$азимут$[n-m-nn_n],
#  rus$азот$[n-m-nn_n],
#  rus$аист$[n-m-aa_n],
#  rus$айва$[n_n-f-nn-sg_n-f-nn],
#  rus$айлант$[n-m-nn_n],
#  rus$айсберг$[n_n-m-nn],
#  rus$академик$[n-m-aa_n],
#  rus$академический$[adj_adj-sint],
#  rus$академия$[n-f-nn_n_n-f],
#  rus$акант$[n-m-nn_n],
#  rus$акафист$[n_n-m-nn],
#  rus$акация$[n-f-nn_n],
#  rus$акварель$[n-f-nn_n],
#  rus$аквариум$[n-m-nn_n],
#  rus$акватинта$[n_n-f-nn],
#  rus$акведук$[n_n-m-nn],
#  rus$аккомпаниатор$[n_n-m-aa],
#  rus$аккорд$[n-f-aa_n],
#  rus$аккордеон$[n_n-m-nn],
#  rus$аккредитив$[n-m-nn_n],
#  rus$аккумулятор$[n-m-nn_n],
#  rus$аккуратный$[adj-sint_adj],
#  rus$аконит$[n-m-nn_n],
#  rus$акр$[n-m-nn_n],
#  rus$акробат$[n_n-m-aa],
#  rus$акробатика$[n-f-nn_n],
#  rus$акробатический$[adj_adj-sint],
#  rus$акрополь$[n-m-nn_n_n-m],
#  rus$акростих$[n_n-m-nn],
#  rus$акселератор$[n-m-nn_n],
#  rus$аксиома$[n-f-nn_n_n-f],
#  rus$акт$[n-m-nn_n],
#  rus$актерский$[adj_adj-sint],
#  rus$актив$[n-m-nn_n],
#  rus$активный$[adj-sint_adj],
#  rus$актиний$[n_n-m-nn],
#  rus$актиния$[n_n-f-aa],
#  rus$актуальный$[adj-sint_adj],
#  rus$актёр$[n-m-aa_n_n-m],
#  rus$акула$[n-f-aa_n_n-f],
#  rus$акупунктура$[n_n-f-nn],
#  rus$акустика$[n-f-nn_n],
#  rus$акустический$[adj_adj-sint],
#  rus$акушерка$[n_n-f-aa],
#  rus$акушерство$[n-nt_n-nt-nn],
#  rus$акцент$[n-m-nn_n],
#  rus$акцепт$[n-m-nn_n],
#  rus$акциденция$[n-f-nn_n],
#  rus$акциз$[n-m-nn_n_n-m],
#  rus$акционер$[n-m-aa_n],
#  rus$акция$[n-f-nn_n-f_n],
#  rus$албанец$[n-m-aa_n-m],
#  rus$албанский$[adj_adj-sint],
#  rus$алгебра$[n-f-nn_n],
#  rus$алгоритм$[n-m-nn_n],
#  rus$алебарда$[n-f-nn_n],
#  rus$алебастр$[n-m-nn_n],
#  rus$алеут$[n_n-m-aa],
#  rus$алиби$[n_n-nt-nn],
#  rus$алименты$[n_n-m-nn],
#  rus$алкалоид$[n-m-nn_n],
#  rus$алкоголизм$[n-m-nn_n_n-m],
#  rus$алкоголик$[n-m-aa_n-m],
#  rus$алкоголь$[n-m-nn_n_n-m],
#  rus$аллегорический$[adj_adj-m],
#  rus$аллегория$[n-f-nn_n_n-f],
#  rus$аллергия$[n-f-nn_n_n-f],
#  rus$аллея$[n-f-nn_n],
#  rus$аллигатор$[n-m-aa_n],
#  rus$аллитерация$[n-f-nn_n],
#  rus$аллопатия$[n_n-f-nn],
#  rus$аллювий$[n-m-nn_n],
#  rus$алмаз$[n-m-nn_n],
#  rus$алопеция$[n_n-f-nn],
#  rus$алоэ$[n-nt-nn_n],
#  rus$алтарь$[n-m-nn_n],
#  rus$алфавит$[n-m-nn_n_n-m],
#  rus$алхимик$[n-m-aa_n],
#  rus$алхимия$[n-f-nn_n],
#  rus$алчность$[n-f-nn_n_n-f],
#  rus$алый$[adj-sint_adj],
#  rus$алыча$[n-f-nn_n],
#  rus$альбатрос$[n-m-aa_n],
#  rus$альбинос$[n-m-aa_n],
#  rus$альбом$[n-m-nn_n],
#  rus$альбумин$[n-m-nn_n-m],
#  rus$альбуминурия$[n_n-f-nn],
#  rus$альвеола$[n_n-f_n-f-nn],
#  rus$альдегид$[n-m-nn_n_n-m],
#  rus$альков$[n-m-nn_n],
#  rus$альманах$[n-m-nn_n],
#  rus$альпеншток$[n_n-m-nn],
#  rus$альпинизм$[n-m-nn_n],
#  rus$альпинист$[n-m-aa_n],
#  rus$альт$[n_n-m-nn],
#  rus$альтернатива$[n-f-nn_n],
#  rus$альтернативный$[adj_adj-sint],
#  rus$альтернатор$[n-m-nn_n],
#  rus$альтруизм$[n-m-nn_n],
#  rus$альтруист$[n-m-aa_n],
#  rus$альфа$[n-f-nn_n],
#  rus$альфа-лучи$[n-m-nn-pl_n-m-nn],
#  rus$альянс$[n-m-nn_n_n-m],
#  rus$алюминий$[n-m-nn_n],
#  rus$амазонка$[n-f-nn_n],
#  rus$амальгама$[n-f-nn_n],
#  rus$амарант$[n-m-nn_n],
#  rus$амариллис$[n_n-m-nn],
#  rus$амбар$[n-m-nn_n],
#  rus$амбициозный$[adj-sint_adj],
#  rus$амбиция$[n-f-nn_n_n-f],
#  rus$амбра$[n-f-nn_n],
#  rus$амбразура$[n-f-nn_n],
#  rus$амброзия$[n-f-nn_n_n-f],
#  rus$американец$[n-m-aa_n],
#  rus$американский$[adj_adj-sint],
#  rus$америций$[n-m-nn_n],
#  rus$аметист$[n-m-nn_n],
#  rus$аммиак$[n-m-nn_n],
#  rus$аммонит$[n_n-m-nn],
#  rus$амнезия$[n-f-nn_n],
#  rus$амнистия$[n-f-nn_n_n-f],
#  rus$амортизатор$[n-m-nn_n],
#  rus$амортизация$[n-f-nn_n-f],
#  rus$ампер$[n-m-nn_n],
#  rus$амперметр$[n-m-nn_n_n-m],
#  rus$ампир$[n-m-nn_n],
#  rus$амплитуда$[n-f-nn_n],
#  rus$ампула$[n-f-nn_n],
#  rus$амулет$[n-m-nn_n],
#  rus$амуниция$[n-f-nn_n],
#  rus$амфибрахий$[n_n-m-nn],
#  rus$амфитеатр$[n-m-nn_n],
#  rus$амфора$[n-f-nn_n],
#  rus$анаграмма$[n-f-nn_n],
#  rus$анализ$[n-m-nn_n_n-m],
#  rus$анализатор$[n-m-nn_n],
#  rus$анализировать$[vblex-impf-tv_vblex-impf],
#  rus$анализироваться$[vblex-impf_vblex-impf-iv],
#  rus$аналитический$[adj_adj-sint],
#  rus$аналогичный$[adj-sint_adj],
#  rus$аналогия$[n-f-nn_n],
#  rus$аналой$[n_n-m-nn],
#  rus$ананас$[n-m-nn_n],
#  rus$анапест$[n-m-nn_n],
#  rus$анархизм$[n-m-nn_n_n-m],
#  rus$анархист$[n_n-m-aa],
#  rus$анархический$[adj_adj-sint],
#  rus$анархия$[n-f-nn_n_n-f],
#  rus$анатомия$[n-f-nn_n_n-f],
#  rus$анафема$[n-f-nn_n_n-f],
#  rus$анахронизм$[n-m-nn_n],
#  rus$ангажемент$[n-m-nn_n-m],
#  rus$ангар$[n-m-nn_n],
#  rus$ангел$[n-m-aa_n],
#  rus$ангина$[n-f-nn_n],
#  rus$английский$[adj_adj-sint],
#  rus$англичанин$[n-m-aa_n],
#  rus$англосакс$[n_n-m-aa],
#  rus$анекдот$[n-m-nn_n],
#  rus$анемия$[n-f-nn_n_n-f],
#  rus$анемометр$[n-m-nn_n],
#  rus$анемона$[n_n-f-nn],
#  rus$анестезия$[n-f-nn_n_n-f],
#  rus$анилин$[n-m-nn_n],
#  rus$анимация$[n-f-nn_n],
#  rus$анис$[n-m-nn_n],
#  rus$анкета$[n-f-nn_n],
#  rus$анкилоз$[n_n-m-nn],
#  rus$аннигиляция$[n-f-nn_n],
#  rus$анод$[n-m-nn_n],
#  rus$аномалия$[n-f-nn_n],
#  rus$анонимность$[n-f-nn_n],
#  rus$анонимный$[adj-sint_adj],
#  rus$ансамбль$[n-m-nn_n],
#  rus$антаблемент$[n_n-m-nn],
#  rus$антагонизм$[n-m-nn_n],
#  rus$антагонист$[n-m-aa_n_n-m],
#  rus$антенна$[n-f-nn_n],
#  rus$антибиотик$[n-m-nn_n_n-m],
#  rus$антиквар$[n_n-m-aa],
#  rus$антиквариат$[n_n-m-nn],
#  rus$антилогарифм$[n_n-m-nn],
#  rus$антилопа$[n-f-aa_n],
#  rus$антиномия$[n-f-nn_n],
#  rus$антипапа$[n_n-m-aa],
#  rus$антипатия$[n-f-nn_n],
#  rus$антипирин$[n_n-m-nn],
#  rus$антипротон$[n_n-m-nn],
#  rus$антисемит$[n-m-aa_n],
#  rus$антисемитизм$[n-m-nn_n],
#  rus$антисептика$[n_n-f-nn],
#  rus$антитеза$[n-f-nn_n_n-f],
#  rus$антитезис$[n-m-nn_n],
#  rus$антифон$[n-m-nn_n],
#  rus$антихрист$[n_n-m-aa],
#  rus$античастица$[n-f-nn_n],
#  rus$античность$[n_n-f-nn],
#  rus$антология$[n-f-nn_n],
#  rus$антоним$[n-m-nn_n],
#  rus$антракт$[n-m-nn_n],
#  rus$антрацит$[n-m-nn_n],
#  rus$антресоль$[n_n-f-nn],
#  rus$антрополог$[n-m-aa_n],
#  rus$антропологический$[adj_adj-sint],
#  rus$антропология$[n-f-nn_n],
#  rus$антропометрия$[n_n-f-nn],
#  rus$антропоморфизм$[n-m-nn_n],
#  rus$анус$[n_n-m-nn],
#  rus$анчоус$[n-m-nn_n],
#  rus$аорта$[n-f-nn_n_n-f],
#  rus$апатит$[n-m-nn_n],
#  rus$апатия$[n-f-nn_n],
#  rus$апельсин$[n-m-nn_n],
#  rus$аперитив$[n-m-nn_n],
#  rus$апланат$[n_n-m-nn],
#  rus$апломб$[n-m-nn_n],
#  rus$апогей$[n-m-nn_n],
#  rus$апокалипсис$[n-m-nn_n],
#  rus$апокопа$[n-f-nn_n],
#  rus$апокриф$[n-m-nn_n],
#  rus$аполог$[n_n-m-nn],
#  rus$апология$[n-f-nn_n],
#  rus$апоплексия$[n-f-nn_n],
#  rus$апостол$[n-m-nn_n],
#  rus$апостроф$[n-m-nn_n],
#  rus$апофема$[n_n-f-nn],
#  rus$апофеоз$[n-m-nn_n],
#  rus$аппарат$[n-m-nn_n],
#  rus$аппаратура$[n-f-nn_n],
#  rus$аппендикс$[n-m-nn_n],
#  rus$аппендицит$[n-m-nn_n],
#  rus$аппетит$[n-m-nn_n],
#  rus$аппликата$[n_n-f-nn],
#  rus$аппозиция$[n-f-nn_n],
#  rus$аппретура$[n_n-f-nn],
#  rus$апрель$[n-m-nn_n-m_n],
#  rus$апсида$[n-f-nn_n],
#  rus$аптека$[n-f-nn_n],
#  rus$ар$[n-m-nn_n],
#  rus$араб$[n-m-aa_n],
#  rus$арабеска$[n-f-nn_n],
#  rus$арак$[n-m-nn_n],
#  rus$араукария$[n-f-nn_n],
#  rus$арахис$[n-m-nn_n],
#  rus$арбалет$[n-m-nn_n],
#  rus$арбитр$[n_n-m-aa],
#  rus$арбитраж$[n-m-nn_n_n-m],
#  rus$арбуз$[n-m-nn_n],
#  rus$арго$[n-nt-nn_n],
#  rus$аргон$[n-m-nn_n],
#  rus$арготизм$[n-m-nn_n],
#  rus$аргумент$[n-m-nn_n],
#  rus$ареал$[n-m-nn_n],
#  rus$арена$[n-f-nn_n],
#  rus$аренда$[n-f-nn_n],
#  rus$арендатор$[n-m-aa_n],
#  rus$ареометр$[n-m-nn_n],
#  rus$ареопаг$[n_n-m-nn],
#  rus$арест$[n-m-nn_n-m_n],
#  rus$арестант$[n_n-m-aa],
#  rus$арестантская$[n_n-f-nn],
#  rus$арестованный$[n_n-m-aa],
#  rus$арестовать$[vblex-perf-tv_vblex-perf],
#  rus$аристократ$[n-m-aa_n_n-m],
#  rus$аристократический$[adj_adj-sint],
#  rus$аристократия$[n-f-nn_n_n-f],
#  rus$арифметика$[n-f-nn_n],
#  rus$ария$[n-f-nn_n],
#  rus$арка$[n-f-nn_n],
#  rus$аркада$[n-f-nn_n],
#  rus$арктический$[adj_adj-sint],
#  rus$арлекин$[n_n-m-aa],
#  rus$арматура$[n-f-nn_n],
#  rus$армия$[n-f-nn_n-f_n],
#  rus$арника$[n-f-nn_n],
#  rus$аромат$[n-m-nn_n],
#  rus$арсенал$[n-m-nn_n],
#  rus$артериальное давление$[n_n-nt-nn],
#  rus$артерия$[n-f-nn_n],
#  rus$артефакт$[n-m-nn_n],
#  rus$артикль$[n-m-nn_n],
#  rus$артикул$[n_n-m-nn],
#  rus$артикуляция$[n-f-nn_n],
#  rus$артиллерист$[n-m-aa_n],
#  rus$артиллерия$[n-f-nn_n],
#  rus$артист$[n-m-aa_n],
#  rus$артистический$[adj_adj-m],
#  rus$артишок$[n_n-m-nn],
#  rus$артрит$[n_n-m-nn],
#  rus$арфа$[n-f-nn_n],
#  rus$архаизм$[n-m-nn_n_n-m],
#  rus$архангел$[n_n-m-aa],
#  rus$археолог$[n_n-m-aa],
#  rus$археологический$[adj_adj-sint],
#  rus$археология$[n-f-nn_n],
#  rus$археоптерикс$[n-m-aa_n],
#  rus$архив$[n-m-nn_n_n-m],
#  rus$архивариус$[n_n-m-aa],
#  rus$архивист$[n_n-m-aa],
#  rus$архивный$[adj-sint_adj],
#  rus$архиепископ$[n-m-aa_n],
#  rus$архиерей$[n-m-aa_n],
#  rus$архимандрит$[n_n-m-an],
#  rus$архипелаг$[n-m-nn_n],
#  rus$архитектор$[n-m-aa_n],
#  rus$архитектура$[n-f-nn_n_n-f],
#  rus$архитрав$[n-m-nn_n],
#  rus$аршин$[n-m-nn_n],
#  rus$арьергард$[n_n-m-nn],
#  rus$ас$[n-m-aa_n_n-m],
#  rus$асбест$[n-m-nn_n],
#  rus$асессор$[n_n-m-aa],
#  rus$асимметрический$[adj_adj-sint],
#  rus$асимптота$[n-f-nn_n],
#  rus$аскарида$[n_n-f-aa],
#  rus$аскеза$[n_n-f-nn],
#  rus$аскет$[n_n-m-aa],
#  rus$аскетизм$[n-m-nn_n],
#  rus$аскетический$[adj_adj-m],
#  rus$аспарагус$[n-m-nn_n],
#  rus$аспид$[n_n-m-nn],
#  rus$аспирин$[n-m-nn_n],
#  rus$ассамблея$[n-f-nn_n],
#  rus$ассемблер$[n-m-nn_n],
#  rus$ассимиляция$[n-f-nn_n-f],
#  rus$ассириец$[n_n-m-aa],
#  rus$ассистент$[n-m-aa_n],
#  rus$ассонанс$[n-m-nn_n],
#  rus$ассортимент$[n-m-nn_n],
#  rus$ассоциативность$[n_n-f-nn],
#  rus$ассоциация$[n-f-nn_n_n-f],
#  rus$астения$[n-f-nn_n],
#  rus$астероид$[n-m-nn_n],
#  rus$астигматизм$[n-m-nn_n],
#  rus$астма$[n-f-nn_n_n-f],
#  rus$астра$[n-f-nn_n],
#  rus$астрагал$[n-m-nn_n],
#  rus$астролог$[n-m-aa_n],
#  rus$астрология$[n-f-nn_n],
#  rus$астролябия$[n-f-nn_n],
#  rus$астронавт$[n-m-aa_n],
#  rus$астроном$[n-m-aa_n],
#  rus$астрономический$[adj_adj-sint],
#  rus$астрономия$[n-f-nn_n],
#  rus$асфальт$[n-m-nn_n],
#  rus$асфиксия$[n-f-nn_n],
#  rus$атавизм$[n-m-nn_n],
#  rus$атаксия$[n-f-nn_n],
#  rus$атаман$[n_n-m-aa],
#  rus$атеизм$[n-m-nn_n_n-m],
#  rus$атеист$[n-m-aa_n],
#  rus$атлант$[n_n-m-aa],
#  rus$атлас$[n-m-nn_n],
#  rus$атлет$[n-m-aa_n],
#  rus$атлетизм$[n-m-nn_n],
#  rus$атлетика$[n-f-nn_n],
#  rus$атмосфера$[n-f-nn_n_n-f],
#  rus$атолл$[n-m-nn_n_n-m],
#  rus$атом$[n-m-nn_n_n-m],
#  rus$атомизм$[n-m-nn_n],
#  rus$атомный$[adj-sint_adj],
#  rus$атония$[n-f-nn_n],
#  rus$атрибут$[n-m-nn_n],
#  rus$атропин$[n-m-nn_n],
#  rus$атрофия$[n-f-nn_n],
#  rus$атташе$[n_n-m-aa],
#  rus$аттестат$[n-m-nn_n],
#  rus$аттракцион$[n-m-nn_n],
#  rus$аудиенция$[n-f-nn_n_n-f],
#  rus$аудитория$[n-f-nn_n],
#  rus$аукцион$[n-m-nn_n],
#  rus$аура$[n-f-nn_n],
#  rus$аутентичность$[n_n-f-nn],
#  rus$афазия$[n-f-nn_n],
#  rus$афелий$[n-m-nn_n],
#  rus$афиша$[n-f-nn_n],
#  rus$афония$[n-f-nn_n],
#  rus$афоризм$[n-m-nn_n],
#  rus$африканец$[n-m-aa_n],
#  rus$аффект$[n-m-nn_n],
#  rus$аффикс$[n-m-nn_n],
#  rus$аффриката$[n_n-f-nn],
#  rus$ахнуть$[vblex-perf-tv_vblex-perf],
#  rus$ацетат$[n-m-nn_n],
#  rus$ацетил$[n_n-m-nn],
#  rus$ацетилен$[n-m-nn_n],
#  rus$ацетон$[n-m-nn_n],
#  rus$аэробика$[n-f-nn_n-f],
#  rus$аэродром$[n-m-nn_n],
#  rus$аэролит$[n_n-m-nn],
#  rus$аэрометр$[n_n-m-nn],
#  rus$аэронавт$[n_n-m-aa],
#  rus$аэронавтика$[n_n-f-nn],
#  rus$аэроплан$[n-m-nn_n],
#  rus$аэропорт$[n-m-nn_n-m_n],
#  rus$аэростат$[n-m-nn_n],
#  rus$аэрофлот$[n-m-nn_n],
#  rus$бабаханье$[n_n-nt-nn],
#  rus$бабочка$[n-f-aa_n_n-f],
#  rus$бабушка$[n-f-aa_n],
#  rus$баварец$[n_n-m-aa],
#  rus$багаж$[n_n-m-nn],
#  rus$багор$[n-m-nn_n],
#  rus$багровый$[adj-sint_adj],
#  rus$бадминтон$[n-m-nn_n],
#  rus$бадья$[n-f-nn_n],
#  rus$бадьян$[n-m-nn_n],
#  rus$база$[n-f-nn_n],
#  rus$базальт$[n-m-nn_n],
#  rus$базар$[n-m-nn_n],
#  rus$базилик$[n-m-nn_n-m],
#  rus$базилика$[n-f-nn_n],
#  rus$базис$[n-m-nn_n],
#  rus$байдарка$[n_n-f-nn],
#  rus$байт$[n_n-m-nn],
#  rus$бак$[n-m-nn_n],
#  rus$бакалавр$[n-m-aa_n],
#  rus$бакборт$[n_n-m-nn],
#  rus$бакелит$[n-m-nn_n],
#  rus$бакен$[n_n-m-nn],
#  rus$баклажан$[n-m-nn_n_n-m],
#  rus$баклан$[n-m-aa_n],
#  rus$бактериологический$[adj_adj-sint],
#  rus$бактерия$[n-f-nn_n_n-f],
#  rus$бал$[n-m-nn_n_n-m],
#  rus$баланс$[n_n-m-nn],
#  rus$балахон$[n_n-m-nn],
#  rus$балдахин$[n-m-nn_n],
#  rus$балерина$[n-f-aa_n],
#  rus$балет$[n-m-nn_n],
#  rus$балка$[n_n-f-nn],
#  rus$балкон$[n-m-nn_n],
#  rus$балл$[n-m-nn_n],
#  rus$баллада$[n-f-nn_n],
#  rus$балласт$[n-m-nn_n],
#  rus$баллиста$[n_n-f-nn],
#  rus$баллистика$[n-f-nn_n],
#  rus$баллон$[n-m-nn_n],
#  rus$балтийский$[adj_adj-sint],
#  rus$бальзам$[n-m-nn_n],
#  rus$бальзамин$[n-m-nn_n],
#  rus$бальзамировщик$[n_n-m-aa],
#  rus$балюстрада$[n_n-f-nn],
#  rus$балясина$[n-f-nn_n],
#  rus$бамбук$[n-m-nn_n],
#  rus$банальный$[adj_adj-sint],
#  rus$банан$[n-m-nn_n],
#  rus$банда$[n-f-nn_n_n-f],
#  rus$бандаж$[n-m-nn_n],
#  rus$бандероль$[n-f-nn_n],
#  rus$бандит$[n-m-aa_n],
#  rus$банк$[n-m-nn_n_n-m],
#  rus$банка$[n_n-f-nn],
#  rus$банкет$[n_n-m-nn],
#  rus$банкир$[n-m-aa_n],
#  rus$банкнот$[n-m-nn_n],
#  rus$банкротство$[n-nt-nn_n],
#  rus$бант$[n-m-nn_n],
#  rus$баня$[n-f-nn_n_n-f],
#  rus$баобаб$[n-m-nn_n],
#  rus$барабан$[n-m-nn_n_n-m],
#  rus$барак$[n-m-nn_n],
#  rus$баран$[n-m-aa_n],
#  rus$баранка$[n_n-f-nn],
#  rus$барахолка$[n-f-nn_n],
#  rus$барбарис$[n-m-nn_n],
#  rus$барвинок$[n_n-m-nn],
#  rus$бард$[n_n-m-aa],
#  rus$барда$[n_n-f-nn],
#  rus$барельеф$[n-m-nn_n],
#  rus$баржа$[n-f-nn_n],
#  rus$барий$[n-m-nn_n],
#  rus$барит$[n-m-nn_n],
#  rus$баритон$[n-m-nn_n],
#  rus$барка$[n-f-nn_n],
#  rus$баркарола$[n-f-nn_n],
#  rus$баркас$[n_n-m-nn],
#  rus$барограф$[n-m-nn_n],
#  rus$барокко$[n-nt-nn_n],
#  rus$барометр$[n-m-nn_n],
#  rus$барон$[n-m-aa_n],
#  rus$бароскоп$[n-m-nn_n],
#  rus$баррикада$[n-f-nn_n],
#  rus$барс$[n_n-m-aa],
#  rus$барсук$[n-m-aa_n],
#  rus$бархан$[n-m-nn_n],
#  rus$бархат$[n-m-nn_n],
#  rus$барщина$[n_n-f-nn],
#  rus$барышня$[n-f-aa_n],
#  rus$барьер$[n-m-nn_n],
#  rus$бас$[n-m-aa_n_n-m],
#  rus$баск$[n_n-m-aa],
#  rus$басня$[n-f-nn_n_n-f],
#  rus$басон$[n-m-nn_n],
#  rus$басонщик$[n_n-m-aa],
#  rus$бассейн$[n-m-nn_n],
#  rus$бастион$[n-m-nn_n],
#  rus$батальон$[n-m-nn_n_n-m],
#  rus$батарейка$[n-f-nn_n],
#  rus$батарея$[n-f-nn_n],
#  rus$батат$[n_n-m-nn],
#  rus$батист$[n-m-nn_n],
#  rus$батрак$[n-m-aa_n],
#  rus$батюшка$[n-m-aa_n],
#  rus$бахвал$[n_n-m-aa],
#  rus$бахвальство$[n_n-nt-nn],
#  rus$бахрома$[n-f-nn-sg_n_n-f-nn],
#  rus$бацилла$[n_n-f-nn],
#  rus$башкирский$[adj_adj-m-an-sg-nom],
#  rus$башлык$[n-m-nn_n],
#  rus$башмак$[n-m-nn_n],
#  rus$башня$[n-f-nn_n],
#  rus$баядерка$[n-f-aa_n],
#  rus$баян$[n-m-nn_n],
#  rus$беатификация$[n_n-f-nn],
#  rus$бег$[n-m-nn_n-m-nn-sg_n],
#  rus$бегать$[vblex-impf-iv_vblex-impf],
#  rus$бегемот$[n-m-aa_n],
#  rus$бегония$[n-f-nn_n],
#  rus$бегство$[n-nt-nn_n],
#  rus$бедность$[n-f-nn_n_n-f],
#  rus$беднота$[n-f-nn-sg_n-f-nn],
#  rus$бедный$[adj-sint_adj],
#  rus$бедняк$[n-m-aa_n],
#  rus$бедро$[n-nt-nn_n],
#  rus$бедствие$[n-nt-nn_n],
#  rus$бедуин$[n-m-aa_n],
#  rus$бежать$[vblex-impf_vblex-impf-iv],
#  rus$беженец$[n-m-aa_n],
#  rus$безбрачие$[n-nt-nn_n],
#  rus$безвкусица$[n-f-nn_n],
#  rus$бездарность$[n-f-nn_n],
#  rus$бездействие$[n-nt-nn_n],
#  rus$безделица$[n-f-nn_n],
#  rus$безделушка$[n-f-nn_n],
#  rus$бездельник$[n-m-aa_n],
#  rus$бездна$[n-f-nn_n],
#  rus$бездомный$[adj-sint_adj],
#  rus$безе$[n_n-nt-nn],
#  rus$безжалостность$[n_n-f-nn],
#  rus$безжизненность$[n-f-nn_n],
#  rus$безмятежность$[n_n-f-nn],
#  rus$безнадежный$[adj_adj-sint],
#  rus$безопасность$[n-f-nn_n-f],
#  rus$безопасный$[adj-sint_adj],
#  rus$безработица$[n-f-nn_n_n-f],
#  rus$безработный$[adj-sint_adj],
#  rus$безразличие$[n-nt-nn_n],
#  rus$безрукий$[adj_adj-sint],
#  rus$безумный$[adj-sint_adj],
#  rus$безухий$[adj_adj-sint],
#  rus$бекар$[n-m-nn_n],
#  rus$бекас$[n_n-m-aa],
#  rus$белена$[n_n-f-nn],
#  rus$белиберда$[n-f-nn_n],
#  rus$белизна$[n-f-nn_n],
#  rus$белка$[n_n-m-aa],
#  rus$беллетристика$[n-f-nn_n],
#  rus$белодушка$[n-f-aa_n-f],
#  rus$белок$[n-m-nn_n],
#  rus$белокровие$[n-nt-nn_n],
#  rus$белорусский$[adj_adj-m],
#  rus$белуга$[n-f-aa_n],
#  rus$белый$[adj_adj-sint],
#  rus$бельведер$[n_n-m-nn],
#  rus$бельгиец$[n-m-aa_n],
#  rus$бельё$[n_n-nt-nn],
#  rus$бемоль$[n_n-m-nn],
#  rus$бенефис$[n-m-nn_n],
#  rus$бензин$[n-m-nn_n],
#  rus$бензобак$[n_n-m-nn],
#  rus$бензозаправка$[n-f-nn_n],
#  rus$бензол$[n-m-nn_n],
#  rus$бергамот$[n-m-nn_n],
#  rus$бердыш$[n-m-nn_n],
#  rus$берег$[n-m-nn_n],
#  rus$беременная$[n_n-f-aa],
#  rus$беременность$[n-f-nn_n_n-f],
#  rus$бересклет$[n-m-nn_n],
#  rus$берет$[n-m-nn_n],
#  rus$беречь$[vblex-impf_vblex-impf-tv],
#  rus$берилл$[n-m-nn_n],
#  rus$бериллий$[n-m-nn_n],
#  rus$берлога$[n-f-nn_n],
#  rus$берёза$[n-f-nn_n],
#  rus$бес$[n-m-aa_n],
#  rus$беседа$[n-f-nn_n],
#  rus$беседка$[n-f-nn_n],
#  rus$бесконечность$[n-f-nn_n_n-f],
#  rus$бесконечный$[adj-sint_adj],
#  rus$беспамятство$[n_n-nt-nn],
#  rus$беспартийность$[n_n-f-nn],
#  rus$бесплатный$[adj-sint_adj],
#  rus$беспокоить$[vblex-impf-tv_vblex-impf],
#  rus$беспокоиться$[vblex-impf_vblex-impf-iv],
#  rus$беспокойство$[n-nt-nn_n],
#  rus$беспомощный$[adj-sint_adj],
#  rus$беспорядок$[n-m-nn_n],
#  rus$беспрепятственный$[adj-sint_adj],
#  rus$беспристрастный$[adj-sint_adj],
#  rus$бессвязность$[n-f-nn_n],
#  rus$бесславие$[n-nt-nn_n],
#  rus$бессмертие$[n-nt-nn_n-nt],
#  rus$бессмертник$[n_n-m-nn],
#  rus$бессмертный$[adj-sint_adj],
#  rus$бессмысленный$[adj-sint_adj],
#  rus$бессмыслица$[n-f-nn_n],
#  rus$бессонница$[n-f-nn_n],
#  rus$бесспорный$[adj_adj-sint],
#  rus$бестолковость$[n-f-nn_n],
#  rus$бестолочь$[n_n-f-aa],
#  rus$бесцеремонность$[n-f-nn_n],
#  rus$бетель$[n_n-m-nn],
#  rus$бетон$[n-m-nn_n],
#  rus$бетонный$[adj-sint_adj],
#  rus$бешенство$[n-nt-nn_n],
#  rus$бешеный$[adj-sint_adj],
#  rus$библиограф$[n_n-m-aa],
#  rus$библиография$[n-f-nn_n],
#  rus$библиотека$[n-f-nn_n],
#  rus$библия$[n-f-nn_n_n-f],
#  rus$бивак$[n_n-m-nn],
#  rus$бивень$[n_n-m-nn],
#  rus$биде$[n_n-nt-nn],
#  rus$биение$[n-nt-nn_n],
#  rus$бизнес$[n-m-nn_n_n-m],
#  rus$бизнесмен$[n-m-aa_n],
#  rus$бизон$[n-m-aa_n],
#  rus$билет$[n-m-nn_n],
#  rus$бильярд$[n-m-nn_n],
#  rus$бильярдная$[n_n-f-nn],
#  rus$биметаллизм$[n-m-nn_n],
#  rus$бимс$[n_n-m-nn],
#  rus$бинокль$[n-m-nn_n],
#  rus$бином$[n-m-nn_n],
#  rus$бинт$[n-m-nn_n],
#  rus$биограф$[n-m-aa_n],
#  rus$биография$[n-f-nn_n],
#  rus$биолог$[n_n-m_n-m-aa],
#  rus$биологический$[adj_adj-sint],
#  rus$биология$[n-f-nn_n_n-f],
#  rus$бионика$[n-f-nn_n-f],
#  rus$биохимия$[n-f-nn_n_n-f],
#  rus$биплан$[n_n-m-nn],
#  rus$биржа$[n-f-nn_n_n-f],
#  rus$бирюза$[n_n-f-nn],
#  rus$бирюк$[n-m-aa_n],
#  rus$бисер$[n_n-m-nn],
#  rus$бисквит$[n-m-nn_n],
#  rus$биссектриса$[n_n-f-nn],
#  rus$бит$[n_n-m-nn],
#  rus$битва$[n-f-nn_n],
#  rus$битум$[n_n-m-nn],
#  rus$бить$[vblex-impf_vblex-impf-tv],
#  rus$биться$[vblex-impf_vblex-impf-iv],
#  rus$битьё$[n_n-nt-nn],
#  rus$бифштекс$[n-m-nn_n],
#  rus$бич$[n-m-nn_n],
#  rus$благо$[n-nt-nn_n],
#  rus$благовещение$[n_n-nt-nn],
#  rus$благоволение$[n_n-nt-nn],
#  rus$благовоние$[n-nt-nn_n],
#  rus$благодарить$[vblex-impf-tv_vblex-impf],
#  rus$благодарность$[n-f-nn_n_n-f],
#  rus$благодарный$[adj-sint_adj],
#  rus$благодать$[n-f-nn_n],
#  rus$благодетель$[n-m-aa_n],
#  rus$благожелательность$[n-f-nn_n],
#  rus$благозвучие$[n_n-nt-nn],
#  rus$благоприятный$[adj-sint_adj],
#  rus$благоразумие$[n-nt-nn_n],
#  rus$благородный$[adj-sint_adj],
#  rus$благосклонность$[n-f-nn_n],
#  rus$благосостояние$[n-nt-nn_n],
#  rus$благотворитель$[n_n-m-nn],
#  rus$благотворительность$[n-f-nn_n],
#  rus$благоухание$[n-nt-nn_n],
#  rus$благочестие$[n-nt-nn_n],
#  rus$блаженство$[n-nt-nn_n],
#  rus$блажь$[n_n-f-nn],
#  rus$бланк$[n-m-nn_n],
#  rus$бледный$[adj-sint_adj],
#  rus$блеск$[n-m-nn_n],
#  rus$блестеть$[vblex-impf_vblex-impf-tv],
#  rus$блестящий$[adj-sint_adj],
#  rus$ближайший$[adj-sint_adj],
#  rus$ближневосточный$[adj_adj-sint],
#  rus$ближний$[adj-sint_adj],
#  rus$ближний$[n_n-m-aa],
#  rus$близкий$[adj-sint_adj],
#  rus$близнец$[n-m-aa_n],
#  rus$близость$[n-f-nn_n],
#  rus$блин$[n-m-nn_n],
#  rus$блок$[n-m-nn_n_n-m],
#  rus$блокада$[n-f-nn_n],
#  rus$блокнот$[n-m-nn_n],
#  rus$блондин$[n-m-aa_n],
#  rus$блондинка$[n-f-aa_n],
#  rus$блоха$[n-f-aa_n],
#  rus$блуза$[n_n-f-nn],
#  rus$блузка$[n-f-nn_n],
#  rus$блюдо$[n-nt-nn_n],
#  rus$боб$[n-m-nn_n],
#  rus$бобина$[n-f-nn_n],
#  rus$бобр$[n-m-aa_n],
#  rus$бог$[n-m-aa_n-m_n],
#  rus$богатей$[n_n-m-aa],
#  rus$богатство$[n-nt-nn_n_n-nt],
#  rus$богатый$[adj-sint_adj],
#  rus$богатырь$[n-m-aa_n],
#  rus$богач$[n-m-aa_n],
#  rus$богемский$[adj_adj-m],
#  rus$богомил$[n_n-m-aa],
#  rus$богомол$[n-m-aa_n],
#  rus$богомолец$[n_n-m-aa],
#  rus$богослужение$[n-nt-nn_n],
#  rus$богохульник$[n-m-aa_n],
#  rus$богохульство$[n-nt-nn_n_n-nt],
#  rus$бод$[n_n-m-nn],
#  rus$бодрость$[n-f-nn_n],
#  rus$боевой$[adj-sint_adj],
#  rus$боезапас$[n_n-m-nn],
#  rus$боеприпасы$[n-m-nn_n],
#  rus$боец$[n-m-aa_n],
#  rus$божество$[n-nt-aa_n-nt],
#  rus$божий$[adj_adj-m],
#  rus$бозон$[n_n-m-nn],
#  rus$бой$[n-m-aa_n],
#  rus$бойкот$[n-m-nn_n_n-m],
#  rus$бойница$[n_n-f-nn],
#  rus$бойня$[n-f-nn_n],
#  rus$бок$[n-m-nn_n],
#  rus$бокал$[n-m-nn_n],
#  rus$боковой$[adj_adj-sint],
#  rus$бокс$[n-m-nn_n],
#  rus$болван$[n-m-nn_n],
#  rus$болгарин$[n_n-m_n-m-aa],
#  rus$болгарский$[adj_adj-m],
#  rus$болезненный$[adj-sint_adj],
#  rus$болезнь$[n-f-nn_n-f_n],
#  rus$болеть$[vblex-impf_vblex-impf-iv],
#  rus$болиголов$[n-m-nn_n],
#  rus$болид$[n_n-m-nn],
#  rus$болото$[n-nt-nn_n],
#  rus$болт$[n-m-nn_n],
#  rus$болтать$[vblex-impf-tv_vblex-impf],
#  rus$боль$[n-f-nn_n],
#  rus$больница$[n-f-nn_n_n-f],
#  rus$больничный$[adj-sint_adj],
#  rus$больной$[adj-sint_adj],
#  rus$больной$[n_n-m-aa],
#  rus$большевизм$[n-m-nn_n],
#  rus$большевик$[n-m-aa_n],
#  rus$больший$[adj_adj-sint],
#  rus$большинство$[n-nt-nn_n_n-nt],
#  rus$большой$[adj-sint_adj],
#  rus$бомба$[n-f-nn_n_n-f],
#  rus$бомбардировка$[n-f-nn_n_n-f],
#  rus$бомбардировочный$[adj_adj-sint],
#  rus$бомбардировщик$[n-m-nn_n],
#  rus$бондарня$[n_n-f-nn],
#  rus$бонза$[n_n-m-aa],
#  rus$бонтон$[n_n-m-nn],
#  rus$бор$[n-m-nn_n],
#  rus$бордель$[n_n-m-nn],
#  rus$бордюр$[n-m-nn_n],
#  rus$борец$[n-m-aa_n_n-m],
#  rus$бормотание$[n_n-nt-nn],
#  rus$бормотать$[vblex-impf_vblex-impf-iv],
#  rus$борода$[n-f-nn_n],
#  rus$бородавка$[n-f-nn_n],
#  rus$бородач$[n-m-aa_n],
#  rus$борозда$[n-f-nn_n],
#  rus$бороздка$[n-f-nn_n],
#  rus$борона$[n_n-m-aa],
#  rus$бороться$[vblex-impf-iv_vblex-impf],
#  rus$бортпроводник$[n-m-aa_n],
#  rus$бортпроводница$[n_n-f-aa],
#  rus$борщ$[n_n-m-nn],
#  rus$борщевик$[n-m-nn_n],
#  rus$борьба$[n-f-nn_n-f],
#  rus$бостон$[n-m-nn_n],
#  rus$ботаник$[n-m-aa_n_n-m],
#  rus$ботаника$[n-f-nn_n_n-f],
#  rus$ботинок$[n-m-nn_n],
#  rus$ботфорты$[n-m-nn-pl_n-m-nn],
#  rus$бочар$[n-m-aa_n],
#  rus$бочка$[n-f-nn_n],
#  rus$бочонок$[n-m-nn_n],
#  rus$боязнь$[n-f-nn_n],
#  rus$боярышник$[n-m-nn_n],
#  rus$бояться$[vblex-impf_vblex-impf-ref],
#  rus$брадобрей$[n_n-m-aa],
#  rus$брак$[n-m-nn_n],
#  rus$бракодел$[n_n-m-aa],
#  rus$бракосочетание$[n-nt-nn_n],
#  rus$браманизм$[n_n-m-nn],
#  rus$брамин$[n_n-m-aa],
#  rus$брамсель$[n_n-m-nn],
#  rus$бранить$[vblex-impf_vblex-impf-tv],
#  rus$браслет$[n-m-nn_n],
#  rus$брат$[n-m-aa_n],
#  rus$братство$[n-nt-nn_n],
#  rus$брать$[vblex-impf-tv_vblex-impf],
#  rus$браузер$[n_n-m-nn],
#  rus$брахицефал$[n_n-m-aa],
#  rus$брашпиль$[n_n-m-nn],
#  rus$бред$[n-m-nn_n-m-nn-sg_n],
#  rus$брезент$[n-m-nn_n],
#  rus$брелок$[n-m-nn_n],
#  rus$брешь$[n-f-nn_n],
#  rus$бриг$[n-m-nn_n],
#  rus$бригада$[n-f-nn_n_n-f],
#  rus$бригадир$[n-m-aa_n],
#  rus$бридж$[n-m-nn_n],
#  rus$бриз$[n-m-nn_n],
#  rus$брикет$[n-m-nn_n],
#  rus$бриллиант$[n-m-nn_n],
#  rus$британец$[n_n-m-aa],
#  rus$британский$[adj_adj-sint],
#  rus$бритва$[n-f-nn_n],
#  rus$бровь$[n-f-nn_n],
#  rus$брод$[n_n-m-nn],
#  rus$бродить$[vblex-impf-iv_vblex-impf],
#  rus$брожение$[n-nt-nn_n],
#  rus$брокер$[n-m-aa_n],
#  rus$бром$[n-m-nn_n],
#  rus$бронеавтомобиль$[n_n-m-nn],
#  rus$броневик$[n_n-m-nn],
#  rus$броненосец$[n_n-m-aa],
#  rus$бронза$[n-f-nn_n],
#  rus$бронзовый$[adj-sint_adj],
#  rus$бронх$[n_n-m-nn],
#  rus$бронхит$[n-m-nn_n],
#  rus$броня$[n-f-nn_n],
#  rus$бросать$[vblex-impf-tv_vblex-impf],
#  rus$бросаться$[vblex-impf_vblex-impf-iv],
#  rus$бросить$[vblex-perf-tv_vblex-perf],
#  rus$броситься$[vblex-perf_vblex-perf-iv],
#  rus$бросок$[n-m-nn_n],
#  rus$брошь$[n_n-f-nn],
#  rus$брошюра$[n-f-nn_n],
#  rus$брус$[n-m-nn_n],
#  rus$брусника$[n_n-f-nn],
#  rus$брусок$[n_n-m-nn],
#  rus$бруствер$[n-m-nn_n],
#  rus$брыжейка$[n_n-f-nn],
#  rus$брыжи$[n-m-nn-pl_n],
#  rus$брынза$[n_n-f-nn],
#  rus$брюзга$[n-m-aa_n],
#  rus$брюква$[n_n-f-nn],
#  ...]

# %%
l1.dict
# Out:
# {rus$и$[cnjcoo]: rus$и$[cnjcoo],
#  rus$и$[n]: rus$и$[n],
#  rus$и$[cnjadv]: rus$и$[cnjadv],
#  rus$а$[cnjcoo]: rus$а$[cnjcoo],
#  rus$а$[cnjadv]: rus$а$[cnjadv],
#  rus$или$[cnjcoo]: rus$или$[cnjcoo],
#  rus$или$[n]: rus$или$[n],
#  rus$или$[cnjadv]: rus$или$[cnjadv],
#  rus$или$[adv]: rus$или$[adv],
#  rus$если$[cnjsub]: rus$если$[cnjsub],
#  rus$если$[n]: rus$если$[n],
#  rus$если$[cnjadv]: rus$если$[cnjadv],
#  rus$без$[pr]: rus$без$[pr],
#  rus$без$[n]: rus$без$[n],
#  rus$благодаря$[pr]: rus$благодаря$[pr],
#  rus$благодаря$[n]: rus$благодаря$[n],
#  rus$в$[n]: rus$в$[n],
#  rus$вдоль$[pr]: rus$вдоль$[pr],
#  rus$вдоль$[adv]: rus$вдоль$[adv],
#  rus$вдоль$[n]: rus$вдоль$[n],
#  rus$включая$[pr]: rus$включая$[pr],
#  rus$вместо$[pr]: rus$вместо$[pr],
#  rus$вместо$[n]: rus$вместо$[n],
#  rus$вместо$[adv]: rus$вместо$[adv],
#  rus$вне$[pr]: rus$вне$[pr],
#  rus$вне$[n]: rus$вне$[n],
#  rus$вне$[adv]: rus$вне$[adv],
#  rus$внизу$[pr]: rus$внизу$[pr],
#  rus$внизу$[adv]: rus$внизу$[adv],
#  rus$внизу$[n]: rus$внизу$[n],
#  rus$внутри$[n]: rus$внутри$[n],
#  rus$внутрь$[pr]: rus$внутрь$[pr],
#  rus$внутрь$[adv]: rus$внутрь$[adv],
#  rus$возле$[n]: rus$возле$[n],
#  rus$вокруг$[pr]: rus$вокруг$[pr],
#  rus$вокруг$[adv]: rus$вокруг$[adv],
#  rus$вокруг$[n]: rus$вокруг$[n],
#  rus$вопреки$[pr]: rus$вопреки$[pr],
#  rus$вопреки$[n]: rus$вопреки$[n],
#  rus$впереди$[pr]: rus$впереди$[pr],
#  rus$впереди$[adv]: rus$впереди$[adv],
#  rus$впереди$[n]: rus$впереди$[n],
#  rus$для$[n]: rus$для$[n],
#  rus$до$[n]: rus$до$[n],
#  rus$за$[n]: rus$за$[n],
#  rus$изнутри$[pr]: rus$изнутри$[pr],
#  rus$изнутри$[adv]: rus$изнутри$[adv],
#  rus$кругом$[pr]: rus$кругом$[pr],
#  rus$меж$[pr]: rus$меж$[pr],
#  rus$меж$[n]: rus$меж$[n],
#  rus$между$[n]: rus$между$[n],
#  rus$мимо$[n]: rus$мимо$[n],
#  rus$мимо$[adv]: rus$мимо$[adv],
#  rus$на$[n]: rus$на$[n],
#  rus$c$[pr]: rus$c$[pr],
#  rus$над$[n]: rus$над$[n],
#  rus$накануне$[pr]: rus$накануне$[pr],
#  rus$накануне$[n]: rus$накануне$[n],
#  rus$напротив$[pr]: rus$напротив$[pr],
#  rus$напротив$[n]: rus$напротив$[n],
#  rus$насчёт$[pr]: rus$насчёт$[pr],
#  rus$насчёт$[n]: rus$насчёт$[n],
#  rus$о$[n]: rus$о$[n],
#  rus$о$[adv]: rus$о$[adv],
#  rus$около$[adv]: rus$около$[adv],
#  rus$около$[n]: rus$около$[n],
#  rus$по$[pr]: rus$по$[pr],
#  rus$по$[n]: rus$по$[n],
#  rus$из$[n]: rus$из$[n],
#  rus$с$[n]: rus$с$[n],
#  rus$с$[adv]: rus$с$[adv],
#  rus$prpers$[prn-p3-m]: rus$prpers$[prn-p3-m],
#  rus$prpers$[prn-p3-f]: rus$prpers$[prn-p3-f],
#  rus$prpers$[prn-p3-nt]: rus$prpers$[prn-p3-nt],
#  rus$prpers$[prn-p3-mf]: rus$prpers$[prn-p3-mf],
#  rus$это$[n]: rus$это$[n],
#  rus$это$[det]: rus$это$[det],
#  rus$это$[itg]: rus$это$[itg],
#  rus$который$[det-itg]: rus$который$[det-itg],
#  rus$который$[prn-itg]: rus$который$[prn-itg],
#  rus$весь$[n]: rus$весь$[n],
#  rus$весь$[adj]: rus$весь$[adj],
#  rus$весь$[prn-ind]: rus$весь$[prn-ind],
#  rus$весь$[det-ind-m-an-sg-nom]: rus$весь$[det-ind-m-an-sg-nom],
#  rus$весь$[prn-def-mfn-aa-pl-acc]: rus$весь$[prn-def-mfn-aa-pl-acc],
#  rus$весь$[prn-def-mfn-nn-pl-acc]: rus$весь$[prn-def-mfn-nn-pl-acc],
#  rus$весь$[pr]: rus$весь$[pr],
#  rus$весь$[prn-def-nt-an-sg]: rus$весь$[prn-def-nt-an-sg],
#  rus$сколько$[n]: rus$сколько$[n],
#  rus$сколько$[adv]: rus$сколько$[adv],
#  rus$сколько$[det-qnt-mfn-an-pl-nom]: rus$сколько$[det-qnt-mfn-an-pl-nom],
#  rus$что$[cnjsub]: rus$что$[cnjsub],
#  rus$что$[n]: rus$что$[n],
#  rus$что$[itg]: rus$что$[itg],
#  rus$что$[cnjcoo]: rus$что$[cnjcoo],
#  rus$свой$[prn-pos]: rus$свой$[prn-pos],
#  rus$свой$[n]: rus$свой$[n],
#  rus$свой$[adj]: rus$свой$[adj],
#  rus$свой$[prn-ref]: rus$свой$[prn-ref],
#  rus$тот же самый$[adj]: rus$тот же самый$[adj],
#  rus$тот же самый$[n]: rus$тот же самый$[n],
#  rus$самый$[adj]: rus$самый$[adj],
#  rus$самый$[n]: rus$самый$[n],
#  rus$либо$[cnjcoo]: rus$либо$[cnjcoo],
#  rus$либо$[cnjadv]: rus$либо$[cnjadv],
#  rus$об этом$[det]: rus$об этом$[det],
#  rus$наименование$[n-nt-nn]: rus$наименование$[n-nt-nn],
#  rus$автор$[n-m-nn]: rus$автор$[n-m-nn],
#  rus$агент$[n-m-nn]: rus$агент$[n-m-nn],
#  rus$агентство$[n-f-nn]: rus$агентство$[n-f-nn],
#  rus$ангел$[n-f-aa]: rus$ангел$[n-f-aa],
#  rus$атака$[n-f-nn]: rus$атака$[n-f-nn],
#  rus$баба$[n-f-aa]: rus$баба$[n-f-aa],
#  rus$бабка$[n-f-aa]: rus$бабка$[n-f-aa],
#  rus$бабка$[n-f-nn]: rus$бабка$[n-f-nn],
#  rus$бабочка$[n-f-nn]: rus$бабочка$[n-f-nn],
#  rus$база$[adj]: rus$база$[adj],
#  rus$башка$[n-f-nn]: rus$башка$[n-f-nn],
#  rus$бой$[adj]: rus$бой$[adj],
#  rus$боцман$[n-m-aa]: rus$боцман$[n-m-aa],
#  rus$бревно$[n-nt-nn]: rus$бревно$[n-nt-nn],
#  rus$бригада$[n-f-an]: rus$бригада$[n-f-an],
#  rus$бровь$[n-m-aa]: rus$бровь$[n-m-aa],
#  rus$бумага$[adj]: rus$бумага$[adj],
#  rus$буря$[n-f-an]: rus$буря$[n-f-an],
#  rus$бык$[n-m-nn]: rus$бык$[n-m-nn],
#  rus$бытие$[n-nt-nn]: rus$бытие$[n-nt-nn],
#  rus$бытие$[n-nt-aa]: rus$бытие$[n-nt-aa],
#  rus$бюро$[n-nt-nn]: rus$бюро$[n-nt-nn],
#  rus$валенок$[n-m-nn]: rus$валенок$[n-m-nn],
#  rus$веревка$[n-f-nn]: rus$веревка$[n-f-nn],
#  rus$вертолет$[n-m-nn]: rus$вертолет$[n-m-nn],
#  rus$взвод$[n-m-nn]: rus$взвод$[n-m-nn],
#  rus$взор$[n-m-nn]: rus$взор$[n-m-nn],
#  rus$воин$[n-m-nn]: rus$воин$[n-m-nn],
#  rus$волк$[n-m-nn]: rus$волк$[n-m-nn],
#  rus$воля$[n-f-aa]: rus$воля$[n-f-aa],
#  rus$воротник$[n-m-nn]: rus$воротник$[n-m-nn],
#  rus$воспоминание$[n-nt-nn]: rus$воспоминание$[n-nt-nn],
#  rus$восхищение$[n-nt-nn]: rus$восхищение$[n-nt-nn],
#  rus$время$[nt]: rus$время$[nt],
#  rus$гад$[n-m-aa]: rus$гад$[n-m-aa],
#  rus$генерал$[n-m-nn]: rus$генерал$[n-m-nn],
#  rus$гений$[n-m-nn]: rus$гений$[n-m-nn],
#  rus$гибель$[n-f-nn]: rus$гибель$[n-f-nn],
#  rus$глава$[n-m-aa]: rus$глава$[n-m-aa],
#  rus$голова$[n-f-aa]: rus$голова$[n-f-aa],
#  rus$голова$[n-m-aa]: rus$голова$[n-m-aa],
#  rus$грамм$[n-m-nn]: rus$грамм$[n-m-nn],
#  rus$движение$[n-n]: rus$движение$[n-n],
#  rus$деятельность$[n-f-nn]: rus$деятельность$[n-f-nn],
#  rus$дипломат$[n-m-nn]: rus$дипломат$[n-m-nn],
#  rus$доклад$[m]: rus$доклад$[m],
#  rus$язык$[n-m-aa]: rus$язык$[n-m-aa],
#  rus$язык$[adj]: rus$язык$[adj],
#  rus$допрос$[n-m-nn]: rus$допрос$[n-m-nn],
#  rus$дочка$[n-f-aa]: rus$дочка$[n-f-aa],
#  rus$драка$[n-f-nn]: rus$драка$[n-f-nn],
#  rus$друг$[n-ma]: rus$друг$[n-ma],
#  rus$дума$[n-f-nn]: rus$дума$[n-f-nn],
#  rus$дура$[n-f-aa]: rus$дура$[n-f-aa],
#  rus$дура$[n-f-nn]: rus$дура$[n-f-nn],
#  rus$дух$[n-m-aa]: rus$дух$[n-m-aa],
#  rus$дядя$[n-m-an]: rus$дядя$[n-m-an],
#  rus$еврей$[n-m-nn]: rus$еврей$[n-m-nn],
#  rus$европа$[n-f-nn]: rus$европа$[n-f-nn],
#  rus$единица$[n-f-aa]: rus$единица$[n-f-aa],
#  rus$жажда$[n-f-nn]: rus$жажда$[n-f-nn],
#  rus$железо$[n-nt-aa]: rus$железо$[n-nt-aa],
#  rus$жертва$[n-f-nn]: rus$жертва$[n-f-nn],
#  rus$живот$[n-m-aa]: rus$живот$[n-m-aa],
#  rus$журналист$[n-f-aa]: rus$журналист$[n-f-aa],
#  rus$заболевание$[n-nt-nn]: rus$заболевание$[n-nt-nn],
#  rus$зависимость$[n-f-nn]: rus$зависимость$[n-f-nn],
#  rus$звезда$[n-f-aa]: rus$звезда$[n-f-aa],
#  rus$здание$[n-n]: rus$здание$[n-n],
#  rus$землянка$[n-f-nn]: rus$землянка$[n-f-nn],
#  rus$зло$[adv]: rus$зло$[adv],
#  rus$значение$[n-n]: rus$значение$[n-n],
#  rus$золото$[n-nt-aa]: rus$золото$[n-nt-aa],
#  rus$игрок$[n-m-aa]: rus$игрок$[n-m-aa],
#  rus$изменение$[n-nt-nn]: rus$изменение$[n-nt-nn],
#  rus$изменение$[n-f-nn]: rus$изменение$[n-f-nn],
#  rus$инвалид$[n-m-nn]: rus$инвалид$[n-m-nn],
#  rus$интервью$[n-nt-nn]: rus$интервью$[n-nt-nn],
#  rus$интонация$[n-f-nn]: rus$интонация$[n-f-nn],
#  rus$историк$[n-m-aa]: rus$историк$[n-m-aa],
#  rus$источник$[adj]: rus$источник$[adj],
#  rus$исход$[n-f]: rus$исход$[n-f],
#  rus$кабина$[n-f-nn]: rus$кабина$[n-f-nn],
#  rus$кадр$[n-m-nn]: rus$кадр$[n-m-nn],
#  rus$калитка$[n-f-nn]: rus$калитка$[n-f-nn],
#  rus$капитализм$[n-m-nn]: rus$капитализм$[n-m-nn],
#  rus$капуста$[n-m-nn]: rus$капуста$[n-m-nn],
#  rus$карта$[n-m-nn]: rus$карта$[n-m-nn],
#  rus$кафе$[n-nt-aa]: rus$кафе$[n-nt-aa],
#  rus$кино$[n-nt-aa]: rus$кино$[n-nt-aa],
#  rus$кладбище$[n-m-nn]: rus$кладбище$[n-m-nn],
#  rus$кладбище$[n-m-aa]: rus$кладбище$[n-m-aa],
#  rus$кладбище$[n-nt-nn-pl]: rus$кладбище$[n-nt-nn-pl],
#  rus$ковер$[n-m-nn]: rus$ковер$[n-m-nn],
#  rus$колдун$[n-m-nn]: rus$колдун$[n-m-nn],
#  rus$командировка$[n-f-nn]: rus$командировка$[n-f-nn],
#  rus$комплекс$[adj]: rus$комплекс$[adj],
#  rus$компьютер$[adj]: rus$компьютер$[adj],
#  rus$конструктор$[n-m-nn]: rus$конструктор$[n-m-nn],
#  rus$конструктор$[n-m-aa]: rus$конструктор$[n-m-aa],
#  rus$копье$[n-nt-nn]: rus$копье$[n-nt-nn],
#  rus$корень$[n-f-nn]: rus$корень$[n-f-nn],
#  rus$корзина$[n-f-nn]: rus$корзина$[n-f-nn],
#  rus$коридор$[n-m-nn]: rus$коридор$[n-m-nn],
#  rus$коробка$[n-f-nn]: rus$коробка$[n-f-nn],
#  rus$корова$[n-f-aa]: rus$корова$[n-f-aa],
#  rus$королева$[n-f-aa]: rus$королева$[n-f-aa],
#  rus$корреспондент$[n-m-aa]: rus$корреспондент$[n-m-aa],
#  rus$космос$[n-m-nn]: rus$космос$[n-m-nn],
#  rus$костюм$[n-m-nn]: rus$костюм$[n-m-nn],
#  rus$кот$[n-m-aa]: rus$кот$[n-m-aa],
#  rus$котенок$[n-m-aa]: rus$котенок$[n-m-aa],
#  rus$котенок$[n-m-nn]: rus$котенок$[n-m-nn],
#  rus$кофе$[n-m-aa]: rus$кофе$[n-m-aa],
#  rus$кофе$[n-m-nn]: rus$кофе$[n-m-nn],
#  rus$кофе$[adj]: rus$кофе$[adj],
#  rus$кошка$[n-f-aa]: rus$кошка$[n-f-aa],
#  rus$край$[pr]: rus$край$[pr],
#  rus$кран$[n-m-nn]: rus$кран$[n-m-nn],
#  rus$краска$[n-f-nn]: rus$краска$[n-f-nn],
#  rus$краска$[n-f-aa]: rus$краска$[n-f-aa],
#  rus$красота$[n-f-nn]: rus$красота$[n-f-nn],
#  rus$кредит$[n-f-nn]: rus$кредит$[n-f-nn],
#  rus$кредит$[adj]: rus$кредит$[adj],
#  rus$кремль$[n-m-nn]: rus$кремль$[n-m-nn],
#  rus$кресло$[n-nt-nn]: rus$кресло$[n-nt-nn],
#  rus$крест$[n-m-nn]: rus$крест$[n-m-nn],
#  rus$крестьянин$[n-m-aa]: rus$крестьянин$[n-m-aa],
#  rus$крик$[n-m-nn]: rus$крик$[n-m-nn],
#  rus$кровать$[n-f-nn]: rus$кровать$[n-f-nn],
#  rus$кролик$[n-m-aa]: rus$кролик$[n-m-aa],
#  rus$крыльцо$[n-nt-nn]: rus$крыльцо$[n-nt-nn],
#  rus$крыса$[n-f-aa]: rus$крыса$[n-f-aa],
#  rus$крыша$[n-f-nn]: rus$крыша$[n-f-nn],
#  rus$крышка$[n-f-nn]: rus$крышка$[n-f-nn],
#  rus$крючок$[n-m-nn]: rus$крючок$[n-m-nn],
#  rus$кузов$[n-m-nn]: rus$кузов$[n-m-nn],
#  rus$кукла$[n-f-aa]: rus$кукла$[n-f-aa],
#  rus$кукла$[n-f-nn]: rus$кукла$[n-f-nn],
#  rus$кулак$[n-m-aa]: rus$кулак$[n-m-aa],
#  rus$кулак$[n-m-nn]: rus$кулак$[n-m-nn],
#  rus$купец$[n-m-aa]: rus$купец$[n-m-aa],
#  rus$купол$[n-m-nn]: rus$купол$[n-m-nn],
#  rus$курица$[n-f-aa]: rus$курица$[n-f-aa],
#  rus$курица$[n-m-aa]: rus$курица$[n-m-aa],
#  rus$куртка$[n-f-nn]: rus$куртка$[n-f-nn],
#  rus$куст$[n-m-nn]: rus$куст$[n-m-nn],
#  rus$лаборатория$[adj]: rus$лаборатория$[adj],
#  rus$лампочка$[n-f-nn]: rus$лампочка$[n-f-nn],
#  rus$лапа$[n-f-nn]: rus$лапа$[n-f-nn],
#  rus$лев$[n-m-nn]: rus$лев$[n-m-nn],
#  rus$легкое$[n-nt-nn]: rus$легкое$[n-nt-nn],
#  rus$лед$[n-m-nn]: rus$лед$[n-m-nn],
#  rus$лед$[n-m-nn-n-m-nn]: rus$лед$[n-m-nn-n-m-nn],
#  rus$лес$[adj]: rus$лес$[adj],
#  rus$летчик$[n-m-aa]: rus$летчик$[n-m-aa],
#  rus$лидер$[n-m-an]: rus$лидер$[n-m-an],
#  rus$ложка$[n-f-nn]: rus$ложка$[n-f-nn],
#  rus$любопытство$[n-nt-nn]: rus$любопытство$[n-nt-nn],
#  rus$мадам$[n-f-aa]: rus$мадам$[n-f-aa],
#  rus$май$[n-f]: rus$май$[n-f],
#  rus$майка$[n-f-aa]: rus$майка$[n-f-aa],
#  rus$мама$[n-f-nn]: rus$мама$[n-f-nn],
#  rus$март$[n-m-aa]: rus$март$[n-m-aa],
#  rus$мастер$[n-m-an]: rus$мастер$[n-m-an],
#  rus$мастер$[n-m-nn]: rus$мастер$[n-m-nn],
#  rus$матушка$[n-f-aa]: rus$матушка$[n-f-aa],
#  rus$мать$[n-aa-f]: rus$мать$[n-aa-f],
#  rus$медаль$[n-m]: rus$медаль$[n-m],
#  rus$месяц$[adv]: rus$месяц$[adv],
#  rus$метро$[n-nt-nn]: rus$метро$[n-nt-nn],
#  rus$метро$[n-np-nn]: rus$метро$[n-np-nn],
#  rus$милиционер$[n-m-aa]: rus$милиционер$[n-m-aa],
#  rus$мужик$[n-m-aa]: rus$мужик$[n-m-aa],
#  rus$музыкант$[n-m-an]: rus$музыкант$[n-m-an],
#  rus$мусор$[n-m-aa]: rus$мусор$[n-m-aa],
#  rus$муха$[n-m-aa]: rus$муха$[n-m-aa],
#  rus$мышь$[n-m-aa]: rus$мышь$[n-m-aa],
#  rus$налог$[adj]: rus$налог$[adj],
#  rus$напиток$[n-m-nn]: rus$напиток$[n-m-nn],
#  rus$народ$[n-m-aa]: rus$народ$[n-m-aa],
#  rus$неправда$[n-f-nn]: rus$неправда$[n-f-nn],
#  rus$норма$[n-m-nn]: rus$норма$[n-m-nn],
#  rus$обезьяна$[n-m-aa]: rus$обезьяна$[n-m-aa],
#  rus$обезьяна$[n-f-an]: rus$обезьяна$[n-f-an],
#  rus$обман$[n-m-nn]: rus$обман$[n-m-nn],
#  rus$обсуждение$[n-nt-nn]: rus$обсуждение$[n-nt-nn],
#  rus$общежитие$[n-nt-nn]: rus$общежитие$[n-nt-nn],
#  rus$объятие$[n-nt-nn]: rus$объятие$[n-nt-nn],
#  rus$овца$[n-m-aa]: rus$овца$[n-m-aa],
#  rus$огонек$[n-m-nn]: rus$огонек$[n-m-nn],
#  rus$окоп$[n-m-nn]: rus$окоп$[n-m-nn],
#  rus$октябрь$[adj]: rus$октябрь$[adj],
#  rus$ответ$[n-m-nn-nn]: rus$ответ$[n-m-nn-nn],
#  rus$ответственность$[adj]: rus$ответственность$[adj],
#  rus$отдых$[adj]: rus$отдых$[adj],
#  rus$отец$[n-aa-m]: rus$отец$[n-aa-m],
#  rus$отпуск$[n-m-nn]: rus$отпуск$[n-m-nn],
#  rus$отчаяние$[n-nt-nn]: rus$отчаяние$[n-nt-nn],
#  rus$отчет$[n-m-nn]: rus$отчет$[n-m-nn],
#  rus$палуба$[n-f-nn]: rus$палуба$[n-f-nn],
#  rus$пальто$[n-nt-nn]: rus$пальто$[n-nt-nn],
#  rus$папка$[n-m-nn]: rus$папка$[n-m-nn],
#  rus$парень$[n-m-aa]: rus$парень$[n-m-aa],
#  rus$партизан$[n-m-aa]: rus$партизан$[n-m-aa],
#  rus$пассажир$[n-mp-aa]: rus$пассажир$[n-mp-aa],
#  rus$патрон$[n-m-nn]: rus$патрон$[n-m-nn],
#  rus$пейзаж$[adj]: rus$пейзаж$[adj],
#  rus$перестройка$[n-f-nn]: rus$перестройка$[n-f-nn],
#  rus$переулок$[n-m-nn]: rus$переулок$[n-m-nn],
#  rus$печь$[n-f-nn]: rus$печь$[n-f-nn],
#  rus$пианистка$[n-f-aa]: rus$пианистка$[n-f-aa],
#  rus$пионер$[n-m-nn]: rus$пионер$[n-m-nn],
#  rus$плакат$[n-m-nn]: rus$плакат$[n-m-nn],
#  rus$пламя$[n-nt-nn-pl]: rus$пламя$[n-nt-nn-pl],
#  rus$победитель$[n-m-aa]: rus$победитель$[n-m-aa],
#  rus$поворот$[n-m-nn]: rus$поворот$[n-m-nn],
#  rus$поиск$[n-m-nn]: rus$поиск$[n-m-nn],
#  rus$покойник$[n-m-aa]: rus$покойник$[n-m-aa],
#  rus$покупатель$[n-m-nn]: rus$покупатель$[n-m-nn],
#  rus$полк$[abbr]: rus$полк$[abbr],
#  rus$поп$[n-m-aa]: rus$поп$[n-m-aa],
#  rus$посол$[n-m-nn]: rus$посол$[n-m-nn],
#  rus$походка$[n-f-nn]: rus$походка$[n-f-nn],
#  rus$правда$[adv]: rus$правда$[adv],
#  rus$право$[adj]: rus$право$[adj],
#  rus$праздник$[n-nt-nn]: rus$праздник$[n-nt-nn],
#  rus$премьера$[n-f-nn]: rus$премьера$[n-f-nn],
#  rus$преступник$[n-m-aa]: rus$преступник$[n-m-aa],
#  rus$пришелец$[n-m-aa]: rus$пришелец$[n-m-aa],
#  rus$проводник$[n-m-nn]: rus$проводник$[n-m-nn],
#  rus$проводник$[n-m-an]: rus$проводник$[n-m-an],
#  rus$продукция$[n-f-nn]: rus$продукция$[n-f-nn],
#  rus$процент$[m-nn]: rus$процент$[m-nn],
#  rus$пруд$[n-m-nn]: rus$пруд$[n-m-nn],
#  rus$птица$[adj]: rus$птица$[adj],
#  rus$публикация$[n-f-nn]: rus$публикация$[n-f-nn],
#  rus$пулемет$[n-m-nn]: rus$пулемет$[n-m-nn],
#  rus$путь$[m]: rus$путь$[m],
#  rus$пыль$[n-f-aa]: rus$пыль$[n-f-aa],
#  rus$рада$[n-f-nn]: rus$рада$[n-f-nn],
#  rus$разведчик$[n-m-nn]: rus$разведчик$[n-m-nn],
#  rus$развод$[n-m-nn]: rus$развод$[n-m-nn],
#  rus$разработка$[n-f-nn]: rus$разработка$[n-f-nn],
#  rus$райком$[n-m-nn]: rus$райком$[n-m-nn],
#  rus$рассказ$[n-f-nn-nn]: rus$рассказ$[n-f-nn-nn],
#  rus$расстрел$[n-m-nn]: rus$расстрел$[n-m-nn],
#  rus$ребенок$[n-m-aa]: rus$ребенок$[n-m-aa],
#  rus$регион$[m]: rus$регион$[m],
#  rus$редактор$[n-m-an]: rus$редактор$[n-m-an],
#  rus$режиссер$[n-m-aa]: rus$режиссер$[n-m-aa],
#  rus$рельс$[n-m-aa]: rus$рельс$[n-m-aa],
#  rus$ресница$[n-f-nn]: rus$ресница$[n-f-nn],
#  rus$ресурс$[n-m-nn]: rus$ресурс$[n-m-nn],
#  rus$решетка$[n-f-nn]: rus$решетка$[n-f-nn],
#  rus$род$[abbr]: rus$род$[abbr],
#  rus$рождение$[n-nt-nn]: rus$рождение$[n-nt-nn],
#  rus$рот$[n-m-aa]: rus$рот$[n-m-aa],
#  rus$ружье$[n-nt-nn]: rus$ружье$[n-nt-nn],
#  rus$русский$[n-f-aa]: rus$русский$[n-f-aa],
#  rus$русский$[adj-m-an-sg-nom]: rus$русский$[adj-m-an-sg-nom],
#  rus$санитар$[n-m-aa]: rus$санитар$[n-m-aa],
#  rus$свет$[adj]: rus$свет$[adj],
#  rus$свет$[n-m-nn-pl]: rus$свет$[n-m-nn-pl],
#  rus$свинья$[n-m-aa]: rus$свинья$[n-m-aa],
#  rus$связь$[n-f-nn-nn]: rus$связь$[n-f-nn-nn],
#  rus$сейф$[n-m-nn]: rus$сейф$[n-m-nn],
#  rus$система$[adj]: rus$система$[adj],
#  rus$событие$[n-n]: rus$событие$[n-n],
#  rus$солнце$[n-m-nn]: rus$солнце$[n-m-nn],
#  rus$сооружение$[n-nt-nn]: rus$сооружение$[n-nt-nn],
#  rus$сотня$[n-f-nn]: rus$сотня$[n-f-nn],
#  rus$сотня$[num]: rus$сотня$[num],
#  rus$сотрудник$[n-m-aa]: rus$сотрудник$[n-m-aa],
#  rus$спорт$[adj]: rus$спорт$[adj],
#  rus$спорт$[n-f-nn]: rus$спорт$[n-f-nn],
#  rus$спорт$[n-m-nn-pl]: rus$спорт$[n-m-nn-pl],
#  rus$спутник$[n-m-nn]: rus$спутник$[n-m-nn],
#  rus$сравнение$[n-f-nn]: rus$сравнение$[n-f-nn],
#  rus$сталкер$[n-m-aa]: rus$сталкер$[n-m-aa],
#  rus$старшина$[n-m-aa]: rus$старшина$[n-m-aa],
#  rus$стая$[n-f-nn]: rus$стая$[n-f-nn],
#  rus$стихи$[n-m-nn]: rus$стихи$[n-m-nn],
#  rus$стража$[n-f-nn]: rus$стража$[n-f-nn],
#  rus$страница$[n-f-aa]: rus$страница$[n-f-aa],
#  rus$стремление$[n-nt-nn]: rus$стремление$[n-nt-nn],
#  rus$студент$[adj]: rus$студент$[adj],
#  rus$суббота$[n-m]: rus$суббота$[n-m],
#  rus$суть$[n-f-nn]: rus$суть$[n-f-nn],
#  rus$счет$[n-m-nn]: rus$счет$[n-m-nn],
#  rus$сынок$[n-m-aa]: rus$сынок$[n-m-aa],
#  rus$сэр$[n-m-aa]: rus$сэр$[n-m-aa],
#  rus$сюжет$[n-m-nn]: rus$сюжет$[n-m-nn],
#  rus$такси$[n-nt-nn]: rus$такси$[n-nt-nn],
#  rus$танцор$[n-m-aa]: rus$танцор$[n-m-aa],
#  rus$телевизор$[adj]: rus$телевизор$[adj],
#  rus$тень$[n-f-aa]: rus$тень$[n-f-aa],
#  rus$тепло$[adv]: rus$тепло$[adv],
#  rus$тетка$[n-f-aa]: rus$тетка$[n-f-aa],
#  rus$тетя$[n-f-aa]: rus$тетя$[n-f-aa],
#  rus$тип$[n-m-nn]: rus$тип$[n-m-nn],
#  rus$толь$[n-m-nn]: rus$толь$[n-m-nn],
#  rus$трус$[n-m-aa]: rus$трус$[n-m-aa],
#  rus$туча$[n-f-nn]: rus$туча$[n-f-nn],
#  rus$увеличение$[n-nt-nn]: rus$увеличение$[n-nt-nn],
#  rus$улица$[adj]: rus$улица$[adj],
#  rus$ум$[abbr]: rus$ум$[abbr],
#  rus$усадьба$[n-f-nn]: rus$усадьба$[n-f-nn],
#  rus$учительница$[n-f-aa]: rus$учительница$[n-f-aa],
#  rus$фактор$[n-m-nn]: rus$фактор$[n-m-nn],
#  rus$фильм$[adj]: rus$фильм$[adj],
#  rus$фон$[n-m-nn]: rus$фон$[n-m-nn],
#  rus$фюрер$[n-m-aa]: rus$фюрер$[n-m-aa],
#  rus$хоббит$[n-m-aa]: rus$хоббит$[n-m-aa],
#  rus$хутор$[n-m-nn]: rus$хутор$[n-m-nn],
#  rus$царь$[n-mp-aa]: rus$царь$[n-mp-aa],
#  rus$цех$[n-m-nn]: rus$цех$[n-m-nn],
#  rus$чай$[cnjadv]: rus$чай$[cnjadv],
#  rus$чайник$[n-m-aa]: rus$чайник$[n-m-aa],
#  rus$честь$[adj]: rus$честь$[adj],
#  rus$читатель$[n-m-aa]: rus$читатель$[n-m-aa],
#  rus$член$[n-m-aa]: rus$член$[n-m-aa],
#  rus$шинель$[n-f-nn]: rus$шинель$[n-f-nn],
#  rus$школьник$[n-m-aa]: rus$школьник$[n-m-aa],
#  rus$шкура$[n-f-aa]: rus$шкура$[n-f-aa],
#  rus$шоссе$[n-nt-aa]: rus$шоссе$[n-nt-aa],
#  rus$юноша$[n-f-nn]: rus$юноша$[n-f-nn],
#  rus$юноша$[n-f-aa]: rus$юноша$[n-f-aa],
#  rus$японец$[n-m-aa]: rus$японец$[n-m-aa],
#  rus$японец$[adj]: rus$японец$[adj],
#  rus$Финляндия$[np-top-f]: rus$Финляндия$[np-top-f],
#  rus$Россия$[np-top-f]: rus$Россия$[np-top-f],
#  rus$Россия$[n]: rus$Россия$[n],
#  rus$Украиня$[np-top-f]: rus$Украиня$[np-top-f],
#  rus$финский$[adj]: rus$финский$[adj],
#  rus$английский$[n]: rus$английский$[n],
#  rus$английский$[adj-m]: rus$английский$[adj-m],
#  rus$французский$[adj]: rus$французский$[adj],
#  rus$французский$[n]: rus$французский$[n],
#  rus$советский$[n]: rus$советский$[n],
#  rus$российский$[n]: rus$российский$[n],
#  rus$германский$[adj]: rus$германский$[adj],
#  rus$европейский$[n]: rus$европейский$[n],
#  rus$исторический$[adj]: rus$исторический$[adj],
#  rus$исторический$[n]: rus$исторический$[n],
#  rus$только$[adv]: rus$только$[adv],
#  rus$только$[n]: rus$только$[n],
#  rus$только$[cnjsub]: rus$только$[cnjsub],
#  rus$дорогой$[n]: rus$дорогой$[n],
#  rus$дорогой$[adv]: rus$дорогой$[adv],
#  rus$отличный$[n]: rus$отличный$[n],
#  rus$последний$[n]: rus$последний$[n],
#  rus$хороший$[n]: rus$хороший$[n],
#  rus$безопасный$[n]: rus$безопасный$[n],
#  rus$существующий$[adj]: rus$существующий$[adj],
#  rus$все еще$[adj]: rus$все еще$[adj],
#  rus$в этом случае$[adv]: rus$в этом случае$[adv],
#  rus$в этом случае$[n]: rus$в этом случае$[n],
#  rus$параллельно с этим$[adv]: rus$параллельно с этим$[adv],
#  rus$до сих пор$[adv]: rus$до сих пор$[adv],
#  rus$до сих пор$[adj]: rus$до сих пор$[adj],
#  rus$завтра$[adv]: rus$завтра$[adv],
#  rus$сегодня$[adv]: rus$сегодня$[adv],
#  rus$сегодня$[n]: rus$сегодня$[n],
#  rus$очень$[adv]: rus$очень$[adv],
#  rus$очень$[n]: rus$очень$[n],
#  rus$хорошо$[adv]: rus$хорошо$[adv],
#  rus$хорошо$[n]: rus$хорошо$[n],
#  rus$как$[n]: rus$как$[n],
#  rus$как$[pr]: rus$как$[pr],
#  rus$как$[cnjadv]: rus$как$[cnjadv],
#  rus$как$[cnjsub]: rus$как$[cnjsub],
#  rus$как$[itg]: rus$как$[itg],
#  rus$здесь$[adv]: rus$здесь$[adv],
#  rus$здесь$[n]: rus$здесь$[n],
#  rus$вот$[part]: rus$вот$[part],
#  rus$вот$[adv]: rus$вот$[adv],
#  rus$вот$[n]: rus$вот$[n],
#  rus$выяснить$[n]: rus$выяснить$[n],
#  rus$выяснить$[vblex-imperf]: rus$выяснить$[vblex-imperf],
#  rus$выяснить$[vblex-perf-iv]: rus$выяснить$[vblex-perf-iv],
#  rus$ответить$[vblex-perf-iv]: rus$ответить$[vblex-perf-iv],
#  rus$ответить$[n]: rus$ответить$[n],
#  rus$разработать$[n]: rus$разработать$[n],
#  rus$быть$[n]: rus$быть$[n],
#  rus$быть$[vblex-impf-iv]: rus$быть$[vblex-impf-iv],
#  rus$закончить$[n]: rus$закончить$[n],
#  rus$запираться$[vblex-impf-iv]: rus$запираться$[vblex-impf-iv],
#  rus$запираться$[vblex-imperf-pprs-actv]: rus$запираться$[vblex-imperf-pprs-actv],
#  rus$решать$[n]: rus$решать$[n],
#  rus$решать$[vblex-imperf]: rus$решать$[vblex-imperf],
#  rus$решать$[vblex-perf-tv]: rus$решать$[vblex-perf-tv],
#  rus$решать$[vblex-impf-pprs-actv]: rus$решать$[vblex-impf-pprs-actv],
#  rus$идти$[vblex-imperf]: rus$идти$[vblex-imperf],
#  rus$идти$[n]: rus$идти$[n],
#  rus$работать$[vblex-imperf]: rus$работать$[vblex-imperf],
#  rus$работать$[n]: rus$работать$[n],
#  rus$работать$[vblex-impf-tv]: rus$работать$[vblex-impf-tv],
#  rus$любить$[n]: rus$любить$[n],
#  rus$любить$[vblex-imperf]: rus$любить$[vblex-imperf],
#  rus$необходимый$[n]: rus$необходимый$[n],
#  rus$говорить$[vblex-imperf]: rus$говорить$[vblex-imperf],
#  rus$говорить$[n]: rus$говорить$[n],
#  rus$читать$[vblex-imperf]: rus$читать$[vblex-imperf],
#  rus$читать$[n]: rus$читать$[n],
#  rus$прочитать$[n]: rus$прочитать$[n],
#  rus$объявить$[n]: rus$объявить$[n],
#  rus$продолжать$[vblex-imperf]: rus$продолжать$[vblex-imperf],
#  rus$продолжать$[n]: rus$продолжать$[n],
#  rus$описать$[n]: rus$описать$[n],
#  rus$сделать$[n]: rus$сделать$[n],
#  rus$учитывать$[n]: rus$учитывать$[n],
#  rus$учитывать$[vblex-imperf]: rus$учитывать$[vblex-imperf],
#  rus$спасибо$[ij]: rus$спасибо$[ij],
#  rus$спасибо за$[ij]: rus$спасибо за$[ij],
#  rus$большое спасибо$[ij]: rus$большое спасибо$[ij],
#  rus$большое спасибо за$[ij]: rus$большое спасибо за$[ij],
#  rus$пожалуйста$[ij]: rus$пожалуйста$[ij],
#  rus$пожалуйста$[n]: rus$пожалуйста$[n],
#  rus$спокойной ночи$[ij]: rus$спокойной ночи$[ij],
#  rus$$[sent]: rus$$[sent],
#  rus$$[n]: rus$$[n],
#  rus$$[num-digit-m-an-sg-nom]: rus$$[num-digit-m-an-sg-nom],
#  rus$$[num-digit-mfn-an-sg-nom]: rus$$[num-digit-mfn-an-sg-nom],
#  rus$$[lpar]: rus$$[lpar],
#  rus$$[rpar]: rus$$[rpar],
#  rus$$[lquot]: rus$$[lquot],
#  rus$$[rquot]: rus$$[rquot],
#  rus$,$[cm]: rus$,$[cm],
#  rus$﻿а$[n]: rus$﻿а$[n],
#  rus$абандон$[n]: rus$абандон$[n],
#  rus$абандонировать$[n]: rus$абандонировать$[n],
#  rus$Аббас$[n]: rus$Аббас$[n],
#  rus$аббасид$[n]: rus$аббасид$[n],
#  rus$абелев$[n]: rus$абелев$[n],
#  rus$абелева$[n]: rus$абелева$[n],
#  rus$Абель$[n]: rus$Абель$[n],
#  rus$Абеля$[n]: rus$Абеля$[n],
#  rus$абзацный отступ$[n]: rus$абзацный отступ$[n],
#  rus$аблатив$[n]: rus$аблатив$[n],
#  rus$аблятив$[n]: rus$аблятив$[n],
#  rus$бланк абонемента$[n]: rus$бланк абонемента$[n],
#  rus$абонировать$[n]: rus$абонировать$[n],
#  rus$взять на абордаж$[n]: rus$взять на абордаж$[n],
#  rus$аборигенный$[n]: rus$аборигенный$[n],
#  rus$аборигенный$[adj-sint]: rus$аборигенный$[adj-sint],
#  rus$аборигенский$[n]: rus$аборигенский$[n],
#  rus$абрикосовое дерево$[n]: rus$абрикосовое дерево$[n],
#  rus$абсида$[n]: rus$абсида$[n],
#  rus$абсолютная влажность$[n]: rus$абсолютная влажность$[n],
#  rus$абсолютное большинство$[n]: rus$абсолютное большинство$[n],
#  rus$абсолютный$[n]: rus$абсолютный$[n],
#  rus$абстрагировать$[n]: rus$абстрагировать$[n],
#  rus$абстрактный$[n]: rus$абстрактный$[n],
#  rus$абсурдный$[n]: rus$абсурдный$[n],
#  rus$выплачивать аванс$[n]: rus$выплачивать аванс$[n],
#  rus$авансировать$[n]: rus$авансировать$[n],
#  rus$аварский$[n]: rus$аварский$[n],
#  rus$Аварский каганат$[n]: rus$Аварский каганат$[n],
#  rus$Авеста$[n]: rus$Авеста$[n],
#  rus$авестийский$[n]: rus$авестийский$[n],
#  rus$авиа-$[n]: rus$авиа-$[n],
#  rus$авиаперевозка$[n]: rus$авиаперевозка$[n],
#  rus$авизо$[n]: rus$авизо$[n],
#  rus$Авиценна$[n]: rus$Авиценна$[n],
#  rus$Аврора$[n]: rus$Аврора$[n],
#  rus$Австралия$[np-top-f]: rus$Австралия$[np-top-f],
#  rus$Австралия$[n]: rus$Австралия$[n],
#  rus$автаркический$[n]: rus$автаркический$[n],
#  rus$автаркичный$[n]: rus$автаркичный$[n],
#  rus$автография$[n]: rus$автография$[n],
#  rus$автокод$[n]: rus$автокод$[n],
#  rus$автоматически$[adv]: rus$автоматически$[adv],
#  rus$автоматически$[n]: rus$автоматически$[n],
#  rus$автоматический$[n]: rus$автоматический$[n],
#  rus$автоматический выключатель$[n]: rus$автоматический выключатель$[n],
#  rus$с автоматическим управлением$[n]: rus$с автоматическим управлением$[n],
#  rus$автомат с магазинной памятью$[n]: rus$автомат с магазинной памятью$[n],
#  rus$автомобиль с откидным верхом$[n]: rus$автомобиль с откидным верхом$[n],
#  rus$внутренний автоморфизм$[n]: rus$внутренний автоморфизм$[n],
#  rus$автономно$[n]: rus$автономно$[n],
#  rus$автономно$[adv]: rus$автономно$[adv],
#  rus$автономный$[n]: rus$автономный$[n],
#  rus$пассажирский автоприцеп$[n]: rus$пассажирский автоприцеп$[n],
#  rus$авторитетный$[adj-sint]: rus$авторитетный$[adj-sint],
#  rus$авторитетный$[n]: rus$авторитетный$[n],
#  rus$авторитетный человек$[n]: rus$авторитетный человек$[n],
#  rus$авторский$[n]: rus$авторский$[n],
#  rus$авторское право$[n]: rus$авторское право$[n],
#  rus$жилой автофургон$[n]: rus$жилой автофургон$[n],
#  rus$авуары$[n]: rus$авуары$[n],
#  rus$агапа$[n]: rus$агапа$[n],
#  rus$агариковые$[n]: rus$агариковые$[n],
#  rus$агглютинативный$[n]: rus$агглютинативный$[n],
#  rus$агент по поручениям$[n]: rus$агент по поручениям$[n],
#  rus$агитировать$[n]: rus$агитировать$[n],
#  rus$агитировать$[vblex-impf-tv]: rus$агитировать$[vblex-impf-tv],
#  rus$агломерировать$[n]: rus$агломерировать$[n],
#  rus$агнат$[n]: rus$агнат$[n],
#  rus$агонизировать$[n]: rus$агонизировать$[n],
#  rus$агрессивный$[n]: rus$агрессивный$[n],
#  rus$адажио$[n]: rus$адажио$[n],
#  rus$Адам$[np-ant-m]: rus$Адам$[np-ant-m],
#  rus$Адам$[n]: rus$Адам$[n],
#  rus$адамово дерево$[n]: rus$адамово дерево$[n],
#  rus$адвент$[n]: rus$адвент$[n],
#  rus$адгезивный$[n]: rus$адгезивный$[n],
#  rus$адекватный$[n]: rus$адекватный$[n],
#  rus$адресная книжка$[n]: rus$адресная книжка$[n],
#  rus$адресник$[n]: rus$адресник$[n],
#  rus$адресный справочник$[n]: rus$адресный справочник$[n],
#  rus$адресовать$[vblex-impf-tv]: rus$адресовать$[vblex-impf-tv],
#  rus$адресовать$[n]: rus$адресовать$[n],
#  rus$адрон$[n]: rus$адрон$[n],
#  rus$адский$[adj]: rus$адский$[adj],
#  rus$адский$[n]: rus$адский$[n],
#  rus$ажио$[n]: rus$ажио$[n],
#  rus$ажурный$[n]: rus$ажурный$[n],
#  rus$ажурный$[adj-sint]: rus$ажурный$[adj-sint],
#  rus$азалея$[n]: rus$азалея$[n],
#  rus$азалия$[np-top-f]: rus$азалия$[np-top-f],
#  rus$азартная игра$[n]: rus$азартная игра$[n],
#  rus$азбука Морзе$[n]: rus$азбука Морзе$[n],
#  rus$Азербайджан$[np-top-m]: rus$Азербайджан$[np-top-m],
#  rus$Азербайджан$[n]: rus$Азербайджан$[n],
#  rus$азербайджанский$[n]: rus$азербайджанский$[n],
#  rus$Азия$[np-top-f]: rus$Азия$[np-top-f],
#  rus$Азия$[n]: rus$Азия$[n],
#  rus$Азов$[n]: rus$Азов$[n],
#  rus$Азовское море$[n]: rus$Азовское море$[n],
#  rus$азот-$[n]: rus$азот-$[n],
#  rus$азотистая кислота$[n]: rus$азотистая кислота$[n],
#  rus$азотная кислота$[n]: rus$азотная кислота$[n],
#  rus$азотные удобрения$[n]: rus$азотные удобрения$[n],
#  rus$азотный$[n]: rus$азотный$[n],
#  rus$азотный$[adj-sint]: rus$азотный$[adj-sint],
#  rus$аистообразные$[n]: rus$аистообразные$[n],
#  rus$аисты$[n]: rus$аисты$[n],
#  rus$айкидо$[n]: rus$айкидо$[n],
#  rus$аймара$[n]: rus$аймара$[n],
#  rus$акажу$[n]: rus$акажу$[n],
#  rus$акантус$[n]: rus$акантус$[n],
#  rus$аквилегия$[n]: rus$аквилегия$[n],
#  rus$акклиматизироваться$[n]: rus$акклиматизироваться$[n],
#  rus$аккомодировать$[n]: rus$аккомодировать$[n],
#  rus$аккомпанировать$[n]: rus$аккомпанировать$[n],
#  rus$аккорд$[n-m-nn]: rus$аккорд$[n-m-nn],
#  rus$открыть аккредитив$[n]: rus$открыть аккредитив$[n],
#  rus$аккредитовать$[n]: rus$аккредитовать$[n],
#  rus$аккумулировать$[n]: rus$аккумулировать$[n],
#  rus$аккумулировать$[vblex-impf-tv]: rus$аккумулировать$[vblex-impf-tv],
#  rus$аккуратный$[n]: rus$аккуратный$[n],
#  rus$аколит$[n]: rus$аколит$[n],
#  rus$аксамитник$[n]: rus$аксамитник$[n],
#  rus$аксиома математической индукции$[n]: rus$аксиома математической индукции$[n],
#  rus$активное владение языком$[n]: rus$активное владение языком$[n],
#  rus$активный$[n]: rus$активный$[n],
#  rus$актовый зал$[n]: rus$актовый зал$[n],
#  rus$актуальная бесконечность$[n]: rus$актуальная бесконечность$[n],
#  rus$актуальный$[n]: rus$актуальный$[n],
#  rus$голубая акула$[n]: rus$голубая акула$[n],
#  rus$акутовый$[n]: rus$акутовый$[n],
#  rus$акушерскиещипцы$[n]: rus$акушерскиещипцы$[n],
#  rus$акушерские щипцы$[n]: rus$акушерские щипцы$[n],
#  rus$акцентировать$[n]: rus$акцентировать$[n],
#  rus$акцептование$[n]: rus$акцептование$[n],
#  rus$акционер$[n-m-nn]: rus$акционер$[n-m-nn],
#  rus$акционерное общество$[n]: rus$акционерное общество$[n],
#  rus$алармист$[n]: rus$алармист$[n],
#  rus$банахова алгебра$[n]: rus$банахова алгебра$[n],
#  rus$булева алгебра$[n]: rus$булева алгебра$[n],
#  rus$линейная алгебра$[n]: rus$линейная алгебра$[n],
#  rus$алгебраический$[n]: rus$алгебраический$[n],
#  rus$алгебраический$[adj]: rus$алгебраический$[adj],
#  rus$алгебра событий$[n]: rus$алгебра событий$[n],
#  rus$алгоритм Евклида$[n]: rus$алгоритм Евклида$[n],
#  rus$алегретто$[n]: rus$алегретто$[n],
#  rus$Александр$[np-ant-m]: rus$Александр$[np-ant-m],
#  rus$Александр$[n]: rus$Александр$[n],
#  rus$Александр Великий$[n]: rus$Александр Великий$[n],
#  rus$александрийский лист$[n]: rus$александрийский лист$[n],
#  rus$Александрия$[np-top-f]: rus$Александрия$[np-top-f],
#  rus$Александрия$[n]: rus$Александрия$[n],
#  rus$Александр Македонский$[n]: rus$Александр Македонский$[n],
#  rus$Алеутские острова$[n]: rus$Алеутские острова$[n],
#  rus$аликвотная часть$[n]: rus$аликвотная часть$[n],
#  rus$алилуйя$[n]: rus$алилуйя$[n],
#  rus$алкать$[n]: rus$алкать$[n],
#  rus$алкогольный напиток$[n]: rus$алкогольный напиток$[n],
#  rus$аллегорический$[n]: rus$аллегорический$[n],
#  rus$аллегро$[n]: rus$аллегро$[n],
#  rus$аллергенный$[n]: rus$аллергенный$[n],
#  rus$аллергический$[n]: rus$аллергический$[n],
#  rus$аллергический$[adj]: rus$аллергический$[adj],
#  rus$вызывающий аллергию$[n]: rus$вызывающий аллергию$[n],
#  rus$аллергия$[n-m-aa]: rus$аллергия$[n-m-aa],
#  rus$аллигаторы$[n]: rus$аллигаторы$[n],
#  rus$аллитерация гласных$[n]: rus$аллитерация гласных$[n],
#  rus$аллонж$[n]: rus$аллонж$[n],
#  rus$аллопатический$[n]: rus$аллопатический$[n],
#  rus$аллопатический$[adj]: rus$аллопатический$[adj],
#  rus$Алма-Ата$[n]: rus$Алма-Ата$[n],
#  rus$алмаатинец$[n]: rus$алмаатинец$[n],
#  rus$алмазный$[adj-sint]: rus$алмазный$[adj-sint],
#  rus$алмазный$[n]: rus$алмазный$[n],
#  rus$Алматы$[n]: rus$Алматы$[n],
#  rus$Алматы$[np-top-f]: rus$Алматы$[np-top-f],
#  rus$алойное дерево$[n]: rus$алойное дерево$[n],
#  rus$Алтай$[n]: rus$Алтай$[n],
#  rus$Алтай$[np-top-m]: rus$Алтай$[np-top-m],
#  rus$алтайская семья языков$[n]: rus$алтайская семья языков$[n],
#  rus$алтайский язык$[n]: rus$алтайский язык$[n],
#  rus$алтей$[n]: rus$алтей$[n],
#  rus$АЛУ$[n]: rus$АЛУ$[n],
#  rus$алфавитное упорядочение$[n]: rus$алфавитное упорядочение$[n],
#  rus$алфавитный$[adj-sint]: rus$алфавитный$[adj-sint],
#  rus$алфавитный$[n]: rus$алфавитный$[n],
#  rus$алфавитный порядок$[n]: rus$алфавитный порядок$[n],
#  rus$алфавитный указатель$[n]: rus$алфавитный указатель$[n],
#  rus$алчный$[n]: rus$алчный$[n],
#  rus$алчный$[adj-sint]: rus$алчный$[adj-sint],
#  rus$алчный человек$[n]: rus$алчный человек$[n],
#  rus$алый$[n]: rus$алый$[n],
#  rus$алый цвет$[n]: rus$алый цвет$[n],
#  rus$альба$[n]: rus$альба$[n],
#  rus$альбатросы$[n]: rus$альбатросы$[n],
#  rus$Альберт$[n]: rus$Альберт$[n],
#  rus$Альберт$[np-ant-m]: rus$Альберт$[np-ant-m],
#  rus$алькогольный напиток$[n]: rus$алькогольный напиток$[n],
#  rus$альпака$[n]: rus$альпака$[n],
#  rus$альпари$[n]: rus$альпари$[n],
#  rus$альпийская фиалка$[n]: rus$альпийская фиалка$[n],
#  rus$альпийский луг$[n]: rus$альпийский луг$[n],
#  rus$Альпы$[n]: rus$Альпы$[n],
#  rus$альт$[n-m-aa]: rus$альт$[n-m-aa],
#  rus$Альтаир$[n]: rus$Альтаир$[n],
#  rus$альтруистический$[n]: rus$альтруистический$[n],
#  rus$альфенид$[n]: rus$альфенид$[n],
#  rus$альфонс$[n]: rus$альфонс$[n],
#  rus$Альфонс$[n]: rus$Альфонс$[n],
#  rus$полуостров Аляска$[n]: rus$полуостров Аляска$[n],
#  rus$залив Аляска$[n]: rus$залив Аляска$[n],
#  rus$штат Аляска$[n]: rus$штат Аляска$[n],
#  rus$Аляскинский залив$[n]: rus$Аляскинский залив$[n],
#  rus$Амазонас$[n]: rus$Амазонас$[n],
#  rus$амазонка$[n-f-aa]: rus$амазонка$[n-f-aa],
#  rus$Амазонка$[n]: rus$Амазонка$[n],
#  rus$Амазонка$[np-top-f]: rus$Амазонка$[np-top-f],
#  rus$амальгамировать$[n]: rus$амальгамировать$[n],
#  rus$амариллис альпийский$[n]: rus$амариллис альпийский$[n],
#  rus$амариллисовые$[n]: rus$амариллисовые$[n],
#  rus$амбициозный$[n]: rus$амбициозный$[n],
#  rus$амёба$[n]: rus$амёба$[n],
#  rus$Америка$[np-top-f]: rus$Америка$[np-top-f],
#  rus$Америка$[n]: rus$Америка$[n],
#  rus$американец$[n-m-nn]: rus$американец$[n-m-nn],
#  rus$Американская мечта$[n]: rus$Американская мечта$[n],
#  rus$американские горки$[n]: rus$американские горки$[n],
#  rus$американский$[n]: rus$американский$[n],
#  rus$аминь$[n]: rus$аминь$[n],
#  rus$аморальный$[n]: rus$аморальный$[n],
#  rus$аморальный$[adj-sint]: rus$аморальный$[adj-sint],
#  rus$амортизировать$[n]: rus$амортизировать$[n],
#  rus$аморфный$[n]: rus$аморфный$[n],
#  rus$аморфный$[adj-sint]: rus$аморфный$[adj-sint],
#  rus$ампелопсис$[n]: rus$ампелопсис$[n],
#  rus$Ампер$[n]: rus$Ампер$[n],
#  rus$ампутировать$[vblex-impf-tv]: rus$ампутировать$[vblex-impf-tv],
#  rus$ампутировать$[n]: rus$ампутировать$[n],
#  rus$Амстердам$[n]: rus$Амстердам$[n],
#  rus$Аму$[n]: rus$Аму$[n],
#  rus$Амударья$[n]: rus$Амударья$[n],
#  rus$амур$[n]: rus$амур$[n],
#  rus$Амур$[n]: rus$Амур$[n],
#  rus$Амур$[np-top-m]: rus$Амур$[np-top-m],
#  rus$амфибии$[n]: rus$амфибии$[n],
#  rus$анакард$[n]: rus$анакард$[n],
#  rus$анакардиевые$[n]: rus$анакардиевые$[n],
#  rus$аналекты$[n]: rus$аналекты$[n],
#  rus$математический анализ$[n]: rus$математический анализ$[n],
#  rus$анализировать$[n]: rus$анализировать$[n],
#  rus$аналитический$[n]: rus$аналитический$[n],
#  rus$аналитический падеж$[n]: rus$аналитический падеж$[n],
#  rus$аналитический язык$[n]: rus$аналитический язык$[n],
#  rus$аналогичность$[n]: rus$аналогичность$[n],
#  rus$аналогичный$[n]: rus$аналогичный$[n],
#  rus$аналоговость$[n]: rus$аналоговость$[n],
#  rus$аналоговый$[n]: rus$аналоговый$[n],
#  rus$аналоговый$[adj-sint]: rus$аналоговый$[adj-sint],
#  rus$аналого-цифровой преобразователь$[n]: rus$аналого-цифровой преобразователь$[n],
#  rus$ананасовые$[n]: rus$ананасовые$[n],
#  rus$анархический$[n]: rus$анархический$[n],
#  rus$анархичный$[n]: rus$анархичный$[n],
#  rus$анастигмат$[n]: rus$анастигмат$[n],
#  rus$анастигматический$[n]: rus$анастигматический$[n],
#  rus$Анатолий$[n]: rus$Анатолий$[n],
#  rus$Анатолий$[np-ant-m]: rus$Анатолий$[np-ant-m],
#  rus$Анатолия$[n]: rus$Анатолия$[n],
#  rus$анафематствовать$[n]: rus$анафематствовать$[n],
#  rus$анахорет$[n]: rus$анахорет$[n],
#  rus$Ангара$[n]: rus$Ангара$[n],
#  rus$ангел-хранитель$[n]: rus$ангел-хранитель$[n],
#  rus$английская булавка$[n]: rus$английская булавка$[n],
#  rus$Англия$[np-top-f]: rus$Англия$[np-top-f],
#  rus$Англия$[n]: rus$Англия$[n],
#  rus$англосаксонский$[n]: rus$англосаксонский$[n],
#  rus$анданте$[n]: rus$анданте$[n],
#  rus$Андрей$[np-ant-m]: rus$Андрей$[np-ant-m],
#  rus$Андрей$[n]: rus$Андрей$[n],
#  rus$анекдотический$[n]: rus$анекдотический$[n],
#  rus$анекдотический$[adj]: rus$анекдотический$[adj],
#  rus$железодефицитная анемия$[n]: rus$железодефицитная анемия$[n],
#  rus$анестезировать$[n]: rus$анестезировать$[n],
#  rus$анестезирующее средство$[n]: rus$анестезирующее средство$[n],
#  rus$а не то$[n]: rus$а не то$[n],
#  rus$анизотропный$[n]: rus$анизотропный$[n],
#  rus$анизотропный$[adj-sint]: rus$анизотропный$[adj-sint],
#  rus$анимационный фи льм$[n]: rus$анимационный фи льм$[n],
#  rus$звёздчатый анис$[n]: rus$звёздчатый анис$[n],
#  rus$аннексировать$[n]: rus$аннексировать$[n],
#  rus$аннигилировать$[n]: rus$аннигилировать$[n],
#  rus$аннулировать$[n]: rus$аннулировать$[n],
#  rus$аннулировать$[vblex-impf-tv]: rus$аннулировать$[vblex-impf-tv],
#  rus$аннулироваться$[n]: rus$аннулироваться$[n],
#  rus$аномальный$[n]: rus$аномальный$[n],
#  rus$аномальный$[adj-sint]: rus$аномальный$[adj-sint],
#  rus$анонимно$[adv]: rus$анонимно$[adv],
#  rus$анонимно$[n]: rus$анонимно$[n],
#  rus$анонимный$[n]: rus$анонимный$[n],
#  rus$анорак$[n]: rus$анорак$[n],
#  rus$анормальный$[n]: rus$анормальный$[n],
#  rus$анормальный$[adj-sint]: rus$анормальный$[adj-sint],
#  rus$Анри$[n]: rus$Анри$[n],
#  rus$Ансельм$[n]: rus$Ансельм$[n],
#  rus$Антарктида$[n]: rus$Антарктида$[n],
#  rus$Антарктика$[n]: rus$Антарктика$[n],
#  rus$антарктический$[adj]: rus$антарктический$[adj],
#  rus$антарктический$[n]: rus$антарктический$[n],
#  rus$Антверпен$[n]: rus$Антверпен$[n],
#  rus$антемис$[n]: rus$антемис$[n],
#  rus$антидемпинговый$[n]: rus$антидемпинговый$[n],
#  rus$антиклерикальный$[adj-sint]: rus$антиклерикальный$[adj-sint],
#  rus$антиклерикальный$[n]: rus$антиклерикальный$[n],
#  rus$антиколониализм$[n]: rus$антиколониализм$[n],
#  rus$антилинейный$[n]: rus$антилинейный$[n],
#  rus$антипатичный$[n]: rus$антипатичный$[n],
#  rus$антиподный$[n]: rus$антиподный$[n],
#  rus$антирефлексивный$[n]: rus$антирефлексивный$[n],
#  rus$антирринум$[n]: rus$антирринум$[n],
#  rus$антисептический$[n]: rus$антисептический$[n],
#  rus$антисептический$[adj]: rus$антисептический$[adj],
#  rus$антисимметричный$[n]: rus$антисимметричный$[n],
#  rus$антихрез$[n]: rus$антихрез$[n],
#  rus$античный$[adj-sint]: rus$античный$[adj-sint],
#  rus$античный$[n]: rus$античный$[n],
#  rus$Антон$[n]: rus$Антон$[n],
#  rus$Антон$[np-ant-m]: rus$Антон$[np-ant-m],
#  rus$антономазия$[n]: rus$антономазия$[n],
#  rus$антракс$[n]: rus$антракс$[n],
#  rus$антье$[n]: rus$антье$[n],
#  rus$анчоус$[n-m-aa]: rus$анчоус$[n-m-aa],
#  rus$анютины глазки$[n]: rus$анютины глазки$[n],
#  rus$АО$[n]: rus$АО$[n],
#  rus$апартаменты$[n]: rus$апартаменты$[n],
#  rus$апатичный$[n]: rus$апатичный$[n],
#  rus$апатичный$[adj-sint]: rus$апатичный$[adj-sint],
#  rus$апач$[n]: rus$апач$[n],
#  rus$апаш$[n]: rus$апаш$[n],
#  rus$апеллировать$[n]: rus$апеллировать$[n],
#  rus$апеллировать$[vblex-imperf]: rus$апеллировать$[vblex-imperf],
#  rus$апеллировать$[vblex-impf-iv]: rus$апеллировать$[vblex-impf-iv],
#  rus$апельсинное дерево$[n]: rus$апельсинное дерево$[n],
#  rus$апланатизм$[n]: rus$апланатизм$[n],
#  rus$апланатический$[n]: rus$апланатический$[n],
#  rus$апланатичный$[n]: rus$апланатичный$[n],
#  rus$аплодировать$[n]: rus$аплодировать$[n],
#  rus$апокалиптический$[n]: rus$апокалиптический$[n],
#  rus$апокалиптический$[adj]: rus$апокалиптический$[adj],
#  rus$апокрифический$[n]: rus$апокрифический$[n],
#  rus$апостериорный$[n]: rus$апостериорный$[n],
#  rus$апостериорный$[adj-sint]: rus$апостериорный$[adj-sint],
#  rus$апостол$[n-m-aa]: rus$апостол$[n-m-aa],
#  rus$апостол$[n-nt-nn]: rus$апостол$[n-nt-nn],
#  rus$апостольский символ веры$[n]: rus$апостольский символ веры$[n],
#  rus$поставить апостроф$[n]: rus$поставить апостроф$[n],
#  rus$апофиз$[n]: rus$апофиз$[n],
#  rus$аппетитный$[n]: rus$аппетитный$[n],
#  rus$аппетитный$[adj-sint]: rus$аппетитный$[adj-sint],
#  rus$аппретировать$[n]: rus$аппретировать$[n],
#  rus$аппроксимировать$[n]: rus$аппроксимировать$[n],
#  rus$априорный$[n]: rus$априорный$[n],
#  rus$априорный$[adj-sint]: rus$априорный$[adj-sint],
#  rus$ара$[n]: rus$ара$[n],
#  rus$арабские страны$[n]: rus$арабские страны$[n],
#  rus$арабский$[adj]: rus$арабский$[adj],
#  rus$арабский$[n]: rus$арабский$[n],
#  rus$арабский мир$[n]: rus$арабский мир$[n],
#  rus$в арабском стиле$[n]: rus$в арабском стиле$[n],
#  rus$Аравийский полуостров$[n]: rus$Аравийский полуостров$[n],
#  rus$Аравийское море$[n]: rus$Аравийское море$[n],
#  rus$Аравия$[n]: rus$Аравия$[n],
#  rus$арака$[n]: rus$арака$[n],
#  rus$аралиевые$[n]: rus$аралиевые$[n],
#  rus$Аральское море$[n]: rus$Аральское море$[n],
#  rus$араукариевые$[n]: rus$араукариевые$[n],
#  rus$аргентан$[n]: rus$аргентан$[n],
#  rus$Аргентина$[n]: rus$Аргентина$[n],
#  rus$аргирол$[n]: rus$аргирол$[n],
#  rus$аргонавт$[n]: rus$аргонавт$[n],
#  rus$аргументировать$[n]: rus$аргументировать$[n],
#  rus$ареа-косинус гиперболический$[n]: rus$ареа-косинус гиперболический$[n],
#  rus$ареа-котангенс гиперболический$[n]: rus$ареа-котангенс гиперболический$[n],
#  rus$ареа-синус гиперболический$[n]: rus$ареа-синус гиперболический$[n],
#  rus$ареа-тангенс гиперболический$[n]: rus$ареа-тангенс гиперболический$[n],
#  rus$ареа-функция$[n]: rus$ареа-функция$[n],
#  rus$арендовать$[n]: rus$арендовать$[n],
#  rus$арендовать$[vblex-perf-tv]: rus$арендовать$[vblex-perf-tv],
#  rus$Арес$[n]: rus$Арес$[n],
#  rus$арестовать$[n]: rus$арестовать$[n],
#  rus$арестовать$[vblex-impf-tv]: rus$арестовать$[vblex-impf-tv],
#  rus$аридный$[n]: rus$аридный$[n],
#  rus$аристократический$[n]: rus$аристократический$[n],
#  rus$Аристотель$[n]: rus$Аристотель$[n],
#  rus$Аристофан$[n]: rus$Аристофан$[n],
#  rus$арифметический$[adj]: rus$арифметический$[adj],
#  rus$арифметический$[n]: rus$арифметический$[n],
#  rus$арифметическое устройство$[n]: rus$арифметическое устройство$[n],
#  rus$арифметическо-логическое устройство$[n]: rus$арифметическо-логическое устройство$[n],
#  rus$арккосеканс$[n]: rus$арккосеканс$[n],
#  rus$арккосинус$[n]: rus$арккосинус$[n],
#  rus$арккотангенс$[n]: rus$арккотангенс$[n],
#  rus$арксеканс$[n]: rus$арксеканс$[n],
#  rus$арксинус$[n]: rus$арксинус$[n],
#  rus$арктангенс$[n]: rus$арктангенс$[n],
#  rus$Арктика$[n]: rus$Арктика$[n],
#  rus$арктический$[n]: rus$арктический$[n],
#  rus$армировать$[n]: rus$армировать$[n],
#  rus$Армия спасения$[n]: rus$Армия спасения$[n],
#  rus$ароматизировать$[n]: rus$ароматизировать$[n],
#  rus$ароматическое вещество$[n]: rus$ароматическое вещество$[n],
#  rus$ароматный$[adj-sint]: rus$ароматный$[adj-sint],
#  rus$ароматный$[n]: rus$ароматный$[n],
#  rus$арорут$[n]: rus$арорут$[n],
#  rus$арочный контрфорс$[n]: rus$арочный контрфорс$[n],
#  rus$арпеджио$[n]: rus$арпеджио$[n],
#  rus$арроба$[n]: rus$арроба$[n],
#  rus$артезианский$[adj]: rus$артезианский$[adj],
#  rus$артезианский$[n]: rus$артезианский$[n],
#  rus$определённый артикль$[n]: rus$определённый артикль$[n],
#  rus$артикулировать$[n]: rus$артикулировать$[n],
#  rus$артикулировать$[vblex-impf-tv]: rus$артикулировать$[vblex-impf-tv],
#  rus$артикуляционная база$[n]: rus$артикуляционная база$[n],
#  rus$артикуляционный$[n]: rus$артикуляционный$[n],
#  rus$артикуляционный$[adj-sint]: rus$артикуляционный$[adj-sint],
#  rus$испанский артишок$[n]: rus$испанский артишок$[n],
#  rus$артроподы$[n]: rus$артроподы$[n],
#  rus$Артур$[n]: rus$Артур$[n],
#  rus$Артур$[np-ant-m]: rus$Артур$[np-ant-m],
#  rus$арх-$[n]: rus$арх-$[n],
#  rus$архаический$[n]: rus$архаический$[n],
#  rus$архаический$[adj-sint]: rus$архаический$[adj-sint],
#  rus$архаичный$[n]: rus$архаичный$[n],
#  rus$архаичный$[adj-sint]: rus$архаичный$[adj-sint],
#  rus$археологический$[n]: rus$археологический$[n],
#  rus$подводная археология$[n]: rus$подводная археология$[n],
#  rus$архимандрит$[n-m-aa]: rus$архимандрит$[n-m-aa],
#  rus$Архимед$[n]: rus$Архимед$[n],
#  rus$Архимеда$[n]: rus$Архимеда$[n],
#  rus$архимедов$[n]: rus$архимедов$[n],
#  rus$архимедова$[n]: rus$архимедова$[n],
#  rus$архипелаг$[n-m-aa]: rus$архипелаг$[n-m-aa],
#  rus$асафетида$[n]: rus$асафетида$[n],
#  rus$асептика$[n]: rus$асептика$[n],
#  rus$асептический$[n]: rus$асептический$[n],
#  rus$асептический$[adj]: rus$асептический$[adj],
#  rus$аскариды$[n]: rus$аскариды$[n],
#  rus$язык ассемблера$[n]: rus$язык ассемблера$[n],
#  rus$ассемблировать$[n]: rus$ассемблировать$[n],
#  rus$ассигновать$[n]: rus$ассигновать$[n],
#  rus$ассимилировать$[n]: rus$ассимилировать$[n],
#  rus$ассирийский$[n]: rus$ассирийский$[n],
#  rus$Ассирия$[n]: rus$Ассирия$[n],
#  rus$ассистировать$[n]: rus$ассистировать$[n],
#  rus$ассоциативный$[n]: rus$ассоциативный$[n],
#  rus$ассоциативный$[adj-sint]: rus$ассоциативный$[adj-sint],
#  rus$ассоциировать$[n]: rus$ассоциировать$[n],
#  rus$астат$[n]: rus$астат$[n],
#  rus$астатин$[n]: rus$астатин$[n],
#  rus$астерия$[n]: rus$астерия$[n],
#  rus$астигматический$[n]: rus$астигматический$[n],
#  rus$астигматический$[adj]: rus$астигматический$[adj],
#  rus$астра садовая$[n]: rus$астра садовая$[n],
#  rus$астровые$[n]: rus$астровые$[n],
#  ...}

# %%
os.stat('./tool/func.py').st_size
# Out:
# 47853

# %%
def recommend(lang1, lang2):
    """
    """
    
    G = nx.Graph()
    with open ('./filelist.txt','r', encoding='utf-8') as f:
        for line in tqdm(f.readlines()):
            line = line.strip('\n')
            pair = [l(i) for i in line.split('.')[-2].split('-')] 
            with open(line, 'r', encoding='utf-8') as f:
                n = len(f.readlines())
            coef = 1/log10(n)
            if coef < 1:
                #print (pair, coef)
                G.add_edge(pair[0], pair[1], weight=coef, name=line)
    result = {}
    for path in islice(nx.shortest_simple_paths(G, source=lang1, target=lang2, weight='weight'), 0, 300):
        length = sum([G[path[i]][path[i-1]]['weight'] for i in range(1, len(path))])
        for i in range(1, len(path)):
            if G[path[i]][path[i-1]]['name'] not in result:
                result[G[path[i]][path[i-1]]['name']]  = length
    #for i in result:
    #    print (i, result[i])
    config = '{}-{}-recommend'.format(lang1, lang2)
    with open (config,'w', encoding='utf-8') as f:
        for i in sorted(result, key=result.get):
            f.write(i+'\n')

# %%
recommend('eng', 'spa')
# Out:
# 100%|████████████████████████████████████████| 289/289 [00:03<00:00, 89.57it/s]

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
class CmpList(list):
    def __lt__(self, other):
        if 
class DiGetItem:
    def __init__(self):
        self.list = CmpList()
        self.dict = {}
    
    def add(self, word):
        if len (word.s) > 1: self.list.append(word)
        else: self.dict[word] = word
    
    def __getitem__(self, key):
        key2 = Word(key.lemma, key.lang, [''])
        if key in self.dict: return self.dict[key]
        else:
            if key2 in self.dict: return self.dict[key2]
            try:
                key = self.list[self.list.index(key)]
                return key
            except:
                pass
    def __len__(self):
        return len(self.list)+len(self.dict)
