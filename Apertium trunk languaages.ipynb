# %%
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
LANG = nx.Graph()

# %%
elist = [('Afrikaans', 'Dutch'), ('Aragonese', 'Catalan'), ('Belarusian', 'Russian'), ('Breton', 'French'), 
         ('Catalan', 'Italian'), ('Catalan', 'Sardinian'), ('Crimean Tatar', 'Turkish'), ('Welsh', 'English'),
        ('Danish', 'Norwegian'), ('English', 'Spanish'), ('English', 'Galician'), ('English', 'Catalan'),
        ('English', 'Kazakh'), ('Esperanto', 'Catalan'), ('Esperanto', 'English'), ('Esperanto', 'Spanish'),
        ('Esperanto', 'French'), ('Spanish', 'Galician'), ('Spanish', 'Portuguese'), ('Spanish', 'Romanian'),
        ('Basque', 'English'), ('Basque', 'Spanish'), ('French', 'Spanish'), ('French', 'Catalan'),
        ('Serbo-Croatian', 'English'), ('Serbo-Croatian', 'Macedonian'), ('Serbo-Croatian', 'Slovenian'), 
         ('Indonesian', 'Malay'),('Icelandic', 'English'),('Icelandic', 'Swedish'),('Kazakh', 'Russian'),
         ('Kazakh', 'Tatar'),('Macedonian', 'Bulgarian'),('Macedonian', 'English'),('Maltese', 'Arabic'),
         ('Norwegian Nynorsk', 'Norwegian Bokmål'),('Occitan', 'Catalan'),('Occitan', 'Spanish'),
         ('Portuguese', 'Catalan'),('Portuguese', 'Galician'),('Russian', 'Ukrainian'),('Northern Sámi', 'Norwegian Bokmål'),
         ('Spanish', 'Aragonese'),('Spanish', 'Asturian'),('Spanish', 'Catalan'),('Spanish', 'Italian'),
         ('Sardinian', 'Italian'),('Swedish', 'Danish'),('Swedish', 'Norwegian'),('Urdu', 'Hindi')]

# %%
LANG.add_edges_from(elist)

# %%
LANG.nodes()
# Out:
# ['Afrikaans',
#  'Dutch',
#  'Aragonese',
#  'Catalan',
#  'Belarusian',
#  'Russian',
#  'Breton',
#  'French',
#  'Italian',
#  'Sardinian',
#  'Crimean Tatar',
#  'Turkish',
#  'Welsh',
#  'English',
#  'Danish',
#  'Norwegian',
#  'Spanish',
#  'Galician',
#  'Kazakh',
#  'Esperanto',
#  'Portuguese',
#  'Romanian',
#  'Basque',
#  'Serbo-Croatian',
#  'Macedonian',
#  'Slovenian',
#  'Indonesian',
#  'Malay',
#  'Icelandic',
#  'Swedish',
#  'Tatar',
#  'Bulgarian',
#  'Maltese',
#  'Arabic',
#  'Norwegian Nynorsk',
#  'Norwegian Bokmål',
#  'Occitan',
#  'Ukrainian',
#  'Northern Sámi',
#  'Asturian',
#  'Urdu',
#  'Hindi']

# %%
plt.figure(figsize=(8,8))
nx.draw(LANG, with_labels = True, font_size = 10, node_color = 'white')
plt.show()
