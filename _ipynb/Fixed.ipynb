# %%
from tool.functions import *
from tool.evaluation import *

# %%
# %time download_all_bidixes()
# Out:
# 2018-07-12 10:41:20,467 | INFO : Start
# 2018-07-12 10:52:31,314 | INFO : Finish
# Wall time: 11min 12s

# %%
rename = {'epo-bul':'bul-epo', 'epo-pes':'pes-epo', 'epo-pol':'pol-epo', 'epo-bel':'bel-epo','epo-bre':'bre-epo',
          'epo-ces':'ces-epo','epo-deu':'deu-epo', 'epo-ell':'ell-epo','epo-fin':'fin-epo','spa-qve':'qve-spa',
          'hun-eng':'eng-hun'}

for root, dirs, files in os.walk ('./dictionaries/'):
    for fl in files :
        nm = fl.replace('.dix','')
        if nm in rename:
            try:
                os.rename (root+'/'+fl, root+'/'+rename[nm]+'.dix')
            except:
                print (fl)

remove = ['ces-ces.dix','ita-ita.dix', 'eus-eu_bis.dix','hbs_HR-hbs_SR.dix','zh_CN-zh_TW.dix']
for i in remove:
    os.remove('./dictionaries/'+i)

# %%
def fix_bi_dictionaries():
    from tool.data import rename, remove
    for root, dirs, files in os.walk ('./dictionaries/'):
        for fl in files :
            nm = fl.replace('.dix','')
            if nm in rename:
                try:
                    os.rename (root+'/'+fl, root+'/'+rename[nm]+'.dix')
                except:
                    pass
    for i in remove:
        try:
            os.remove('./dictionaries/'+i)
        except:
            pass

# %%
fix_bi_dictionaries()

# %%
for root, dirs, files in os.walk ('./dictionaries/'):
    for fl in files :
        pair = fl.replace('.dix','').split('-')
        if 
        try:
            tree = ET.parse(root+'/'+fl)
            for section in tree.findall('section'):
                vr = section.findall(".//*[@vr]")
                if vr: print ('vr\t', fl, len(vr))
                vl = section.findall(".//*[@vl]")
                if vl: print ('vl\t', fl, len(vl))
        except:
            print ('error:\t',fl)

# %%
# %time monodix()
# Out:
# 2018-07-12 11:09:22,634 | INFO : started
# 2018-07-12 11:12:53,886 | INFO : finished
# Wall time: 3min 31s

# %%
# %time preprocessing()
# Out:
# HBox(children=(IntProgress(value=0, max=279), HTML(value='')))
# Wall time: 1h 30min 2s

# %%
for root, dirs, files in os.walk ('./dictionaries/'):
    for fl in files :
        try:
            tree = ET.parse(root+'/'+fl)
            for section in tree.findall('section'):
                vr = section.findall(".//*[@vr]")
                if vr: print ('vr\t', fl, len(vr))
                vl = section.findall(".//*[@vl]")
                if vl: print ('vl\t', fl, len(vl))
        except:
            print ('error:\t',fl)

# %%
import os
import xml.etree.ElementTree as ET

# %%
ET.parse('C:/Users/Glaz/Documents/GitHub/apertium-sah-eng/apertium-sah-eng.sah-eng.dix')

# %%
for root, dirs, files in os.walk ('./dictionaries/'):
    for fl in files :
        try:
            tree = ET.parse(root+'/'+fl)
            for section in tree.findall('section'):
                vr = section.findall(".//*[@vr]")
                if vr: print ('vr\t', fl, len(vr))
                vl = section.findall(".//*[@vl]")
                if vl: print ('vl\t', fl, len(vl))
        except:
            print ('error:\t',fl)
# Out:
# vr	 arg-cat.dix 6
# vr	 dan-nor.dix 9944
# vr	 eng-cat.dix 495
# vl	 eng-cat.dix 80
# error:	 epo-bul.dix
# error:	 epo-fas.dix
# error:	 epo-pol.dix
# vr	 fao-nor.dix 2254
# error:	 fin-fra.dix
# vr	 fra-cat.dix 3
# vr	 fra-por.dix 550
# vr	 ita-nor.dix 696
# vl	 nor-eng.dix 140
# error:	 pol-lav.dix
# error:	 sah-eng.dix
# vr	 spa-cat.dix 997
# vr	 swe-nor.dix 7394
# vr	 swe-nor.dix 9350

# %%
variants = {'nor':{'nno':'nno','nob':'nob'}, 
            'cat':{'val':'val', 'cat':'cat_cat'}, 
            'por':{'pt':'por_pt', 'br':'por_br'},
            'eng':{'en_GB':'eng_GB','en_US':'eng_US'}
           }

# %%
def separate_dictionaries(root, filename):
    global variants
    pair = filename.replace('.dix','').split('-')
    tree = ET.parse(root+'/'+filename)
    no, left, right, both = ET.Element('section'), ET.Element('section'), ET.Element('section'), ET.Element('section')
    for section in tree.findall('section'):
        vr = section.findall(".//*[@vr]")
        for i in vr:
            if 'vl' in i.attrib:
                both.append(i)
            else:
                right.append(i)
        vl = section.findall(".//*[@vl]")
        for i in vl:
            if 'vr' not in i.attrib:
                left.append(i)
        if
# Out:
#   File "<ipython-input-2-fc0df6561f45>", line 4
#     if pair[0] in variants
#                           ^
# SyntaxError: invalid syntax

# %%
for root, dirs, files in os.walk ('./dictionaries/'):
    for fl in files :
        try:
            tree = ET.parse(root+'/'+fl)
            for section in tree.findall('section'):
                vr = section.findall(".//*[@vr]")
                for i in vr:
                    if 'vl' in i.attrib:
                        print ('!')
        except:
            print ('error:\t',fl)
# Out:
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# error:	 epo-bul.dix
# error:	 epo-fas.dix
# error:	 epo-pol.dix
# error:	 fin-fra.dix
# error:	 pol-lav.dix
# error:	 sah-eng.dix

# %% [markdown]
# # Filter

# %%
def filter_results(result, cutoff=4):
    mean = 0
    for i in result:
        mean += i[1]
    if len(result) < 20: mean += (20-len(result))*exp(-cutoff-1)
    mean = mean / 20
    return [i for i in result if i[1]>mean]

# %%
lang1, lang2 = 'eng','spa'
n = 10

# %time load_file(lang1, lang2, n=n)
# %time change_encoding('{}-{}'.format(lang1,lang2))
# %time G = built_from_file('{}-{}'.format(lang1,lang2))
# %time l1, l2 = dictionaries(lang1, lang2)

# %%
def print_lemma_results2(results, n=20):
    for i in results:
        print ('\t\t', i)
        words = filter_results(sorting(results[i], n))
        for j in words:
            print ('{}\t{}'.format(j[0], j[1]))
        print()

# %%
# %time print_lemma_results(lemma_search (G, 'star', l1, 'spa', 4, 40), n = 20)
# Out:
# 		 eng$star$[n_n-ND]
# spa$estrella$[n-f_n_n-f-sg]	2.1957739681949104
# spa$estelo$[n-m]	0.2712844579026809
# spa$lucero$[n-m_n]	0.2712844579026809
# spa$astro$[n_n-m]	0.19526883880421858
# spa$estrella$[n-f-ND]	0.1470598691371015
# spa$cometa$[n-f_n-f-sg]	0.052005373884161515
# spa$cometa$[n-m_n]	0.04526742688507605
# spa$sol$[n-m_n_n-m-ND]	0.006737946999085467
# spa$barrilete$[n-m_n]	0.006737946999085467
# spa$pata$[n-f_n_n-f-ND]	0.006737946999085467
#
# 		 eng$star$[adj]
# spa$estelar$[adj_adj-mf]	0.1268460281398451
# spa$estupendo$[adj-GD_adj-GD-ND]	0.006737946999085467
# spa$magnífico$[adj_adj-GD-ND_adj-GD]	0.006737946999085467
#
# 		 eng$star$[vblex]
# spa$protagonizar$[vblex]	0.4821836326607207
# spa$jugar$[vblex_vblex-vbact]	0.2840371146351084
# spa$presentar$[vblex]	0.11074869476740849
# spa$constar$[vblex]	0.09727280076923756
# spa$tocar$[vblex]	0.0404276819945128
# spa$actuar$[vblex]	0.0404276819945128
# spa$tener$[vblex_vblex-pis]	0.0202138409972564
# spa$obrar$[vblex]	0.0202138409972564
# spa$hacer$[vblex_vblex-inf]	0.0202138409972564
# spa$alivianarse$[vblex-pron]	0.0202138409972564
# spa$interpretar$[vblex]	0.0202138409972564
# spa$reproducir$[vblex]	0.0202138409972564
# spa$juguetear$[vblex]	0.0202138409972564
# spa$figurar$[vblex]	0.013475893998170934
#
# Wall time: 291 ms

# %%
# %time print_lemma_results2(lemma_search (G, 'star', l1, 'spa', 4, 40), n = 20)
# Out:
# 		 eng$star$[n_n-ND]
# spa$estrella$[n-f_n_n-f-sg]	2.1957739681949104
# spa$estelo$[n-m]	0.2712844579026809
# spa$lucero$[n-m_n]	0.2712844579026809
# spa$astro$[n_n-m]	0.19526883880421858
#
# 		 eng$star$[adj]
# spa$estelar$[adj_adj-mf]	0.1268460281398451
#
# 		 eng$star$[vblex]
# spa$protagonizar$[vblex]	0.4821836326607207
# spa$jugar$[vblex_vblex-vbact]	0.2840371146351084
# spa$presentar$[vblex]	0.11074869476740849
# spa$constar$[vblex]	0.09727280076923756
#
# Wall time: 256 ms

# %%
# %time print_lemma_results(lemma_search (G, 'star', l1, 'spa', 4, 40), n = 10)

# %%
def generate_example(l1, G, lang2):
    for i in l1:
        if i in G:
            ne = list(G.neighbors(i))
            s = FilteredList(ne).lang(lang2)
            if len(s) == 0:
                candidates = possible_translations(G, i, lang2, cutoff=4, n=10)
                result = evaluation(G, i, candidates, mode = 'exp', cutoff=4)
                result = filter_results(sorting(result, 10))
                #result = sorting(result, 10)
                if result:
                    yield i, result

def example(lang1, lang2, n=20):
    n = int(n)
    G = built_from_file('{}-{}'.format(lang1,lang2))
    l1, l2 = dictionaries(lang1, lang2)
    for i, result in islice(generate_example(l1, G, lang2), n):
        print (i)
        for r in result:
            print ('\t', r[0], '\t', r[1])

# %%
lang1, lang2 = 'fra','rus'
n = 10

# %time load_file(lang1, lang2, n=n)
# %time change_encoding('{}-{}'.format(lang1,lang2))
# Out:
# Wall time: 1.09 s
# Wall time: 762 ms

# %%
check_graph(lang1, lang2, n=10)

# %%
example(lang1, lang2, n=200)
# Out:
# fra$violence$[n_n-f_n-f-ND]
# 	 rus$насилие$[n-nt-nn_n_n-nt_n-nt-nn-sg] 	 0.19232729602217757
# fra$concordat$[n-m]
# 	 rus$конкордат$[n-m-nn_n] 	 0.049787068367863944
# fra$embaumeur$[n]
# 	 rus$бальзамировщик$[n_n-m-aa] 	 0.049787068367863944
# fra$cacao$[n-m]
# 	 rus$какао$[n_n-nt-nn] 	 0.08157860125476905
# 	 rus$какао-бобы$[n] 	 0.08157860125476905
# 	 rus$шоколад$[n-m-nn_n] 	 0.08157860125476905
# fra$oignon$[n-m_n_n-m-ND]
# 	 rus$лук$[n-m-nn_n_n-m] 	 0.17885140202400662
# fra$haricot$[n-m_n-m-ND]
# 	 rus$фасоль$[n-f-nn_n] 	 0.13358397513893056
# 	 rus$боб$[n-m-nn_n] 	 0.05874332088324698
# fra$syndicat$[n_n-m_n-m-ND]
# 	 rus$профсоюз$[n-m-nn_n_n-m] 	 0.1470598691371015
# 	 rus$синдикат$[n-m-nn_n] 	 0.1470598691371015
# 	 rus$объединение$[n-nt-nn_n] 	 0.052005373884161515
# 	 rus$союз$[n-m-nn_n_n-m] 	 0.052005373884161515
# 	 rus$уния$[n-f-nn_n] 	 0.052005373884161515
# fra$catamaran$[n-m]
# 	 rus$катамаран$[n_n-m-nn] 	 0.049787068367863944
# fra$alcali$[n-m]
# 	 rus$щёлочь$[n_n-f-nn] 	 0.049787068367863944
# fra$fayot$[n-m]
# 	 rus$фасоль$[n-f-nn_n] 	 0.031791532886905116
# fra$moule$[n-m_n]
# 	 rus$литейная форма$[n] 	 0.2173808819099972
# 	 rus$пуансон$[n] 	 0.2173808819099972
# fra$usure$[n-f]
# 	 rus$ростовщичество$[n-nt-nn_n_n-nt] 	 0.049787068367863944
# fra$post-scriptum$[n-m-sp_n-m]
# 	 rus$постскриптум$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$приписка$[n-f-nn_n] 	 0.049787068367863944
# fra$Hessois$[n]
# 	 rus$гессенец$[n] 	 0.049787068367863944
# fra$virus$[n-m-ND]
# 	 rus$вирус$[n-m-nn_n_n-m] 	 0.013475893998170934
# fra$aconit$[n-m]
# 	 rus$аконит$[n-m-nn_n] 	 0.06810270725659812
# 	 rus$борец$[n-m-aa_n_n-m] 	 0.06810270725659812
# fra$lobbying$[n-m]
# 	 rus$лоббирование$[n_n-nt-nn] 	 0.049787068367863944
# fra$via$[pr]
# 	 rus$из$[pr_] 	 0.04526742688507605
# fra$jonque$[n-f]
# 	 rus$джонка$[n_n-f-nn] 	 0.049787068367863944
# fra$pub$[n-f]
# 	 rus$реклама$[n-f-nn_n] 	 0.09537459866071533
# fra$application bijective$[n-f]
# 	 rus$биекция$[n] 	 0.05652501536694941
# 	 rus$взаимно однозначное соответствие$[n] 	 0.05652501536694941
# fra$lilas$[n-m_m-m]
# 	 rus$лиловый цвет$[n] 	 0.049787068367863944
# fra$majeur$[adj_adj-f]
# 	 rus$отличный$[adj-sint_adj] 	 0.2712844579026809
# fra$cil$[n-m_n_n-m-ND]
# 	 rus$ресница$[n-f-nn] 	 0.15863756102675022
# 	 rus$ресничка$[n-f-nn_n] 	 0.049787068367863944
# fra$géniteur$[n]
# 	 rus$отец$[n-m-aa_n] 	 0.031791532886905116
# 	 rus$батюшка$[n-m-aa_n] 	 0.025053585887819647
# 	 rus$падре$[n] 	 0.025053585887819647
# fra$bouquet$[n-m_n]
# 	 rus$букет$[n-m-nn_n] 	 0.20580319002034847
# 	 rus$ветвь$[n-f-nn_n_n-f-nn-pl] 	 0.09727280076923756
# 	 rus$ар$[n-m-nn_n] 	 0.03852947988599058
# 	 rus$группа$[n-f-nn_n_n-f] 	 0.03852947988599058
# 	 rus$множество$[n-nt-nn_n_n-nt_n-nt-nn-sg] 	 0.03852947988599058
# 	 rus$совокупность$[n-f-nn_n] 	 0.03852947988599058
# fra$plan$[n-m_n_n-m-ND]
# 	 rus$план$[n-m-nn_n_n-m] 	 0.20580319002034847
# 	 rus$аэроплан$[n-m-nn_n] 	 0.06548126788233244
# 	 rus$самолёт$[n-m-nn_n_n-m] 	 0.06548126788233244
# 	 rus$плоскость симметрии$[n] 	 0.049787068367863944
# fra$pratique$[n_n-f_n-f-ND]
# 	 rus$практика$[n-f-nn_n] 	 0.49834482959380466
# fra$lunch$[n-m]
# 	 rus$второй завтрак$[n] 	 0.049787068367863944
# 	 rus$ленч$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$обед$[n-m-nn_n] 	 0.01831563888873418
# fra$prescrire$[vblex]
# 	 rus$объявить$[vblex-perf_vblex-perf-tv] 	 0.013475893998170934
# 	 rus$быть$[vbser_vbser-adj] 	 0.013475893998170934
# fra$récusation$[n-f_n]
# 	 rus$вызов$[n-m-nn_n] 	 0.08157860125476907
# fra$prolétariat$[n-m_n_n-m-ND]
# 	 rus$пролетариат$[n-m-nn_n] 	 0.1586375610267502
# fra$vivres$[n_n-m]
# 	 rus$продовольствие$[n-nt-nn_n] 	 0.07484065425568358
# 	 rus$провиант$[n-m-nn_n] 	 0.031791532886905116
# fra$prééminence$[n-f]
# 	 rus$привилегия$[n-f-nn_n] 	 0.01831563888873418
# fra$pari$[n-m_n-m-ND]
# 	 rus$заклад$[n-m-nn_n] 	 0.17401165713344338
# 	 rus$пари$[n-nt-nn_n] 	 0.17401165713344338
# 	 rus$ставка$[n-f-nn_n] 	 0.17401165713344338
# fra$Aléoute$[n]
# 	 rus$алеут$[n_n-m-aa] 	 0.049787068367863944
# fra$dossier$[n-m_n_n-m-ND]
# 	 rus$файл$[n-m-nn_n] 	 0.25591036179598775
# 	 rus$дело$[n-nt-nn_n_n-nt] 	 0.17885140202400662
# 	 rus$досье$[n-nt-nn_n] 	 0.17885140202400662
# 	 rus$папка$[n-m-nn] 	 0.07673885636420581
# 	 rus$папка$[n-f-nn_n] 	 0.052005373884161515
# fra$exotisme$[n-m]
# 	 rus$экзотика$[n_n-f-nn] 	 0.049787068367863944
# fra$dernier$[adj_adj-GD-ND]
# 	 rus$последний$[adj_adj-sint] 	 0.3502416197831843
# fra$collet$[n-m_n_n-m-ND]
# 	 rus$шея$[n-f-nn_n] 	 0.5264715824329252
# 	 rus$шейка$[n_n-f-nn] 	 0.27992060701028865
# 	 rus$горлышко$[n-nt-nn_n] 	 0.23687148564151017
# fra$lourdeur$[n-f]
# 	 rus$вес$[n-m-nn_n_n-m-nn-pl] 	 0.08831654825385452
# 	 rus$тяжесть$[n-f-nn_n] 	 0.049787068367863944
# fra$téléphoner$[vblex]
# 	 rus$говорить$[vblex-imperf] 	 0.013475893998170934
# fra$peuplade$[n-f]
# 	 rus$род$[n-m-nn_n_n-m] 	 0.06326296236603487
# 	 rus$племя$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$народность$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$народ$[n-m-nn_n_n-m] 	 0.0202138409972564
# 	 rus$село$[n-nt-nn_n_n-nt] 	 0.0202138409972564
# fra$décalque$[n-f]
# 	 rus$имитация$[n-f-nn_n] 	 0.07000090936512035
# 	 rus$калька$[n_n-f-nn] 	 0.07000090936512035
# 	 rus$копия$[n-f-nn_n] 	 0.07000090936512035
# fra$peuplier$[n_n-m]
# 	 rus$тополь$[n-m-nn_n] 	 0.12494782603132289
# fra$polythéisme$[n-m]
# 	 rus$многобожие$[n_n-nt-nn] 	 0.08157860125476905
# 	 rus$политеизм$[n_n-m-nn] 	 0.08157860125476905
# fra$ulna$[n-m]
# 	 rus$локоть$[n-m-nn_n] 	 0.05652501536694941
# 	 rus$локтеваякость$[n] 	 0.049787068367863944
# fra$lier$[vblex]
# 	 rus$говорить$[vblex-imperf] 	 0.013475893998170934
# 	 rus$объявить$[vblex-perf_vblex-perf-tv] 	 0.013475893998170934
# fra$instigation$[n-f_n]
# 	 rus$побуждение$[n-nt-nn_n] 	 0.13358397513893056
# 	 rus$инициатива$[n-f-nn_n] 	 0.03852947988599058
# 	 rus$начинание$[n-nt-nn_n] 	 0.03852947988599058
# 	 rus$почин$[n-m-nn_n] 	 0.03852947988599058
# fra$celui qui$[rel-m-sg]
# 	 rus$который$[prn_prn-rel] 	 0.01831563888873418
# fra$lupanar$[n-m]
# 	 rus$бордель$[n_n-m-nn] 	 0.07000090936512035
# 	 rus$публичный дом$[n] 	 0.07000090936512035
# 	 rus$дом терпимости$[n] 	 0.0202138409972564
# fra$fading$[n-m]
# 	 rus$замирание$[n_n-nt-nn] 	 0.049787068367863944
# 	 rus$затухание$[n-nt-nn_n] 	 0.049787068367863944
# 	 rus$фединг$[n] 	 0.049787068367863944
# fra$sept$[num_num-mf-sp]
# 	 rus$семь$[n] 	 0.08379690677106663
# fra$journaliste$[n_n-mf_n-mf-ND]
# 	 rus$журналист$[n-m-aa_n_n-m] 	 0.5635059940683618
# 	 rus$газетчик$[n-m-aa_n] 	 0.06326296236603487
# fra$mortalité$[n-f_n_n-f-ND]
# 	 rus$смертность$[n-f-nn_n_n-f] 	 0.052005373884161515
# 	 rus$умирание$[n-nt-nn_n] 	 0.052005373884161515
# fra$espérance$[n_n-f_n-f-ND]
# 	 rus$надежда$[n-f-nn_n-f_n] 	 0.619627875577343
# 	 rus$доверие$[n-nt-nn_n_n-nt] 	 0.05652501536694941
# fra$couvercle$[n-m]
# 	 rus$одеяло$[n-nt-nn_n] 	 0.12200628324928185
# 	 rus$обложка$[n-f-nn_n] 	 0.11526833625019639
# 	 rus$пелена$[n-f-nn_n] 	 0.11526833625019639
# 	 rus$покрывало$[n-nt-nn_n] 	 0.11526833625019639
# 	 rus$покрытие$[n_n-nt-nn] 	 0.11526833625019639
# 	 rus$прикрытие$[n-nt-nn_n] 	 0.11526833625019639
# 	 rus$ставень$[n-m-nn_n] 	 0.11526833625019639
# fra$pardessus$[n-m]
# 	 rus$сюртук$[n_n-m-nn] 	 0.07484065425568358
# 	 rus$пальто$[n-nt-aa_n] 	 0.04526742688507605
# fra$au long de$[pr]
# 	 rus$вдоль$[pr] 	 0.05874332088324698
# 	 rus$по$[pr] 	 0.05874332088324698
# fra$talon$[n_n-m_n-m-ND]
# 	 rus$пята$[n-f-nn_n] 	 0.1855893490230921
# 	 rus$пятка$[n-f-nn_n] 	 0.1855893490230921
# fra$nihilisme$[n-m]
# 	 rus$нигилизм$[n-m-nn_n] 	 0.06326296236603487
# fra$stagnation$[n-f_n]
# 	 rus$застой$[n-m-nn_n] 	 0.026951787996341868
# fra$beaupré$[n-m]
# 	 rus$бушприт$[n-m-nn_n] 	 0.049787068367863944
# fra$compas$[n-m]
# 	 rus$циркуль$[n-m-nn_n] 	 0.07484065425568358
# 	 rus$ритм$[n-m-nn_n] 	 0.013475893998170934
# fra$endossataire$[n-mf_n]
# 	 rus$индоссат$[n] 	 0.049787068367863944
# fra$subrogation$[n-f]
# 	 rus$замена$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$замещение$[n-nt-nn_n] 	 0.049787068367863944
# 	 rus$перестановка$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$подмена$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$подстановка$[n-f-nn_n] 	 0.049787068367863944
# fra$abstinence$[n-f_n_n-f-ND]
# 	 rus$абстиненция$[n_n-f-nn] 	 0.09505449525293999
# 	 rus$воздержание$[n-nt-nn_n] 	 0.09505449525293999
# fra$iode$[n-m_n]
# 	 rus$йод$[n-m-nn_n] 	 0.11337013414167417
# fra$empilement$[n-m]
# 	 rus$пачка$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$стопа$[n_n-f-nn] 	 0.049787068367863944
# 	 rus$стопка$[n_n-f-nn] 	 0.049787068367863944
# 	 rus$штабель$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$склад$[n-m-nn_n] 	 0.03852947988599058
# fra$dysprosium$[n-m]
# 	 rus$диспрозий$[n] 	 0.049787068367863944
# fra$germanium$[n-m]
# 	 rus$германий$[n-m-nn_n] 	 0.05652501536694941
# fra$pérégrination$[n-f_n]
# 	 rus$путешествие$[n-nt-nn_n] 	 0.07000090936512035
# 	 rus$поездка$[n-f-nn_n] 	 0.026951787996341868
# fra$révision$[n-f_n_n-f-ND]
# 	 rus$пересмотр$[n-m-nn_n_n-m] 	 0.22411882890908266
# 	 rus$ревизия$[n-f-nn_n] 	 0.22411882890908266
# 	 rus$журнал$[n-m-nn_n_n-m] 	 0.060641522991769205
# fra$météo$[n-f-sp_n-f_n]
# 	 rus$климат$[n-m-nn_n_n-m] 	 0.07895716188050339
# 	 rus$время$[n] 	 0.052005373884161515
# 	 rus$доля$[n-f-nn_n] 	 0.052005373884161515
# 	 rus$срок$[n-m-nn_n] 	 0.052005373884161515
# 	 rus$прогноз погоды$[n] 	 0.049787068367863944
# 	 rus$время$[n-nt-nn_nt_n-nt] 	 0.04526742688507605
# fra$secousse tellurique$[n-f]
# 	 rus$толчок$[n-m-nn_n] 	 0.049787068367863944
# fra$voyou$[n]
# 	 rus$хулиган$[n-m-aa_n] 	 0.049787068367863944
# fra$SA$[n-acr_n-acr-f_n-acr-f-sg]
# 	 rus$акционерное общество$[n] 	 0.05652501536694941
# 	 rus$АО$[n] 	 0.05652501536694941
# 	 rus$общество$[n-nt-nn_n_n-nt] 	 0.013475893998170934
# fra$moyenne$[n-f_n_n-f-ND]
# 	 rus$носок$[n-m-nn_n] 	 0.03852947988599058
# fra$asphyxie$[n-f]
# 	 rus$асфиксия$[n-f-nn_n] 	 0.07484065425568358
# 	 rus$удушье$[n_n-nt-nn] 	 0.07484065425568358
# fra$gandin$[n-m]
# 	 rus$птица$[n-f-aa_n_n-f] 	 0.049787068367863944
# fra$télescopage$[n-m]
# 	 rus$конфликт$[n-m-nn_n_n-m] 	 0.05652501536694941
# 	 rus$столкновение$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$коллизия$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$удар$[n-m-nn_n] 	 0.031791532886905116
# fra$appeau$[n-m_n]
# 	 rus$реклама$[n-f-nn_n] 	 0.12010808114075963
# fra$gadolinium$[n-m]
# 	 rus$гадолиний$[n_n-m-nn] 	 0.049787068367863944
# fra$quel$[adj-itg-GD-ND_adj_adj-itg]
# 	 rus$который$[prn_prn-rel] 	 0.01831563888873418
# fra$filandre$[n-f]
# 	 rus$волокно$[n_n-nt-nn] 	 0.049787068367863944
# 	 rus$жгут$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$жгутик$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$нить накала$[n] 	 0.049787068367863944
# fra$sous-suite$[n-f]
# 	 rus$подпоследовательность$[n] 	 0.049787068367863944
# fra$stick$[n_n-m]
# 	 rus$жезл$[n-m-nn_n] 	 0.052005373884161515
# 	 rus$палка$[n-f-nn_n] 	 0.052005373884161515
# 	 rus$посох$[n-m-nn_n] 	 0.052005373884161515
# 	 rus$трость$[n-f-nn_n] 	 0.052005373884161515
# fra$scission$[n-f]
# 	 rus$деление$[n-nt-nn_n_n-nt] 	 0.05652501536694941
# fra$coopérative$[n-f]
# 	 rus$кооператив$[n-m-nn_n_n-m] 	 0.08157860125476905
# fra$appareil$[n-m_n_n-m-ND]
# 	 rus$аппарат$[n-m-nn_n] 	 0.303075990789586
# 	 rus$печь$[n_n-f-nn] 	 0.06326296236603487
# 	 rus$носилки$[n_n-f-nn-pl] 	 0.05652501536694941
# 	 rus$обогреватель$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$машина$[n-f-nn_n] 	 0.04526742688507605
# fra$hibou moyen duc$[n-m]
# 	 rus$ушастая сова$[n] 	 0.049787068367863944
# fra$passeport$[n_n-m_n-m-ND]
# 	 rus$паспорт$[n-m-nn_n_n-m] 	 0.47329124370598497
# fra$genêt$[n-m]
# 	 rus$дрок$[n-m-nn_n] 	 0.049787068367863944
# fra$statut$[n-m-pl]
# 	 rus$статус$[n-m-nn_n-m_n] 	 0.1855893490230921
# 	 rus$статут$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$устав$[n-m-nn_n_n-m] 	 0.049787068367863944
# 	 rus$ранг$[n-m-nn_n] 	 0.031791532886905116
# fra$glucose$[n-m]
# 	 rus$глюкоза$[n-f-nn_n] 	 0.031791532886905116
# fra$décembre$[n-m-ND]
# 	 rus$декабрь$[n-m-nn_n-m_n] 	 0.025053585887819647
# fra$campagnol$[n-m]
# 	 rus$полёвка$[n] 	 0.049787068367863944
# fra$francium$[n-m]
# 	 rus$франций$[n_n-m-nn] 	 0.05652501536694941
# fra$équinoxe$[n-m]
# 	 rus$равноденствие$[n_n-nt-nn] 	 0.013475893998170934
# fra$surplis$[n-m]
# 	 rus$стихарь$[n_n-m-nn] 	 0.049787068367863944
# fra$idiotie$[n-f]
# 	 rus$идиотизм$[n] 	 0.049787068367863944
# fra$essence$[n-f_n_n-f-ND]
# 	 rus$сущность$[n-f-nn_n] 	 0.42802381682090895
# 	 rus$бензин$[n-m-nn_n] 	 0.3049741928981083
# 	 rus$суть$[n-f-nn] 	 0.25591036179598775
# 	 rus$существо$[n_n-nt-nn] 	 0.1855893490230921
# 	 rus$эссенция$[n-f-nn_n] 	 0.1855893490230921
# fra$interaction$[n_n-f_n-f-ND]
# 	 rus$взаимодействие$[n-nt-nn_n] 	 0.15379781613618698
# fra$marchand$[n-GD_n-GD-ND]
# 	 rus$торговец$[n-m-aa_n] 	 0.09917100287775978
# 	 rus$бизнесмен$[n-m-aa_n] 	 0.04716562899359827
# 	 rus$коммерсант$[n-m-aa_n] 	 0.04716562899359827
# fra$tonnelier$[n-m_n]
# 	 rus$бочар$[n-m-aa_n] 	 0.049787068367863944
# fra$mullah$[n-m]
# 	 rus$мулла$[n-m-aa-sg_n-m-aa_n] 	 0.049787068367863944
# fra$passant$[n_n-m]
# 	 rus$прохожий$[n-m-aa_n] 	 0.07484065425568359
# fra$cotylédon$[n-m]
# 	 rus$семядоля$[n_n-f-nn] 	 0.049787068367863944
# fra$xérès$[n-m]
# 	 rus$херес$[n_n-m-nn] 	 0.08157860125476905
# 	 rus$шерри$[n] 	 0.08157860125476905
# fra$père$[n-m-pl]
# 	 rus$отец$[n-m-aa_n] 	 0.05874332088324698
# 	 rus$родители$[n] 	 0.025053585887819647
# 	 rus$батюшка$[n-m-aa_n] 	 0.025053585887819647
# 	 rus$падре$[n] 	 0.025053585887819647
# fra$boudin$[n-m]
# 	 rus$колбаса$[n-f-nn_n] 	 0.025053585887819647
# fra$épervier$[n-m]
# 	 rus$перепелятник$[n-m-aa_n] 	 0.049787068367863944
# 	 rus$тетеревятник$[n_n-m-aa] 	 0.049787068367863944
# 	 rus$ястреб$[n-m-aa_n] 	 0.049787068367863944
# 	 rus$ястреб-перепелятник$[n] 	 0.031791532886905116
# fra$rhum$[n-m_n]
# 	 rus$ром$[n-m-nn_n_n-m] 	 0.08831654825385453
# fra$couronne$[n_n-f_n-f-ND]
# 	 rus$венец$[n-m-aa_n] 	 0.199065243021263
# 	 rus$венок$[n-m-nn_n] 	 0.199065243021263
# fra$bréviaire$[n-m]
# 	 rus$молитвенник$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$настольная книга$[n] 	 0.049787068367863944
# 	 rus$требник$[n_n-m-nn] 	 0.049787068367863944
# fra$boisseau$[n-m]
# 	 rus$бушель$[n_n-m-nn] 	 0.049787068367863944
# fra$ensemble$[n-m_n_n-m-ND]
# 	 rus$группа$[n-f-nn_n_n-f] 	 0.47708764792302943
# 	 rus$группировка$[n-f-nn_n] 	 0.23275497801669037
# 	 rus$ар$[n-m-nn_n] 	 0.19232729602217757
# 	 rus$множество$[n-nt-nn_n_n-nt_n-nt-nn-sg] 	 0.19232729602217757
# 	 rus$совокупность$[n-f-nn_n] 	 0.19232729602217757
# fra$recueillir$[vblex]
# 	 rus$сделать$[vblex-perf-tv_vblex-perf] 	 0.0202138409972564
# fra$gorille$[n-mf_n_n-mf-ND]
# 	 rus$горилла$[n-f-aa_n] 	 0.1586375610267502
# fra$thèse$[n-f-ND]
# 	 rus$диссертация$[n-f-nn_n_n-f] 	 0.07895716188050339
# 	 rus$положение$[n-nt-nn_n] 	 0.07895716188050339
# 	 rus$тезис$[n-m-nn_n] 	 0.07895716188050339
# fra$superconducteur$[n]
# 	 rus$сверхпроводник$[n_n-m-nn] 	 0.049787068367863944
# fra$nombre$[n_n-m_n-m-ND]
# 	 rus$число$[n-nt-nn_n_n-nt] 	 0.41160638004069694
# 	 rus$номер$[n-m-nn_n] 	 0.11938484387501619
# 	 rus$население$[n-nt-nn_n-nt_n] 	 0.08831654825385452
# 	 rus$телефонный номер$[n] 	 0.052005373884161515
# fra$laine$[n_n-f_n-f-ND]
# 	 rus$шерсть$[n-f-nn_n] 	 0.17211345502492115
# fra$protocole$[n-m_n]
# 	 rus$протокол$[n-m-nn_n_n-m] 	 0.4482376578181654
# fra$navet$[n-m]
# 	 rus$брюква$[n_n-f-nn] 	 0.07484065425568358
# fra$borne supérieure$[n-f]
# 	 rus$точная верхняя грань$[n] 	 0.049787068367863944
# 	 rus$супремум$[n] 	 0.049787068367863944
# fra$voltairien$[n]
# 	 rus$вольтерьянец$[n_n-m-aa] 	 0.049787068367863944
# fra$Aymara$[n]
# 	 rus$аймара$[n] 	 0.049787068367863944
# fra$explorateur$[n_n-f]
# 	 rus$штурман$[n-m-aa_n] 	 0.10179244225202547
# 	 rus$мореплаватель$[n_n-m-aa] 	 0.031791532886905116
# 	 rus$мореход$[n_n-m-aa] 	 0.031791532886905116
# fra$herbe$[n_n-f_n-f-ND]
# 	 rus$трава$[n-f-nn_n] 	 0.47518944581450717
# fra$février$[n_n-m_n-m-sg]
# 	 rus$февраль$[n-m-nn_n-m_n] 	 0.17885140202400662
# fra$caoutchouc$[n_n-m]
# 	 rus$резина$[n-f-nn_n] 	 0.17211345502492115
# 	 rus$каучук$[n-m-nn_n] 	 0.1451616670285793
# 	 rus$гумми$[n] 	 0.03368973499542734
# 	 rus$камедь$[n] 	 0.03368973499542734
# fra$quinquina$[n-m]
# 	 rus$хина$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$хинное дерево$[n] 	 0.049787068367863944
# 	 rus$цинхона$[n] 	 0.049787068367863944
# fra$logique mathématique$[n-f]
# 	 rus$математическая логика$[n] 	 0.05652501536694941
# 	 rus$логистика$[n_n-f-nn] 	 0.05652501536694941
# fra$éducation$[n_n-f_n-f-ND]
# 	 rus$образование$[n-nt-nn_n_n-nt] 	 0.3445470134576176
# 	 rus$воспитание$[n-nt-nn_n] 	 0.2260170310176049
# fra$lignite$[n-f]
# 	 rus$бурый уголь$[n] 	 0.049787068367863944
# 	 rus$лигнит$[n-m-nn_n] 	 0.049787068367863944
# fra$cualquier$[det-ind-GD-sg]
# 	 rus$либо$[cnjcoo] 	 0.013475893998170934
# fra$repêchage$[n-m]
# 	 rus$шанс$[n-m-nn_n] 	 0.09315629314441777
# 	 rus$случай$[n-m-nn_n_n-m] 	 0.031791532886905116
# fra$argument$[n-m_n_n-m-ND]
# 	 rus$аргумент$[n-m-nn_n] 	 0.19232729602217757
# 	 rus$довод$[n-m-nn_n] 	 0.19232729602217757
# 	 rus$неизвестная$[n] 	 0.19232729602217757
# 	 rus$неопределённая$[n] 	 0.19232729602217757
# 	 rus$операнд$[n_n-m-nn] 	 0.19232729602217757
# fra$douce-amère$[n-f]
# 	 rus$паслён сладко-горький$[n] 	 0.049787068367863944
# fra$juste$[adv]
# 	 rus$только$[adv] 	 0.04716562899359827
# fra$schiste$[n-m]
# 	 rus$сланец$[n-m-nn_n] 	 0.06326296236603487
# 	 rus$шифер$[n-m-nn_n] 	 0.06326296236603487
# fra$cocasserie$[n-f]
# 	 rus$забавность$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$комизм$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$комичность$[n] 	 0.049787068367863944
# fra$animateur$[n_n-m]
# 	 rus$докладчик$[n-m-aa_n] 	 0.07000090936512035
# 	 rus$лектор$[n-m-aa_n] 	 0.07000090936512035
# 	 rus$диктор$[n-m-aa_n] 	 0.06326296236603487
# 	 rus$представитель$[n-m-aa_n_n-m] 	 0.06326296236603487
# fra$fédération$[n-f_n_n-f-ND]
# 	 rus$федерация$[n-f-nn_n_n-f] 	 0.5406707136968396
# fra$partie fractionnaire$[n-f]
# 	 rus$дробная часть$[n] 	 0.049787068367863944
# fra$pivot$[n-m_n]
# 	 rus$цапфа$[n_n-f-nn] 	 0.10663218714258871
# 	 rus$шейка вала$[n] 	 0.10663218714258871
# fra$condensé$[n-m]
# 	 rus$дайджест$[n_n-m-nn] 	 0.049787068367863944
# fra$tréfonds$[n-m]
# 	 rus$бездна$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$пропасть$[n-f-nn_n] 	 0.049787068367863944
# fra$quadrilatère$[n-m]
# 	 rus$четырёхугольник$[n_n-m-nn] 	 0.049787068367863944
# fra$putsch$[n-m_n]
# 	 rus$путч$[n_n-m-nn] 	 0.12010808114075965
# 	 rus$удар$[n-m-nn_n] 	 0.07895716188050339
# 	 rus$стук$[n-m-nn_n] 	 0.0202138409972564
# fra$établissement scolaire$[n-m]
# 	 rus$учебное заведение$[n] 	 0.049787068367863944
# fra$roue dentée$[n-f]
# 	 rus$зубчатое колесо$[n] 	 0.049787068367863944
# 	 rus$шестерёнка$[n] 	 0.049787068367863944
# 	 rus$шестерня$[n_n-f-nn] 	 0.049787068367863944
# fra$Turc$[n_n-m]
# 	 rus$турок$[n-m-aa_n-m_n] 	 0.049787068367863944
# fra$lemme$[n-m]
# 	 rus$лемма$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$мотто$[n] 	 0.025053585887819647
# 	 rus$эпиграф$[n_n-m-nn] 	 0.025053585887819647
# fra$grade$[n-m_n]
# 	 rus$ранг$[n-m-nn_n] 	 0.1268460281398451
# 	 rus$градус$[n-m-nn_n_n-m] 	 0.11074869476740849
# 	 rus$степень$[n-f-nn_n] 	 0.11074869476740849
# 	 rus$достоинство$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$звание$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$класс$[n-m-nn_n] 	 0.05652501536694941
# 	 rus$разряд$[n-m-nn_n] 	 0.05652501536694941
# 	 rus$сан$[n-m-nn_n] 	 0.05652501536694941
# 	 rus$сорт$[n-m-nn_n] 	 0.05652501536694941
# 	 rus$деление$[n-nt-nn_n_n-nt] 	 0.052005373884161515
# fra$sûr$[adj_adj-GD-ND]
# 	 rus$безопасный$[adj-sint_adj] 	 0.1470598691371015
# fra$fascination$[n-f_n]
# 	 rus$очарование$[n-nt-nn_n] 	 0.08157860125476905
# fra$beau-père$[n-m-pl]
# 	 rus$свёкор$[n] 	 0.01831563888873418
# 	 rus$тесть$[n-m-aa_n] 	 0.01831563888873418
# fra$vêpres$[n-f]
# 	 rus$вечерня$[n-f-nn_n] 	 0.049787068367863944
# fra$conjonctivite$[n-f]
# 	 rus$конъюнктивит$[n-m-nn_n] 	 0.049787068367863944
# fra$rôle principal$[n]
# 	 rus$лидер$[n-m-aa_n_n-m] 	 0.025053585887819647
# fra$ottavino$[n-m]
# 	 rus$спинет$[n] 	 0.049787068367863944
# fra$ballottage$[n-m_n_n-m-ND]
# 	 rus$лига$[n-f-nn_n] 	 0.06548126788233244
# 	 rus$связь$[n-f-nn_n_n-f] 	 0.06548126788233244
# 	 rus$химическая связь$[n] 	 0.06548126788233244
# 	 rus$союз$[n-m-nn_n_n-m] 	 0.06548126788233244
# 	 rus$галстук$[n-m-nn_n] 	 0.0202138409972564
# fra$enveloppe convexe$[n-f]
# 	 rus$оболочка$[n-f-nn_n] 	 0.06326296236603487
# 	 rus$покрытие$[n_n-nt-nn] 	 0.06326296236603487
# 	 rus$алгебраическое замыкание$[n] 	 0.049787068367863944
# 	 rus$выпуклая оболочка$[n] 	 0.049787068367863944
# 	 rus$линейная оболочка$[n] 	 0.049787068367863944
# fra$robe$[n-f_n-f-ND]
# 	 rus$платье$[n-nt-nn_n] 	 0.3461251121583645
# 	 rus$одежда$[n-f-nn_n] 	 0.19644380364699732
# 	 rus$костюм$[n-m-nn] 	 0.09505449525293999
# 	 rus$комплект одежды$[n] 	 0.05874332088324698
# 	 rus$халат$[n-m-nn_n] 	 0.049787068367863944
# fra$révolte$[n_n-f_n-f-ND]
# 	 rus$восстание$[n-nt-nn_n_n-nt] 	 0.1855893490230921
# 	 rus$бунт$[n-m-nn_n_n-m] 	 0.14032192213801603
# 	 rus$мятеж$[n-m-nn_n] 	 0.14032192213801603
# fra$boycottage$[n_n-m]
# 	 rus$бойкот$[n-m-nn_n_n-m] 	 0.08157860125476905
# fra$colonne vertébrale$[n-f]
# 	 rus$позвоночник$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$спин$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$хребет$[n-m-nn_n] 	 0.049787068367863944
# fra$dépistage$[n-m]
# 	 rus$выявление$[n-nt-nn_n] 	 0.031791532886905116
# 	 rus$обнаружение$[n_n-nt-nn] 	 0.031791532886905116
# fra$ticket$[n-m_n]
# 	 rus$билет$[n-m-nn_n] 	 0.07000090936512035
# 	 rus$контроль$[n-m-nn_n] 	 0.05684511877472476
# 	 rus$отрезной талон$[n] 	 0.05684511877472476
# 	 rus$банкнот$[n-m-nn_n] 	 0.0202138409972564
# 	 rus$банковский билет$[n] 	 0.0202138409972564
# fra$caractère privé$[n-m]
# 	 rus$близость$[n-f-nn_n] 	 0.0202138409972564
# 	 rus$задушевность$[n_n-f-nn] 	 0.0202138409972564
# 	 rus$интимность$[n_n-f-nn] 	 0.0202138409972564
# 	 rus$сердечность$[n_n-f-nn] 	 0.0202138409972564
# fra$exactitude$[n_n-f_n-f-ND]
# 	 rus$точность$[n-f-nn_n] 	 0.0404276819945128
# fra$compendium$[n-m]
# 	 rus$компендий$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$компендиум$[n-m-nn_n] 	 0.049787068367863944
# fra$textura$[n-m]
# 	 rus$зерно$[n-nt-nn_n] 	 0.013475893998170934
# fra$laie$[n-f]
# 	 rus$вепрь$[n-m-aa_n] 	 0.049787068367863944
# 	 rus$дикий кабан$[n_n-m-aa] 	 0.049787068367863944
# fra$aventure$[n-f_n_n-f-ND]
# 	 rus$приключение$[n-nt-nn_n] 	 0.46361175392485854
# 	 rus$похождение$[n-nt-nn_n] 	 0.19232729602217757
# fra$bifurcation$[n-f_n]
# 	 rus$развилка$[n_n-f-nn] 	 0.14032192213801603
# 	 rus$ветвь$[n-f-nn_n_n-f-nn-pl] 	 0.10369064436054767
# 	 rus$вилка$[n-f-nn_n] 	 0.09727280076923756
# 	 rus$вилы$[n_n-f-nn] 	 0.09727280076923756
# 	 rus$разветвление$[n-nt-nn_n] 	 0.09727280076923756
# 	 rus$отделение$[n-nt-nn_n] 	 0.03852947988599058
# 	 rus$филиал$[n-m-nn_n] 	 0.03852947988599058
# fra$ciboulette$[n-f]
# 	 rus$лук-резанец$[n] 	 0.049787068367863944
# 	 rus$лук-скорода$[n] 	 0.049787068367863944
# 	 rus$шнитт-лук$[n] 	 0.049787068367863944
# fra$langouste$[n-f_n]
# 	 rus$лангуст$[n_n-m-aa] 	 0.07484065425568359
# 	 rus$лангуста$[n_n-f-aa] 	 0.07484065425568359
# fra$emprunt$[n-m]
# 	 rus$заимствование$[n-nt-nn_n] 	 0.049787068367863944
# fra$géhenne$[n-f]
# 	 rus$геенна$[n_n-f-nn] 	 0.049787068367863944
# 	 rus$преисподняя$[n_n-f-nn] 	 0.049787068367863944
# fra$risque$[n_n-m_n-m-ND]
# 	 rus$риск$[n-m-nn_n-m] 	 0.2626483087950732
# 	 rus$опасность$[n-f-nn_n] 	 0.0202138409972564
# fra$abbé$[n_n-m]
# 	 rus$аббат$[n-m-aa_n] 	 0.15189961402766475
# fra$assistance$[n_n-f_n-f-ND]
# 	 rus$помощь$[n-f-nn_n] 	 0.05874332088324698
# fra$domination$[n-f_n_n-f-ND]
# 	 rus$порядок$[n-m-nn_n_n-m] 	 0.04716562899359827
# 	 rus$команда$[n-f-nn_n_n-f] 	 0.04526742688507605
# 	 rus$власть$[n-f-nn_n_n-f] 	 0.03852947988599058
# 	 rus$возможность$[n-f-nn_n] 	 0.03852947988599058
# 	 rus$кардинальное число$[n] 	 0.03852947988599058
# 	 rus$мощность$[n-f-nn_n] 	 0.03852947988599058
# 	 rus$сила$[n-f-nn_n_n-f] 	 0.03852947988599058
# 	 rus$правление$[n-nt-nn_n] 	 0.03852947988599058
# 	 rus$управление$[n-nt-nn_n_n-nt] 	 0.03852947988599058
# fra$nationaliste$[n_n-mf_n-mf-ND]
# 	 rus$националист$[n-m-aa_n] 	 0.20580319002034847
# fra$combien$[rel-adv_adv]
# 	 rus$что$[prn-itg_prn_prn-itg-nt_prn-itg-nt-sg] 	 0.08831654825385453
# fra$couveuse$[n-f]
# 	 rus$инкубатор$[n-m-nn_n] 	 0.06326296236603487
# fra$fantaisiste$[n]
# 	 rus$мечтатель$[n-m-aa_n] 	 0.049787068367863944
# 	 rus$фантазёр$[n] 	 0.049787068367863944
# fra$malfaiteur$[n]
# 	 rus$мерзавец$[n-m-aa_n] 	 0.06326296236603487
# 	 rus$негодяй$[n-m-aa_n] 	 0.06326296236603487
# 	 rus$подлец$[n-m-aa_n] 	 0.06326296236603487
# 	 rus$каналья$[n-m-aa_n] 	 0.049787068367863944
# 	 rus$прохвост$[n-m-aa_n] 	 0.049787068367863944
# 	 rus$сволочь$[n-f-aa_n] 	 0.049787068367863944
# 	 rus$хам$[n_n-m-aa] 	 0.049787068367863944
# fra$père$[n-m-sg]
# 	 rus$отец$[n-m-aa_n] 	 0.025053585887819647
# fra$levant$[n-m]
# 	 rus$восток$[n-m-nn_n_n-m] 	 0.12010808114075963
# fra$ontologie$[n-f]
# 	 rus$онтология$[n-f-nn_n] 	 0.013475893998170934
# fra$épanouissement$[n-m]
# 	 rus$цветение$[n-nt-nn_n] 	 0.049787068367863944
# fra$endroit$[n-m_n_n-m-ND]
# 	 rus$место$[n-nt-nn_n_n-nt] 	 0.3068723950066305
# 	 rus$веб-сайт$[n] 	 0.05874332088324698
# 	 rus$сайт$[n-m-nn_n] 	 0.05874332088324698
# fra$haché$[n-m]
# 	 rus$пики$[n] 	 0.031791532886905116
# 	 rus$пикировка$[n] 	 0.031791532886905116
# 	 rus$подколка$[n_n-f-nn] 	 0.031791532886905116
# 	 rus$укол$[n-m-nn_n] 	 0.031791532886905116
# fra$crise$[n-f-pl_n-f_n]
# 	 rus$кризис$[n-m-nn_n-m] 	 0.24917241479690233
# 	 rus$перелом$[n-m-nn_n] 	 0.17211345502492115
# fra$argent$[n-m-ND]
# 	 rus$серебро$[n-nt-nn_n-nt-nn-sg_n_n-nt] 	 0.03852947988599058
# fra$chapelle$[n_n-f_n-f-ND]
# 	 rus$капелла$[n-f-nn_n] 	 0.17885140202400662
# 	 rus$часовня$[n-f-nn_n] 	 0.17885140202400662

# %%
lang1, lang2 = 'eng','rus'
n = 10

# %time load_file(lang1, lang2, n=n)
# %time change_encoding('{}-{}'.format(lang1,lang2))
# Out:
# Wall time: 497 ms
# Wall time: 812 ms

# %%
check_graph(lang1, lang2, n=10)

# %%
example(lang1, lang2, n=200)
# Out:
# eng$participation$[n_n-ND]
# 	 rus$интерес$[n-m-nn_n-m_n] 	 0.013475893998170934
# eng$late$[adj-sint_adj]
# 	 rus$последний$[adj_adj-sint] 	 0.04526742688507605
# eng$trespass$[vblex]
# 	 rus$идти$[vblex-imperf] 	 0.04526742688507605
# 	 rus$сделать$[vblex-perf-tv_vblex-perf] 	 0.013475893998170934
# eng$esophagus$[n]
# 	 rus$пищевод$[n-m-nn_n] 	 0.06326296236603487
# eng$sarcasm$[n]
# 	 rus$сарказм$[n-m-nn_n] 	 0.12906433365614267
# eng$marchioness$[n_n-ND]
# 	 rus$маркграф$[n_n-m-aa] 	 0.08379690677106663
# 	 rus$маркиз$[n-m-aa_n] 	 0.08379690677106663
# eng$emulsion$[n]
# 	 rus$эмульсия$[n-f-nn_n] 	 0.05684511877472476
# eng$alloy$[n_n-sg]
# 	 rus$сплав$[n] 	 0.17211345502492115
# 	 rus$лига$[n-f-nn_n] 	 0.0404276819945128
# 	 rus$связь$[n-f-nn_n_n-f] 	 0.026951787996341868
# 	 rus$химическая связь$[n] 	 0.026951787996341868
# 	 rus$союз$[n-m-nn_n_n-m] 	 0.026951787996341868
# eng$stake$[n_n-ND]
# 	 rus$заклад$[n-m-nn_n] 	 0.0905348537701521
# 	 rus$пари$[n-nt-nn_n] 	 0.0905348537701521
# 	 rus$ставка$[n-f-nn_n] 	 0.0905348537701521
# 	 rus$интерес$[n-m-nn_n-m_n] 	 0.049787068367863944
# 	 rus$кол$[n-m-nn_n] 	 0.031791532886905116
# eng$pigment$[n]
# 	 rus$краска$[n-f-nn] 	 0.01831563888873418
# eng$brute$[n]
# 	 rus$скот$[n-m-aa_n] 	 0.05652501536694941
# 	 rus$скотина$[n-f-aa_n_n-f-aa-sg] 	 0.05652501536694941
# 	 rus$тварь$[n-f-aa_n] 	 0.031791532886905116
# eng$nurture$[n]
# 	 rus$образование$[n-nt-nn_n_n-nt] 	 0.05874332088324698
# 	 rus$воспитание$[n-nt-nn_n] 	 0.03852947988599058
# eng$bran$[n_n-sg]
# 	 rus$отруби$[n-m-nn-pl_n_n-m-nn] 	 0.03852947988599058
# eng$ride$[n]
# 	 rus$марш$[n-m-nn_n] 	 0.03368973499542734
# eng$gland$[n]
# 	 rus$железа$[n-f-nn_n] 	 0.1268460281398451
# eng$servant$[n_n-ND]
# 	 rus$слуга$[n-m-aa_n] 	 0.11558843965797175
# 	 rus$сервер$[n_n-m-nn] 	 0.013475893998170934
# eng$coolness$[n]
# 	 rus$холод$[n-m-nn_n] 	 0.052005373884161515
# eng$oasis$[n-pl]
# 	 rus$оазис$[n-m-nn_n] 	 0.0202138409972564
# eng$heroine$[n_n-ND]
# 	 rus$герой$[n-m-aa_n] 	 0.35729967019004516
# eng$liane$[n_n-ND]
# 	 rus$лиана$[n-f-nn_n] 	 0.05684511877472476
# eng$ache$[n]
# 	 rus$боль$[n-f-nn_n] 	 0.2147594425357315
# eng$souvenir$[n]
# 	 rus$воспоминания$[n] 	 0.05652501536694941
# 	 rus$мемуары$[n_n-m-nn] 	 0.05652501536694941
# 	 rus$подарок на память$[n] 	 0.049787068367863944
# 	 rus$сувенир$[n-m-nn_n] 	 0.049787068367863944
# eng$ignominy$[n]
# 	 rus$стыд$[n-m-nn_n] 	 0.025053585887819647
# eng$pickled mussel$[n]
# 	 rus$мидия$[n_n-f-aa] 	 0.03852947988599058
# eng$exchange rate$[n_n-sg]
# 	 rus$тип$[n-m-aa_n] 	 0.1945456015384751
# 	 rus$литера$[n-f-nn_n] 	 0.07705895977198116
# 	 rus$налог$[n-m-nn_n-m_n] 	 0.03368973499542734
# eng$fundamentalism$[n]
# 	 rus$фундаментализм$[n-m-nn_n] 	 0.1021125456598008
# eng$tender$[n_n-ND]
# 	 rus$предложение$[n-nt-nn_n_n-nt] 	 0.23687148564151017
# 	 rus$испытание$[n-nt-nn_n] 	 0.03368973499542734
# 	 rus$попытка$[n-f-nn_n] 	 0.03368973499542734
# 	 rus$проба$[n-f-nn_n] 	 0.03368973499542734
# 	 rus$проверка$[n-f-nn_n] 	 0.03368973499542734
# 	 rus$тест$[n_n-m-nn] 	 0.03368973499542734
# eng$alcove$[n_n-ND]
# 	 rus$спальня$[n-f-nn_n] 	 0.09727280076923756
# 	 rus$альков$[n-m-nn_n] 	 0.05684511877472476
# 	 rus$комната$[n-f-nn_n] 	 0.026951787996341868
# eng$associate member$[n-ND]
# 	 rus$член$[n-m-nn_n_n-m] 	 0.013475893998170934
# eng$tug$[n_n-ND]
# 	 rus$влечение$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$вытягивание$[n_n-nt-nn] 	 0.05652501536694941
# 	 rus$дёрганье$[n] 	 0.05652501536694941
# 	 rus$тяга$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$буксир$[n-m-nn_n] 	 0.01831563888873418
# eng$storyline$[n]
# 	 rus$интрига$[n-f-nn_n] 	 0.0202138409972564
# 	 rus$интрижка$[n] 	 0.0202138409972564
# 	 rus$уток$[n-m-nn_n] 	 0.01831563888873418
# eng$sure$[adj-sint_adj]
# 	 rus$безопасный$[adj-sint_adj] 	 0.12906433365614267
# eng$battlefield$[n]
# 	 rus$поле$[n-nt-nn_n_n-nt_n-nt-nn-pl] 	 0.11748664176649395
# 	 rus$поле битвы$[n] 	 0.06326296236603487
# 	 rus$графа$[n-f-nn_n] 	 0.04526742688507605
# 	 rus$нива$[n-f-nn_n] 	 0.04526742688507605
# 	 rus$почва$[n-f-nn_n] 	 0.04526742688507605
# 	 rus$площадь$[n-f-nn_n_n-f] 	 0.025053585887819647
# eng$orthography$[n]
# 	 rus$орфография$[n-f-nn_n] 	 0.031791532886905116
# 	 rus$правописание$[n-nt-nn_n] 	 0.031791532886905116
# eng$modifier$[n_n-sg]
# 	 rus$адаптер$[n-m-nn_n] 	 0.013475893998170934
# 	 rus$контроллер$[n-m-nn_n] 	 0.013475893998170934
# eng$contact$[vblex]
# 	 rus$описать$[vblex-perf_vblex-perf-tv] 	 0.013475893998170934
# eng$self-supervision$[n]
# 	 rus$самообладание$[n_n-nt-nn] 	 0.06358306577381023
# 	 rus$самоуправление$[n-nt-nn_n] 	 0.06358306577381023
# eng$personnel$[n_n-pl]
# 	 rus$группа$[n-f-nn_n_n-f] 	 0.013475893998170934
# 	 rus$клише$[n_n-nt-nn] 	 0.013475893998170934
# 	 rus$трафарет$[n-m-nn_n] 	 0.013475893998170934
# 	 rus$шаблон$[n-m-nn_n] 	 0.013475893998170934
# 	 rus$штамп$[n-m-nn_n] 	 0.013475893998170934
# eng$adulto$[n]
# 	 rus$взрослый$[n] 	 0.031791532886905116
# eng$photon$[n_n-ND]
# 	 rus$фотон$[n-m-nn_n] 	 0.10853038925111091
# eng$patriarch$[n]
# 	 rus$патриарх$[n-m-aa_n_n-m] 	 0.17211345502492115
# 	 rus$праотец$[n_n-m-aa] 	 0.17211345502492115
# eng$romance$[n_n-ND]
# 	 rus$идиллия$[n-f-nn_n] 	 0.0905348537701521
# 	 rus$роман$[n-m-nn_n_n-m] 	 0.04716562899359827
# 	 rus$римлянин$[n-m-aa_n] 	 0.0202138409972564
# 	 rus$романс$[n-m-nn_n] 	 0.01831563888873418
# eng$recipient$[n_n-sg]
# 	 rus$адресат$[n-m-aa_n] 	 0.04526742688507605
# 	 rus$получатель$[n-m-aa_n] 	 0.04526742688507605
# eng$meteorology$[n_n-sg]
# 	 rus$метеорология$[n-f-nn_n] 	 0.1268460281398451
# eng$North American$[n_n-ND]
# 	 rus$американец$[n-m-aa_n] 	 0.013475893998170934
# eng$control bit$[n]
# 	 rus$бит$[n_n-m-nn] 	 0.06358306577381023
# 	 rus$пара кнехтов$[n] 	 0.06358306577381023
# eng$mandolin$[n_n-sg]
# 	 rus$мандолина$[n-f-nn_n] 	 0.013475893998170934
# eng$shooting$[n_n-ND]
# 	 rus$залп$[n-m-nn_n] 	 0.14032192213801603
# 	 rus$стрельба$[n-f-nn_n] 	 0.14032192213801603
# eng$telegraph$[n_n-sg]
# 	 rus$телеграф$[n-m-nn_n-m_n] 	 0.13842372002949382
# eng$affect$[n]
# 	 rus$эффект$[n-m-nn_n] 	 0.06326296236603487
# 	 rus$действие$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$воздействие$[n-nt-nn_n] 	 0.049787068367863944
# eng$typhus$[n-sg_n]
# 	 rus$тиф$[n-m-nn_n] 	 0.01831563888873418
# eng$spread$[n-ND]
# 	 rus$паста$[n-f-nn_n] 	 0.013475893998170934
# 	 rus$тесто$[n-nt-nn_n] 	 0.013475893998170934
# eng$indigo$[n]
# 	 rus$индиец$[n_n-m-aa] 	 0.025053585887819647
# 	 rus$индиго$[n] 	 0.01831563888873418
# eng$tramcar$[n-pl]
# 	 rus$трамвай$[n-m-nn_n] 	 0.013475893998170934
# eng$athletics$[n_n-sg]
# 	 rus$атлетика$[n-f-nn_n] 	 0.17885140202400662
# eng$stigma$[n]
# 	 rus$стыд$[n-m-nn_n] 	 0.08831654825385452
# 	 rus$срам$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$рыльце$[n-nt-nn_n] 	 0.04526742688507605
# eng$accolade$[n]
# 	 rus$награда$[n-f-nn_n] 	 0.025053585887819647
# 	 rus$вознаграждение$[n-nt-nn_n] 	 0.01831563888873418
# 	 rus$премия$[n-f-nn_n_n-f] 	 0.013475893998170934
# 	 rus$цена$[n-f-nn_n_n-f] 	 0.013475893998170934
# eng$cinema$[n-pl]
# 	 rus$кино$[n-nt-nn_n] 	 0.0202138409972564
# 	 rus$кинематограф$[n-m-nn_n] 	 0.013475893998170934
# eng$puritan$[n]
# 	 rus$пуританин$[n-m-aa_n] 	 0.07484065425568359
# eng$ointment$[n]
# 	 rus$мазь$[n-f-nn_n] 	 0.08863665166162987
# eng$reindeer$[n_n-sg]
# 	 rus$олень$[n-m-aa_n_n-m] 	 0.025053585887819647
# eng$lady$[n-ND]
# 	 rus$дама$[n-f-aa_n] 	 0.013475893998170934
# 	 rus$дамка$[n-f-nn_n] 	 0.013475893998170934
# 	 rus$ферзь$[n_n-m-nn] 	 0.013475893998170934
# eng$aftereffect$[n]
# 	 rus$последовательность функций$[n] 	 0.01831563888873418
# 	 rus$последовательность Коши$[n] 	 0.01831563888873418
# 	 rus$сходящаяся в себе последовательность$[n] 	 0.01831563888873418
# 	 rus$фундаментальная последовательность$[n] 	 0.01831563888873418
# eng$metaphysics$[n_n-sg]
# 	 rus$метафизика$[n-f-nn_n] 	 0.07484065425568359
# eng$flowering$[n_n-ND]
# 	 rus$цветение$[n-nt-nn_n] 	 0.12010808114075963
# eng$inquest$[n]
# 	 rus$исследование$[n-nt-nn_n-nt] 	 0.16275406865157
# 	 rus$дознание$[n_n-nt-nn] 	 0.07221921488141791
# 	 rus$расследование$[n-nt-nn_n_n-nt] 	 0.07221921488141791
# 	 rus$следствие$[n-nt-nn_n] 	 0.07221921488141791
# eng$saber$[n]
# 	 rus$сабля$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$меч$[n-m-nn_n_n-m] 	 0.025053585887819647
# eng$tax free registration$[n]
# 	 rus$налог$[n-m-nn_n-m_n] 	 0.11748664176649395
# 	 rus$дань$[n-f-nn_n] 	 0.04526742688507605
# 	 rus$подать$[n] 	 0.04526742688507605
# 	 rus$пошлина$[n-f-nn_n] 	 0.04526742688507605
# 	 rus$налог на добавленную стоимость$[n] 	 0.025053585887819647
# 	 rus$НДС$[n] 	 0.025053585887819647
# eng$stomach-ache$[n_n-sg]
# 	 rus$боль$[n-f-nn_n] 	 0.15601612165248455
# 	 rus$зло$[n-nt-nn_n-nt-nn-sg__n] 	 0.05874332088324698
# 	 rus$головная боль$[n] 	 0.03852947988599058
# eng$euro$[n_n-sg]
# 	 rus$евро$[n-m-nn_n] 	 0.19232729602217757
# eng$centilitre$[n]
# 	 rus$сантилитр$[n] 	 0.043369224776553826
# eng$pest$[n]
# 	 rus$бедствие$[n-nt-nn_n] 	 0.07705895977198116
# 	 rus$рана$[n-f-nn_n] 	 0.04526742688507605
# eng$commonwealth$[n]
# 	 rus$конфедерация$[n-f-nn_n_n-f] 	 0.049787068367863944
# eng$inundation$[n_n-ND]
# 	 rus$наводнение$[n-nt-nn_n_n-nt] 	 0.20770139212887073
# eng$forward$[n_n-ND]
# 	 rus$перёд$[n] 	 0.013475893998170934
# 	 rus$перед$[n_n-m-nn] 	 0.013475893998170934
# 	 rus$передняя часть$[n] 	 0.013475893998170934
# 	 rus$предшествующ ее$[n] 	 0.013475893998170934
# 	 rus$предыдущее$[n] 	 0.013475893998170934
# 	 rus$прошлое$[n_n-nt-nn] 	 0.013475893998170934
# eng$libel$[n]
# 	 rus$клевета$[n-f-nn_n] 	 0.049787068367863944
# eng$proximity$[n_n-sg]
# 	 rus$окрестность$[n-f-nn_n_n-f-nn-pl] 	 0.031791532886905116
# 	 rus$сосед$[n-m-aa_n] 	 0.0202138409972564
# eng$wingspan$[n]
# 	 rus$размах крыльев$[n] 	 0.031791532886905116
# 	 rus$ширина паруса$[n] 	 0.031791532886905116
# eng$ambiguity$[n-pl]
# 	 rus$двузначность$[n] 	 0.026951787996341868
# 	 rus$двусмысленность$[n-f-nn_n] 	 0.026951787996341868
# 	 rus$неясность$[n-f-nn_n] 	 0.026951787996341868
# eng$cochlea$[n]
# 	 rus$собака$[n-f-aa_n_n-f] 	 0.025053585887819647
# 	 rus$улитка$[n_n-f-nn] 	 0.025053585887819647
# eng$ovary$[n]
# 	 rus$яичник$[n-m-nn_n] 	 0.13358397513893058
# 	 rus$завязь$[n_n-f-nn] 	 0.08831654825385452
# eng$seeing eye dog$[n]
# 	 rus$собака$[n-f-aa_n_n-f] 	 0.013475893998170934
# eng$hazelnut$[n]
# 	 rus$лесной орех$[n] 	 0.12010808114075963
# 	 rus$лещина$[n-f-nn_n] 	 0.12010808114075963
# eng$molding$[n]
# 	 rus$полоса$[n-f-nn_n] 	 0.031791532886905116
# 	 rus$струя$[n-f-nn_n] 	 0.025053585887819647
# eng$retirement$[n_n-ND]
# 	 rus$пенсия$[n-f-nn_n_n-f] 	 0.053903575992683736
# 	 rus$торжество$[n-nt-nn_n] 	 0.052005373884161515
# 	 rus$триумф$[n-m-nn_n] 	 0.052005373884161515
# eng$ascendent$[n]
# 	 rus$предок$[n-m-aa_n] 	 0.05684511877472476
# 	 rus$пращур$[n-m-aa_n] 	 0.01831563888873418
# 	 rus$праотец$[n_n-m-aa] 	 0.013475893998170934
# 	 rus$прародитель$[n_n-m-aa] 	 0.013475893998170934
# eng$meltdown$[n]
# 	 rus$коллапс$[n-m-nn_n] 	 0.013475893998170934
# eng$formalism$[n]
# 	 rus$формализм$[n-m-nn_n] 	 0.031791532886905116
# eng$retain$[vblex]
# 	 rus$учитывать$[vblex-imperf] 	 0.013475893998170934
# eng$hack$[n]
# 	 rus$удар$[n-m-nn_n] 	 0.06326296236603487
# 	 rus$стук$[n-m-nn_n] 	 0.013475893998170934
# eng$web technology$[n]
# 	 rus$технология$[n-f-nn_n_n-f] 	 0.09727280076923756
# eng$ambrosia$[n]
# 	 rus$амброзия$[n-f-nn_n_n-f] 	 0.05684511877472476
# eng$prosody$[n]
# 	 rus$просодия$[n-f-nn_n] 	 0.08831654825385452
# eng$prosthesis$[n-sg]
# 	 rus$протез$[n-m-nn_n] 	 0.0202138409972564
# eng$foreigner$[n_n-ND]
# 	 rus$посторонний$[n-m-aa_n] 	 0.07000090936512035
# 	 rus$чужой$[n] 	 0.07000090936512035
# 	 rus$чужак$[n-m-aa_n] 	 0.06326296236603487
# eng$commissure$[n]
# 	 rus$комиссура$[n] 	 0.025053585887819647
# 	 rus$соединение$[n-nt-nn_n] 	 0.025053585887819647
# 	 rus$спайка$[n_n-f-nn] 	 0.025053585887819647
# eng$abatement$[n]
# 	 rus$скидка$[n-f-nn_n] 	 0.031791532886905116
# eng$confederacy$[n]
# 	 rus$конфедерация$[n-f-nn_n_n-f] 	 0.03852947988599058
# eng$encephalopathy$[n]
# 	 rus$энцефалопатия$[n] 	 0.09989424014350323
# eng$prpers$[prn-subj-p2-mf-sp_prn-p2_prn-subj-p2-mf]
# 	 rus$prpers$[prn-pers-p3-mf-pl_prn_prn-pers] 	 0.053903575992683736
# eng$retailing$[n]
# 	 rus$продажа$[n-f-nn_n_n-f] 	 0.03852947988599058
# eng$lean$[vblex]
# 	 rus$объявить$[vblex-perf_vblex-perf-tv] 	 0.0905348537701521
# 	 rus$учитывать$[vblex-imperf] 	 0.04526742688507605
# 	 rus$быть$[vbser_vbser-adj] 	 0.03852947988599058
# eng$dinar$[n]
# 	 rus$обед$[n-m-nn_n] 	 0.08379690677106663
# 	 rus$еда$[n-f-nn_n-f-nn-sg_n] 	 0.07221921488141791
# 	 rus$пища$[n-f-nn_n-f-nn-sg_n_n-f] 	 0.04526742688507605
# 	 rus$блюдо$[n-nt-nn_n] 	 0.026951787996341868
# 	 rus$приём пищи$[n] 	 0.0202138409972564
# 	 rus$трапеза$[n_n-f-nn] 	 0.0202138409972564
# eng$dosage$[n]
# 	 rus$доза$[n-f-nn_n] 	 0.08831654825385452
# 	 rus$порция$[n-f-nn_n] 	 0.049787068367863944
# eng$labour union$[n]
# 	 rus$профсоюз$[n-m-nn_n_n-m] 	 0.06358306577381023
# 	 rus$синдикат$[n-m-nn_n] 	 0.06358306577381023
# 	 rus$объединение$[n-nt-nn_n] 	 0.013475893998170934
# 	 rus$союз$[n-m-nn_n_n-m] 	 0.013475893998170934
# 	 rus$уния$[n-f-nn_n] 	 0.013475893998170934
# eng$intimacy$[n_n-ND]
# 	 rus$близость$[n-f-nn_n] 	 0.031791532886905116
# 	 rus$задушевность$[n_n-f-nn] 	 0.031791532886905116
# 	 rus$интимность$[n_n-f-nn] 	 0.031791532886905116
# 	 rus$сердечность$[n_n-f-nn] 	 0.031791532886905116
# eng$emission$[n_n-ND]
# 	 rus$выделение$[n-nt-nn_n] 	 0.05652501536694941
# 	 rus$эманация$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$передача$[n-f-nn_n] 	 0.0202138409972564
# eng$yolk$[n]
# 	 rus$желток$[n-m-nn_n] 	 0.050107171775639295
# eng$north$[n-ND]
# 	 rus$север$[n-m-nn_n_n-m] 	 0.0404276819945128
# eng$retiree$[n]
# 	 rus$пенсионер$[n-m-aa_n] 	 0.049787068367863944
# eng$purgatory$[n]
# 	 rus$чистилище$[n-nt-nn_n] 	 0.14516166702857927
# eng$quoted share$[n]
# 	 rus$акция$[n-f-nn_n-f_n] 	 0.07221921488141791
# 	 rus$действие$[n-nt-nn_n] 	 0.03852947988599058
# eng$evacuation$[n_n-sg]
# 	 rus$эвакуация$[n-f-nn_n_n-f] 	 0.09505449525293999
# eng$moraine$[n]
# 	 rus$мурена$[n_n-f-aa] 	 0.01831563888873418
# eng$viewpoint$[n]
# 	 rus$точка$[n-f-nn_n_n-f] 	 0.22823533653390246
# 	 rus$пункт$[n-m-nn_n] 	 0.08379690677106663
# 	 rus$точка зрения$[n_n-f-nn] 	 0.06326296236603487
# 	 rus$место артикуляции$[n] 	 0.04526742688507605
# 	 rus$стежок$[n_n-m-nn] 	 0.03368973499542734
# eng$millennium$[n_n-ND]
# 	 rus$тысячелетие$[n-nt-nn_n] 	 0.18074960413252883
# eng$justice$[n-ND]
# 	 rus$справедливость$[n-f-nn_n] 	 0.013475893998170934
# eng$breeze$[n_n-ND]
# 	 rus$бриз$[n-m-nn_n] 	 0.17885140202400662
# eng$padded cell$[n]
# 	 rus$келья$[n_n-f-nn] 	 0.031791532886905116
# 	 rus$клетка$[n-f-nn_n_n-f] 	 0.031791532886905116
# 	 rus$коморка$[n] 	 0.031791532886905116
# 	 rus$отсек$[n-m-nn_n] 	 0.031791532886905116
# 	 rus$ячейка$[n-f-nn_n] 	 0.031791532886905116
# 	 rus$ячея$[n_n-f-nn] 	 0.031791532886905116
# eng$profit$[n_n-ND]
# 	 rus$польза$[n-f-nn_n] 	 0.2780224049017664
# 	 rus$выгода$[n-f-nn_n] 	 0.25107061690542454
# 	 rus$прибыль$[n-f-nn_n] 	 0.25107061690542454
# eng$admirer$[n]
# 	 rus$горячий сторонник$[n] 	 0.013475893998170934
# 	 rus$ревностный поборник$[n] 	 0.013475893998170934
# eng$soybean$[n]
# 	 rus$соя$[n_n-f-nn] 	 0.013475893998170934
# eng$theater$[n_n-ND]
# 	 rus$театр$[n-m-nn_n_n-m] 	 0.40224699366734584
# 	 rus$кукольный театр$[n] 	 0.04526742688507605
# 	 rus$театр варьете$[n] 	 0.04526742688507605
# eng$motherhood$[n_n-sg]
# 	 rus$материнство$[n-nt-nn_n] 	 0.1470598691371015
# eng$serum$[n]
# 	 rus$сыворотка$[n-f-nn_n] 	 0.12010808114075963
# eng$verve$[n_n-ND]
# 	 rus$воодушевление$[n-nt-nn_n] 	 0.049787068367863944
# 	 rus$пыл$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$вдохновение$[n-nt-nn_n] 	 0.0202138409972564
# eng$doom$[n]
# 	 rus$судьба$[n-f-nn_n] 	 0.025053585887819647
# 	 rus$участь$[n-f-nn_n] 	 0.025053585887819647
# eng$sparkle$[n]
# 	 rus$блеск$[n-m-nn_n] 	 0.013475893998170934
# 	 rus$сияние$[n-nt-nn_n] 	 0.013475893998170934
# eng$time$[n-unc]
# 	 rus$время$[n-nt-nn_nt_n-nt] 	 0.0808553639890256
# 	 rus$час$[n-m-nn_n_n-m] 	 0.0404276819945128
# 	 rus$время$[n] 	 0.0202138409972564
# 	 rus$доля$[n-f-nn_n] 	 0.0202138409972564
# 	 rus$срок$[n-m-nn_n] 	 0.0202138409972564
# 	 rus$раз$[n-m-nn_n] 	 0.0202138409972564
# eng$investment fund$[n]
# 	 rus$основа$[n-f-nn_n_n-f] 	 0.04526742688507605
# 	 rus$фон$[n-m-nn_n] 	 0.04526742688507605
# 	 rus$глубина$[n-f-nn_n] 	 0.03852947988599058
# 	 rus$дно$[n-nt-nn_n] 	 0.03852947988599058
# 	 rus$бюджет$[n-m-nn_n_n-m] 	 0.025053585887819647
# 	 rus$система$[n-f-nn_n_n-f] 	 0.025053585887819647
# eng$vine$[n]
# 	 rus$виноград$[n_n-m-nn] 	 0.09989424014350323
# 	 rus$виноградная лоза$[n] 	 0.05684511877472476
# eng$injector$[n]
# 	 rus$инжектор$[n_n-m-nn] 	 0.031791532886905116
# eng$valve$[n]
# 	 rus$клапан$[n-m-nn_n] 	 0.24433266990633906
# 	 rus$вентиль$[n_n-m-nn] 	 0.19906524302126302
# 	 rus$створка$[n_n-f-nn] 	 0.19906524302126302
# 	 rus$радиолампа$[n-f-nn_n] 	 0.13358397513893058
# 	 rus$электронная лампа$[n] 	 0.13358397513893058
# 	 rus$заслонка$[n_n-f-nn] 	 0.07221921488141791
# eng$jellyfish$[n]
# 	 rus$медуза$[n-f-aa_n] 	 0.06358306577381023
# eng$sabre$[n_n-ND]
# 	 rus$сабля$[n-f-nn_n] 	 0.09727280076923756
# 	 rus$меч$[n-m-nn_n_n-m] 	 0.013475893998170934
# eng$rear-view mirror$[n]
# 	 rus$зеркало заднего вида$[n] 	 0.025053585887819647
# eng$run$[n_n-ND]
# 	 rus$карьера$[n-f-nn_n] 	 0.41983939529033654
# 	 rus$бег$[n-m-nn_n-m-nn-sg_n] 	 0.18074960413252883
# 	 rus$бег наперегонки$[n] 	 0.07895716188050339
# 	 rus$забег$[n-m-nn_n] 	 0.07895716188050339
# 	 rus$состязание в беге$[n] 	 0.07895716188050339
# eng$fitness$[n_n-unc]
# 	 rus$здоровье$[n-nt-nn_n_n-nt_n-nt-nn-sg] 	 0.09727280076923756
# eng$guillotine$[n_n-sg]
# 	 rus$гильотина$[n-f-nn_n] 	 0.11337013414167418
# eng$pet$[n]
# 	 rus$тварь$[n-f-aa_n] 	 0.13580228065522815
# 	 rus$животное$[n-nt-aa_n_n-nt] 	 0.07895716188050339
# 	 rus$зверь$[n-m-aa_n] 	 0.07895716188050339
# eng$intellect$[n_n-sg]
# 	 rus$разум$[n-m-nn_n] 	 0.13358397513893058
# 	 rus$ум$[n-m-nn_n] 	 0.13358397513893058
# 	 rus$интеллект$[n-m-nn_n] 	 0.1268460281398451
# eng$instability$[n_n-ND]
# 	 rus$нестабильность$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$неустойчивость$[n-f-nn_n] 	 0.05652501536694941
# eng$repugnance$[n_n-unc]
# 	 rus$тошнота$[n-f-nn_n] 	 0.052005373884161515
# eng$insurance policy$[n]
# 	 rus$страховой полис$[n] 	 0.050107171775639295
# 	 rus$политика$[n-f-nn_n-f_n] 	 0.013475893998170934
# 	 rus$полиция$[n-f-nn_n-f_n] 	 0.013475893998170934
# eng$pivot$[n]
# 	 rus$цапфа$[n_n-f-nn] 	 0.10663218714258871
# 	 rus$шейка вала$[n] 	 0.10663218714258871
# eng$leisure$[n_n-ND]
# 	 rus$свободное время$[n] 	 0.07000090936512035
# 	 rus$праздник$[n-m-nn_n_n-m] 	 0.01831563888873418
# eng$gondola$[n]
# 	 rus$гондола$[n-f-nn_n] 	 0.043369224776553826
# eng$prior to$[pr]
# 	 rus$впереди$[pr] 	 0.07705895977198116
# 	 rus$перед$[pr_] 	 0.07705895977198116
# 	 rus$до$[pr_pr-gen_] 	 0.043369224776553826
# eng$news$[n-unc]
# 	 rus$новость$[n-f-nn_n-f_n] 	 0.013475893998170934
# eng$new$[adj-sint_adj]
# 	 rus$девять$[n] 	 0.06548126788233244
# eng$periwinkle$[n]
# 	 rus$барвинок$[n_n-m-nn] 	 0.025053585887819647
# eng$bump$[n_n-ND]
# 	 rus$удар$[n-m-nn_n] 	 0.29561480652475713
# 	 rus$путч$[n_n-m-nn] 	 0.22823533653390246
# 	 rus$опухоль$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$шишка$[n-f-nn_n] 	 0.05652501536694941
# 	 rus$блажь$[n_n-f-nn] 	 0.052005373884161515
# 	 rus$каприз$[n-m-nn_n] 	 0.052005373884161515
# 	 rus$выстрел$[n-m-nn_n_n-m_n-m-nn-pl] 	 0.052005373884161515
# 	 rus$солнечный ожог$[n] 	 0.052005373884161515
# 	 rus$солнечный удар$[n] 	 0.052005373884161515
# eng$alone$[adv]
# 	 rus$только$[adv] 	 0.26192507152932976
# eng$eucalyptus$[n-pl]
# 	 rus$эвкалипт$[n-m-nn_n] 	 0.031791532886905116
# eng$oil reserve$[n]
# 	 rus$запас$[n-m-nn_n_n-m-nn-pl] 	 0.031791532886905116
# 	 rus$резерв$[n-m-nn_n] 	 0.031791532886905116
# eng$neutron star$[n]
# 	 rus$звезда$[n-f-nn_n_n-f] 	 0.07705895977198116
# 	 rus$астерия$[n] 	 0.06358306577381023
# 	 rus$морская звезда$[n] 	 0.06358306577381023
# eng$jeopardy$[n]
# 	 rus$риск$[n-m-nn_n-m] 	 0.05874332088324698
# 	 rus$опасность$[n-f-nn_n] 	 0.05652501536694941
# eng$Protestantism$[n]
# 	 rus$протестантство$[n_n-nt-nn] 	 0.03852947988599058
# eng$flip$[n]
# 	 rus$палец$[n-m-nn_n] 	 0.23981302842355118
# 	 rus$палец ноги$[n] 	 0.0202138409972564
# eng$motif$[n]
# 	 rus$разум$[n-m-nn_n] 	 0.12422458876557943
# 	 rus$мотив$[n-m-nn_n] 	 0.11558843965797175
# 	 rus$лозунг$[n-m-nn_n] 	 0.06810270725659812
# 	 rus$тема$[n-f-nn_n_n-f] 	 0.06548126788233244
# 	 rus$девиз$[n-m-nn_n_n-m] 	 0.049787068367863944
# 	 rus$девиза$[n-f-nn_n] 	 0.049787068367863944
# 	 rus$исчисление в иностранной валюте$[n] 	 0.049787068367863944
# 	 rus$причина$[n-f-nn_n_n-f] 	 0.04526742688507605
# eng$furthfullness$[n]
# 	 rus$истинность$[n-f-nn_n] 	 0.08157860125476905
# 	 rus$подлинность$[n_n-f-nn] 	 0.08157860125476905
# 	 rus$истина$[n-f-nn_n_n-f] 	 0.025053585887819647
# eng$hermeneutics$[n]
# 	 rus$герменевтика$[n_n-f-nn] 	 0.049787068367863944
# 	 rus$толкование текстов$[n] 	 0.049787068367863944
# eng$arrest$[n_n-ND]
# 	 rus$арест$[n-m-nn_n-m_n] 	 0.3348675236764912
# eng$earthernware$[n]
# 	 rus$фаянс$[n_n-m-nn] 	 0.06358306577381023
# eng$lathe$[n_n-ND]
# 	 rus$очередь$[n-f-nn_n] 	 0.06548126788233244
# 	 rus$последовательность$[n-f-nn_n_n-f] 	 0.06548126788233244
# 	 rus$ряд$[n-m-nn_n] 	 0.06548126788233244
# 	 rus$череда$[n_n-f-nn] 	 0.06548126788233244
# 	 rus$волчок$[n-m-aa_n] 	 0.031791532886905116
# 	 rus$юла$[n-f-nn_n] 	 0.031791532886905116
# eng$Thursday$[n-sg]
# 	 rus$четверг$[n-m-nn_n-m_n] 	 0.05874332088324698
# eng$transcendence$[n_n-ND]
# 	 rus$важность$[n-f-nn_n] 	 0.08379690677106663
# 	 rus$значительность$[n-f-nn_n] 	 0.08379690677106663
# eng$curiosity$[n-pl]
# 	 rus$любопытство$[n-nt-nn] 	 0.03852947988599058
# eng$open$[n]
# 	 rus$турнир$[n-m-nn_n] 	 0.049787068367863944
# eng$contest$[n-pl]
# 	 rus$конкурс$[n-m-nn_n] 	 0.04526742688507605
# 	 rus$состязание$[n-nt-nn_n] 	 0.04526742688507605
# eng$isolation cell$[n]
# 	 rus$келья$[n_n-f-nn] 	 0.031791532886905116
# 	 rus$клетка$[n-f-nn_n_n-f] 	 0.031791532886905116
# 	 rus$коморка$[n] 	 0.031791532886905116
# 	 rus$отсек$[n-m-nn_n] 	 0.031791532886905116
# 	 rus$ячейка$[n-f-nn_n] 	 0.031791532886905116
# 	 rus$ячея$[n_n-f-nn] 	 0.031791532886905116
# eng$glance$[n_n-ND]
# 	 rus$взгляд$[n-m-nn_n] 	 0.3476201804089186
# 	 rus$взор$[n-m-nn] 	 0.11074869476740849
# eng$avidity$[n]
# 	 rus$алчность$[n-f-nn_n_n-f] 	 0.031791532886905116
# 	 rus$жадность$[n-f-nn_n] 	 0.031791532886905116
# eng$denture$[n_n-ND]
# 	 rus$зубы$[n] 	 0.08379690677106663
# eng$ace$[n-sg]
# 	 rus$туз$[n_n-m] 	 0.031791532886905116
# eng$subsoil$[n]
# 	 rus$подвал$[n-m-nn_n] 	 0.013475893998170934
# eng$decease$[n_n-sg]
# 	 rus$смерть$[n-f-nn_n_n-f] 	 0.031791532886905116
# eng$cinnabar$[n]
# 	 rus$киноварь$[n_n-f-nn] 	 0.025053585887819647
# eng$capital$[n-ND]
# 	 rus$столица$[n-f-nn_n_n-f] 	 0.013475893998170934
# 	 rus$капитал$[n-m-nn_n_n-m] 	 0.013475893998170934
# eng$skiff$[n]
# 	 rus$судно$[n-nt-nn_n_n-nt] 	 0.025053585887819647
# eng$return$[vblex]
# 	 rus$идти$[vblex-imperf] 	 0.1328607378731871
# 	 rus$сделать$[vblex-perf-tv_vblex-perf] 	 0.07895716188050339
# eng$ton$[n_n-ND]
# 	 rus$тонна$[n-f-nn_n] 	 0.5264715824329252
# eng$regularisation$[n]
# 	 rus$правило$[n-nt-nn_n] 	 0.013475893998170934
# eng$sea urchin$[n]
# 	 rus$морской каштан$[n] 	 0.07516075766345894
# 	 rus$ёж$[n] 	 0.0703210127728957
# eng$porthole$[n]
# 	 rus$иллюминатор$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$люк$[n-m-nn_n] 	 0.049787068367863944
# 	 rus$брешь$[n-f-nn_n] 	 0.025053585887819647
# 	 rus$пробоина$[n-f-nn_n] 	 0.025053585887819647
# 	 rus$пролом$[n-m-nn_n] 	 0.025053585887819647
# 	 rus$прорыв$[n-m-nn_n] 	 0.025053585887819647
# eng$self-defence$[n]
# 	 rus$самозащита$[n-f-nn_n] 	 0.031791532886905116
# eng$wail$[n_n-ND]
# 	 rus$плач$[n-m-nn_n] 	 0.07000090936512035
# 	 rus$причитание$[n_n-nt-nn] 	 0.06326296236603487
# 	 rus$стенание$[n_n-nt-nn] 	 0.06326296236603487
# eng$placing$[n]
# 	 rus$инвестиция$[n-f-nn_n_n-f] 	 0.10401074776832303
# 	 rus$капиталовложение$[n] 	 0.10401074776832303
# 	 rus$место$[n-nt-nn_n_n-nt] 	 0.04526742688507605
# eng$exit$[vblex]
# 	 rus$идти$[vblex-imperf] 	 0.35729967019004516
# 	 rus$разработать$[vblex-perf_vblex-perf-tv] 	 0.266764816419893
# 	 rus$работать$[vblex-imperf] 	 0.266764816419893
# 	 rus$сделать$[vblex-perf-tv_vblex-perf] 	 0.2147594425357315
# 	 rus$быть$[vbser_vbser-adj] 	 0.06548126788233244
# eng$shot$[n_n-ND]
# 	 rus$выстрел$[n-m-nn_n_n-m_n-m-nn-pl] 	 0.21254113701943395
# 	 rus$черта$[n-f-nn_n] 	 0.09917100287775978
# 	 rus$острота$[n-f-nn_n] 	 0.025053585887819647
# eng$gum$[n_n-pl]
# 	 rus$десна$[n_n-f-nn] 	 0.04526742688507605
# eng$theft$[n_n-ND]
# 	 rus$полёт$[n-m-nn_n] 	 0.06548126788233244
# eng$elder$[n_n-ND]
# 	 rus$старейшина$[n_n-m-aa] 	 0.049787068367863944
# eng$cartel$[n]
# 	 rus$картель$[n_n-m-nn] 	 0.10663218714258871
# 	 rus$объединение$[n-nt-nn_n] 	 0.10663218714258871
# 	 rus$плакат$[n-m-nn] 	 0.06548126788233244
# 	 rus$афиша$[n-f-nn_n] 	 0.03368973499542734
# 	 rus$объявление$[n-nt-nn_n] 	 0.03368973499542734
# 	 rus$статья$[n-f-nn_n_n-f] 	 0.03368973499542734
# eng$sludge$[n]
# 	 rus$ил$[n_n-m-nn] 	 0.049787068367863944
# 	 rus$тина$[n_n-f-nn] 	 0.049787068367863944
# 	 rus$грязь$[n-f-nn_n] 	 0.013475893998170934
# eng$house$[n_n-sg]
# 	 rus$дом$[n-m-nn_n_n-m] 	 0.21443933912795618
# 	 rus$здание$[n-nt-nn_n_n-nt] 	 0.17401165713344338
# 	 rus$изба$[n-f-nn_n] 	 0.17401165713344338
# 	 rus$камера$[n-f-nn_n] 	 0.1511763767619213
# 	 rus$комната$[n-f-nn_n] 	 0.13770048276375035
# 	 rus$палата$[n-f-nn_n] 	 0.0905348537701521
# 	 rus$бордель$[n_n-m-nn] 	 0.06737946999085467
# 	 rus$публичный дом$[n] 	 0.06737946999085467
# eng$theism$[n]
# 	 rus$теизм$[n_n-m-nn] 	 0.049787068367863944
# eng$insulation$[n_n-unc]
# 	 rus$изоляция$[n-f-nn_n_n-f] 	 0.013475893998170934
# eng$bronzework$[n]
# 	 rus$работа$[n-f-nn_n_n-f] 	 0.05874332088324698
# 	 rus$труд$[n-m-nn_n_n-m] 	 0.03852947988599058
# 	 rus$дело$[n-nt-nn_n_n-nt] 	 0.031791532886905116
# 	 rus$произведение$[n-nt-nn_n] 	 0.031791532886905116
# 	 rus$сочинение$[n-nt-nn_n] 	 0.031791532886905116
# eng$alderwoman$[n]
# 	 rus$консультант$[n-m-aa_n] 	 0.013475893998170934
# 	 rus$советник$[n-m-aa_n] 	 0.013475893998170934
# 	 rus$советчик$[n-m-aa_n] 	 0.013475893998170934

# %%
lang_c
def copy_local():
    global lang_codes
    with open ('./files/lang_codes.json', 'r') as f: lang_codes = json.load(f)   
    logging.info('Start')
    if not os.path.exists('./dictionaries2/'): os.makedirs('./dictionaries2/')
    with open ('dictionaries.txt','r') as inp:
        for line in inp:
            pair = [l(i) for i in line.replace('.dix','').split('.')[-1].split('-')]
            print (pair)
            
    
    #for repo_name in repo_names(user):
    #    bidix = bidix_url(github.get_repo(user.name+'/'+repo_name))
    #    langs = [l(i) for i in repo_name.split('-')[1:]]
    #    filename = './dictionaries/'+'-'.join(langs)+'.dix'
    #    if bidix:
    #        response = requests.get(bidix)
    #        response.encoding = 'UTF-8'
    #        with open(filename, 'w', encoding='UTF-8') as f: f.write(response.text)
    #logging.info('Finish')

# %%
from tool.functions import *
from tool.evaluation import *
copy_local()
# Out:
# 2018-07-13 18:11:12,974 | INFO : Start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ecfc7ade84a> in <module>()
#       1 from tool.functions import *
#       2 from tool.evaluation import *
# ----> 3 copy_local()
#
# ~\Documents\GitHub\GSoC_2018\tool\functions.py in copy_local()
#     563         for line in inp:
#     564             langs = [l(i) for i in line.replace('.dix','').split('.')[-1].split('-')]
# --> 565             print (pair)
#     566             filename = './dictionaries2/'+'-'.join(langs)+'.dix'
#     567             with open(line, 'r') as f:
#
# NameError: name 'pair' is not defined
