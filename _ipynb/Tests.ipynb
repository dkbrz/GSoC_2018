# %%
from tool.functions import *
from tool.evaluation import *

# %%
def GRRF (lang1, lang2, n=10, cutoff=4, n_iter=3):
    get_relevant_languages(lang1, lang2)
    #check_graph(lang1, lang2, n=n)
    print ('top-5')
    # %time eval_loop(lang1, lang2, n=n, cutoff=cutoff, n_iter=n_iter, topn=5)
    print ('top-1')
    # %time eval_loop(lang1, lang2, n=n, cutoff=cutoff, n_iter=n_iter, topn=1)

# %%
check_graph('fin', 'eng', n=10)

# %%
GRRF ('fin', 'eng', n=10, cutoff=4, n_iter=3)
# Out:
# top-5
# ...
# Precision : 0.8429319371727748, recall : 0.575, f1-score : 0.6836518046709129
# Precision : 0.8294117647058824, recall : 0.5685483870967742, f1-score : 0.6746411483253589
# Precision : 0.8364779874213837, recall : 0.4962686567164179, f1-score : 0.6229508196721312
#
# Wall time: 4min 3s
# top-1
# ...
# Precision : 0.47770700636942676, recall : 0.2918287937743191, f1-score : 0.36231884057971014
# Precision : 0.4444444444444444, recall : 0.28451882845188287, f1-score : 0.3469387755102041
# Precision : 0.4682080924855491, recall : 0.313953488372093, f1-score : 0.37587006960556846
#
# Wall time: 3min 56s

# %%
lang1, lang2 = 'fra','cat'
check_graph(lang1, lang2)

# %%
GRRF (lang1, lang2)
# Out:
# top-5
# ...
# Precision : 0.9469387755102041, recall : 0.464, f1-score : 0.6228187919463088
# Precision : 0.9279835390946503, recall : 0.451, f1-score : 0.6069986541049798
# Precision : 0.9483471074380165, recall : 0.459, f1-score : 0.6185983827493261
#
# Wall time: 6min 1s
# top-1
# ...
# Precision : 0.6808510638297872, recall : 0.32, f1-score : 0.435374149659864
# Precision : 0.7448979591836735, recall : 0.365, f1-score : 0.4899328859060403
# Precision : 0.7133620689655172, recall : 0.331, f1-score : 0.4521857923497268
#
# Wall time: 6min 5s

# %%
lang1, lang2 = 'kaz','rus'
check_graph(lang1, lang2)

# %%
GRRF (lang1, lang2)
# Out:
# top-5
# ...
# Precision : 0.7931034482758621, recall : 0.345, f1-score : 0.48083623693379784
# Precision : 0.8184019370460048, recall : 0.338, f1-score : 0.47841472045293704
# Precision : 0.8423423423423423, recall : 0.374, f1-score : 0.518005540166205
#
# Wall time: 3min 29s
# top-1
# ...
# Precision : 0.37404580152671757, recall : 0.147, f1-score : 0.21105527638190955
# Precision : 0.4174757281553398, recall : 0.172, f1-score : 0.24362606232294615
# Precision : 0.3967136150234742, recall : 0.169, f1-score : 0.2370266479663394
#
# Wall time: 3min 15s

# %%
lang1, lang2 = 'fra','eng'
check_graph(lang1, lang2)

# %%
GRRF (lang1, lang2)
# Out:
# top-5
# ...
# Precision : 0.9387283236994219, recall : 0.812, f1-score : 0.8707774798927614
# Precision : 0.9383720930232559, recall : 0.807, f1-score : 0.867741935483871
# Precision : 0.9351415094339622, recall : 0.793, f1-score : 0.8582251082251082
#
# Wall time: 8min 39s
# top-1
# ...
# Precision : 0.7004662004662005, recall : 0.601, f1-score : 0.6469321851453175
# Precision : 0.7101947308132875, recall : 0.62, f1-score : 0.6620395088093967
# Precision : 0.7110091743119266, recall : 0.62, f1-score : 0.6623931623931624
#
# Wall time: 7min 32s

# %%
lang1, lang2 = 'deu','swe'
check_graph(lang1, lang2)

# %%
GRRF (lang1, lang2)
# Out:
# top-5
# ...
# Precision : 0.8381410256410257, recall : 0.523, f1-score : 0.6440886699507389
# Precision : 0.8658536585365854, recall : 0.568, f1-score : 0.6859903381642511
# Precision : 0.8320373250388803, recall : 0.535, f1-score : 0.6512477175897748
#
# Wall time: 12min 7s
# top-1
# ...
# Precision : 0.4776357827476038, recall : 0.299, f1-score : 0.3677736777367773
# Precision : 0.5106035889070146, recall : 0.313, f1-score : 0.3880967141971482
# Precision : 0.5110759493670886, recall : 0.323, f1-score : 0.39583333333333326
#
# Wall time: 11min 22s

# %%
lang1, lang2 = 'urd','hin'
check_graph(lang1, lang2)

# %%
GRRF (lang1, lang2)
# Out:
# top-5
# ...
# Precision : 0.998992950654582, recall : 0.992, f1-score : 0.9954841946813848
# Precision : 0.998992950654582, recall : 0.992, f1-score : 0.9954841946813848
# Precision : 0.998992950654582, recall : 0.992, f1-score : 0.9954841946813848
#
# Wall time: 9.95 s
# top-1
# ...
# Precision : 0.7323943661971831, recall : 0.728, f1-score : 0.7301905717151455
# Precision : 0.7328629032258065, recall : 0.727, f1-score : 0.7299196787148594
# Precision : 0.7354124748490946, recall : 0.731, f1-score : 0.7331995987963892
#
# Wall time: 6.69 s

# %%
lang1, lang2 = 'tur','tat'
check_graph(lang1, lang2)

# %%
GRRF (lang1, lang2)
# Out:
# top-5
# ...
# Precision : 0.775, recall : 0.40789473684210525, f1-score : 0.5344827586206897
# Precision : 0.7452830188679245, recall : 0.3640552995391705, f1-score : 0.48916408668730643
# Precision : 0.7317073170731707, recall : 0.36, f1-score : 0.48257372654155495
#
# Wall time: 3min 33s
# top-1
# ...
# Precision : 0.5174825174825175, recall : 0.2948207171314741, f1-score : 0.37563451776649753
# Precision : 0.4485294117647059, recall : 0.23735408560311283, f1-score : 0.3104325699745547
# Precision : 0.4962962962962963, recall : 0.2815126050420168, f1-score : 0.3592493297587131
#
# Wall time: 3min 33s
